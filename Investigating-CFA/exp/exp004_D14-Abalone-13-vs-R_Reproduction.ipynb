# %% [markdown]
# # Reproduction of Experiments on Dataset D14

# %% [markdown]
# ## Read data

# %%
import sys 
import os
sys.path.insert(0, os.path.join("..", "src"))
import pandas as pd
# %matplotlib inline

names = ["Sex", "Length", "Diameter", "Height", "Whole weight", "Shucked weight", "Viscera weight", "Shell weight", "Rings"] 

path = 'http://archive.ics.uci.edu/ml/machine-learning-databases/abalone/abalone.data'
df = pd.read_csv(path, header=None, names=names)
df
# Out:
#      Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 0      M   0.455     0.365   0.095        0.5140          0.2245
# 1      M   0.350     0.265   0.090        0.2255          0.0995
# 2      F   0.530     0.420   0.135        0.6770          0.2565
# 3      M   0.440     0.365   0.125        0.5160          0.2155
# 4      I   0.330     0.255   0.080        0.2050          0.0895
# ...   ..     ...       ...     ...           ...             ...
# 4172   F   0.565     0.450   0.165        0.8870          0.3700
# 4173   M   0.590     0.440   0.135        0.9660          0.4390
# 4174   M   0.600     0.475   0.205        1.1760          0.5255
# 4175   F   0.625     0.485   0.150        1.0945          0.5310
# 4176   M   0.710     0.555   0.195        1.9485          0.9455
#
#       Viscera weight  Shell weight  Rings
# 0             0.1010        0.1500     15
# 1             0.0485        0.0700      7
# 2             0.1415        0.2100      9
# 3             0.1140        0.1550     10
# 4             0.0395        0.0550      7
# ...              ...           ...    ...
# 4172          0.2390        0.2490     11
# 4173          0.2145        0.2605     10
# 4174          0.2875        0.3080      9
# 4175          0.2610        0.2960     10
# 4176          0.3765        0.4950     12
#
# [4177 rows x 9 columns]

# %%
# preprocess categorical column
from sklearn.preprocessing import LabelEncoder
label_encoder = LabelEncoder()

df["Sex"] = label_encoder.fit_transform(df["Sex"])
df
# Out:
#       Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 0       2   0.455     0.365   0.095        0.5140          0.2245
# 1       2   0.350     0.265   0.090        0.2255          0.0995
# 2       0   0.530     0.420   0.135        0.6770          0.2565
# 3       2   0.440     0.365   0.125        0.5160          0.2155
# 4       1   0.330     0.255   0.080        0.2050          0.0895
# ...   ...     ...       ...     ...           ...             ...
# 4172    0   0.565     0.450   0.165        0.8870          0.3700
# 4173    2   0.590     0.440   0.135        0.9660          0.4390
# 4174    2   0.600     0.475   0.205        1.1760          0.5255
# 4175    0   0.625     0.485   0.150        1.0945          0.5310
# 4176    2   0.710     0.555   0.195        1.9485          0.9455
#
#       Viscera weight  Shell weight  Rings
# 0             0.1010        0.1500     15
# 1             0.0485        0.0700      7
# 2             0.1415        0.2100      9
# 3             0.1140        0.1550     10
# 4             0.0395        0.0550      7
# ...              ...           ...    ...
# 4172          0.2390        0.2490     11
# 4173          0.2145        0.2605     10
# 4174          0.2875        0.3080      9
# 4175          0.2610        0.2960     10
# 4176          0.3765        0.4950     12
#
# [4177 rows x 9 columns]

# %%
label_column = "Rings"

minority_labels = [13]
majority_labels = df[label_column].value_counts().drop(minority_labels).index.tolist() # all except 13

df_filtered = df[df[label_column].isin(majority_labels + minority_labels)].copy()

df_filtered.loc[df_filtered[label_column].isin(majority_labels), label_column] = 1
df_filtered.loc[df_filtered[label_column].isin(minority_labels), label_column] = 0

X = df_filtered.drop(label_column, axis=1)
y = df_filtered[label_column]

# %%
y.value_counts()
# Out:
# 1    3974
# 0     203
# Name: Rings, dtype: int64

# %% [markdown]
# # Classification

# %%
from sklearn.model_selection import ParameterGrid, KFold, GridSearchCV
from sklearn.metrics import roc_auc_score
import numpy as np

# %% [markdown]
# > **Note:** In the following, we use a custom piece of code for the grid search and cross-validation. We do this to enforce that the augmentation/oversampling step is only applied to training data and the test data is actually kept separate. For the baseline model, this means that we could also simply make use of the functions provided by sklearn instead of our custom code. However, in order to make the results comparable, we use the same code in each case.

# %%
kf = KFold(n_splits=5, shuffle=True, random_state=7018321)

# %% [markdown]
# ## Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf_param_grid = {
    'n_estimators': [50, 100, 200, 400, 600],
    'max_depth': [None, 4, 6, 10, 20, 30, 50, 80, 100],
}

# compute all combinations of parameters
combination_dicts = list(ParameterGrid(rf_param_grid))

# %% [markdown]
# ### Baseline (no augmentation)

# %%
all_scores = []

for i, (train_index, test_index) in enumerate(kf.split(X)):
    #print(f"Fold {i}:")
    scores_for_fold = []
    X_train, X_test, y_train, y_test = X.iloc[train_index], X.iloc[test_index], y.iloc[train_index], y.iloc[test_index]
        
    for param_comb in combination_dicts:
        clf = RandomForestClassifier(random_state=19231823, **param_comb)
        clf.fit(X_train, y_train)
        current_score = roc_auc_score(y_test, clf.predict_proba(X_test)[:, 1])
        #print(f"Score for combination {param_comb}: {current_score}")
        scores_for_fold.append(current_score)
        
    all_scores.append(scores_for_fold)

# %%
score_avg_over_folds = np.array(all_scores).mean(axis=0)
best_score_idx = score_avg_over_folds.argmax()
print(f"Best params: {combination_dicts[best_score_idx]}")
print(f"Best AUC: {score_avg_over_folds[best_score_idx]}")
# Out:
# Best params: {'max_depth': 6, 'n_estimators': 600}
# Best AUC: 0.7395650202089131

# %% [markdown]
# To verify that our cross-validation code works as expected, we can compare to a regular sklearn grid search here:

# %%
baseline_search = GridSearchCV(RandomForestClassifier(random_state=19231823), rf_param_grid, scoring="roc_auc")
baseline_search.fit(X, y)
baseline_search.best_score_
# Out:
# 0.7195691823899371

# %% [markdown]
# We can see that the best model found by a sklearn grid search performs similarly well to our best model, which indicates that the code works as expected.

# %% [markdown]
# ### With CFA

# %%
from cfa import Iterative_CFA

# %% [markdown]
# For CFA, we try two different approaches, since it is not entirely clear from the paper what the authors actually did.
# 1. The first approach strictly follows the pseudo-code and description given in section 3.2 of the paper.
# 2. In an earlier section of the paper, the authors say that _"the class of [a] new [synthetic counterfactual] instance needs to be verified by the underlying ML model."_ This means that we use some ML model trained on the data (without CFA) to assign a class to a new synthetic counterfactual, and only keep those that were classified to be a minority instance. This seems to lead to much more reasonable synthetic counterfactuals (see visualizations of the algorithm in exp001) but, at the same time, often means that the algorithm is unable to produce a fully balanced dataset (since it may terminate early).
#
# > **Note:** We also use a different tolerance level of 50% here, since the 10%-threshold proposed by the authors does not yield any "good" native counterfactuals, which makes the algorithm unusable.

# %% [markdown]
# #### Approach 1: No verification

# %%
all_scores = []

for i, (train_index, test_index) in enumerate(kf.split(X)):
    print(f"Fold {i}:")
    scores_for_fold = []
    X_train, X_test, y_train, y_test = X.iloc[train_index], X.iloc[test_index], y.iloc[train_index], y.iloc[test_index]
    
    X_train_augmented, y_train_augmented = Iterative_CFA(X_train, 
                                                         y_train, 
                                                         stddev_percent=50, 
                                                         verify_with_baseline_model=False,
                                                         visualize_with_pca=False)
    
    for param_comb in combination_dicts:
        clf = RandomForestClassifier(random_state=19231823, **param_comb)
        clf.fit(X_train_augmented, y_train_augmented)
        current_score = roc_auc_score(y_test, clf.predict_proba(X_test)[:, 1])
        #print(f"Score for combination {param_comb}: {current_score}")
        scores_for_fold.append(current_score)
        
    all_scores.append(scores_for_fold)
# Out:
# Fold 0:
# Data distribution before CFA:
# 	Majority (1): 3183, Minority (label 0): 158
# Number of 'good' native counterfactuals in data: 1378
# Data distribution after iteration 0:
# 	Majority (1): 3183, Minority (label 0): 310
# Number of 'good' native counterfactuals in data: 1125
# Data distribution after iteration 1:
# 	Majority (1): 3183, Minority (label 0): 347
# Number of 'good' native counterfactuals in data: 1136
# Data distribution after iteration 2:
# 	Majority (1): 3183, Minority (label 0): 353
# Number of 'good' native counterfactuals in data: 1141
# Data distribution after iteration 3:
# 	Majority (1): 3183, Minority (label 0): 354
# Number of 'good' native counterfactuals in data: 1141
# Data distribution after iteration 4:
# 	Majority (1): 3183, Minority (label 0): 355
# Number of 'good' native counterfactuals in data: 1141
# Data distribution after iteration 5:
# 	Majority (1): 3183, Minority (label 0): 356
# Number of 'good' native counterfactuals in data: 1141
# Data distribution after iteration 6:
# 	Majority (1): 3183, Minority (label 0): 357
# Number of 'good' native counterfactuals in data: 1141
# Data distribution after iteration 7:
# 	Majority (1): 3183, Minority (label 0): 358
# Number of 'good' native counterfactuals in data: 1141
# Data distribution after iteration 8:
# 	Majority (1): 3183, Minority (label 0): 359
# Number of 'good' native counterfactuals in data: 1141
# Data distribution after iteration 9:
# 	Majority (1): 3183, Minority (label 0): 360
# Number of 'good' native counterfactuals in data: 1141
# Data distribution after iteration 10:
# 	Majority (1): 3183, Minority (label 0): 361
# Number of 'good' native counterfactuals in data: 1141
# Data distribution after iteration 11:
# 	Majority (1): 3183, Minority (label 0): 362
# Number of 'good' native counterfactuals in data: 1141
# Data distribution after iteration 12:
# 	Majority (1): 3183, Minority (label 0): 363
# Number of 'good' native counterfactuals in data: 1141
# Data distribution after iteration 13:
# 	Majority (1): 3183, Minority (label 0): 364
# Number of 'good' native counterfactuals in data: 1141
# Data distribution after iteration 14:
# 	Majority (1): 3183, Minority (label 0): 365
# Number of 'good' native counterfactuals in data: 1141
# Data distribution after iteration 15:
# 	Majority (1): 3183, Minority (label 0): 366
# Number of 'good' native counterfactuals in data: 1141
# Data distribution after iteration 16:
# 	Majority (1): 3183, Minority (label 0): 367
# Number of 'good' native counterfactuals in data: 1141
# Data distribution after iteration 17:
# 	Majority (1): 3183, Minority (label 0): 368
# Number of 'good' native counterfactuals in data: 1141
# Data distribution after iteration 18:
# 	Majority (1): 3183, Minority (label 0): 369
# Number of 'good' native counterfactuals in data: 1141
# Data distribution after iteration 19:
# 	Majority (1): 3183, Minority (label 0): 370
# Number of 'good' native counterfactuals in data: 1141
# Data distribution after iteration 20:
# 	Majority (1): 3183, Minority (label 0): 371
# Number of 'good' native counterfactuals in data: 1141
# Data distribution after iteration 21:
# 	Majority (1): 3183, Minority (label 0): 372
# Number of 'good' native counterfactuals in data: 1141
# Data distribution after iteration 22:
# 	Majority (1): 3183, Minority (label 0): 373
# Number of 'good' native counterfactuals in data: 1141
# Data distribution after iteration 23:
# 	Majority (1): 3183, Minority (label 0): 374
# Number of 'good' native counterfactuals in data: 1141
# Data distribution after iteration 24:
# 	Majority (1): 3183, Minority (label 0): 375
# Number of 'good' native counterfactuals in data: 1141
# Data distribution after iteration 25:
# 	Majority (1): 3183, Minority (label 0): 376
# Number of 'good' native counterfactuals in data: 1140
# Data distribution after iteration 26:
# 	Majority (1): 3183, Minority (label 0): 377
# Number of 'good' native counterfactuals in data: 1140
# Data distribution after iteration 27:
# 	Majority (1): 3183, Minority (label 0): 378
# Number of 'good' native counterfactuals in data: 1140
# Data distribution after iteration 28:
# 	Majority (1): 3183, Minority (label 0): 379
# Number of 'good' native counterfactuals in data: 1140
# Data distribution after iteration 29:
# 	Majority (1): 3183, Minority (label 0): 380
# Number of 'good' native counterfactuals in data: 1140
# Data distribution after iteration 30:
# 	Majority (1): 3183, Minority (label 0): 381
# Number of 'good' native counterfactuals in data: 1140
# Data distribution after iteration 31:
# 	Majority (1): 3183, Minority (label 0): 382
# Number of 'good' native counterfactuals in data: 1140
# Data distribution after iteration 32:
# 	Majority (1): 3183, Minority (label 0): 383
# Number of 'good' native counterfactuals in data: 1140
# Data distribution after iteration 33:
# 	Majority (1): 3183, Minority (label 0): 384
# Number of 'good' native counterfactuals in data: 1140
# Data distribution after iteration 34:
# 	Majority (1): 3183, Minority (label 0): 385
# Number of 'good' native counterfactuals in data: 1140
# Data distribution after iteration 35:
# 	Majority (1): 3183, Minority (label 0): 386
# Number of 'good' native counterfactuals in data: 1140
# Data distribution after iteration 36:
# 	Majority (1): 3183, Minority (label 0): 387
# Number of 'good' native counterfactuals in data: 1140
# Data distribution after iteration 37:
# 	Majority (1): 3183, Minority (label 0): 388
# Number of 'good' native counterfactuals in data: 1140
# Data distribution after iteration 38:
# 	Majority (1): 3183, Minority (label 0): 389
# Number of 'good' native counterfactuals in data: 1140
# Data distribution after iteration 39:
# 	Majority (1): 3183, Minority (label 0): 390
# Number of 'good' native counterfactuals in data: 1140
# Data distribution after iteration 40:
# 	Majority (1): 3183, Minority (label 0): 391
# Number of 'good' native counterfactuals in data: 1140
# Data distribution after iteration 41:
# 	Majority (1): 3183, Minority (label 0): 392
# Number of 'good' native counterfactuals in data: 1137
# Data distribution after iteration 42:
# 	Majority (1): 3183, Minority (label 0): 393
# Number of 'good' native counterfactuals in data: 1137
# Data distribution after iteration 43:
# 	Majority (1): 3183, Minority (label 0): 394
# Number of 'good' native counterfactuals in data: 1137
# Data distribution after iteration 44:
# 	Majority (1): 3183, Minority (label 0): 395
# Number of 'good' native counterfactuals in data: 1137
# Data distribution after iteration 45:
# 	Majority (1): 3183, Minority (label 0): 396
# Number of 'good' native counterfactuals in data: 1137
# Data distribution after iteration 46:
# 	Majority (1): 3183, Minority (label 0): 397
# Number of 'good' native counterfactuals in data: 1137
# Data distribution after iteration 47:
# 	Majority (1): 3183, Minority (label 0): 398
# Number of 'good' native counterfactuals in data: 1137
# Data distribution after iteration 48:
# 	Majority (1): 3183, Minority (label 0): 399
# Number of 'good' native counterfactuals in data: 1137
# Data distribution after iteration 49:
# 	Majority (1): 3183, Minority (label 0): 400
# Number of 'good' native counterfactuals in data: 1137
# Data distribution after iteration 50:
# 	Majority (1): 3183, Minority (label 0): 401
# Number of 'good' native counterfactuals in data: 1137
# Data distribution after iteration 51:
# 	Majority (1): 3183, Minority (label 0): 402
# Number of 'good' native counterfactuals in data: 1137
# Data distribution after iteration 52:
# 	Majority (1): 3183, Minority (label 0): 403
# Number of 'good' native counterfactuals in data: 1137
# Data distribution after iteration 53:
# 	Majority (1): 3183, Minority (label 0): 404
# Number of 'good' native counterfactuals in data: 1137
# Data distribution after iteration 54:
# 	Majority (1): 3183, Minority (label 0): 405
# Number of 'good' native counterfactuals in data: 1137
# Data distribution after iteration 55:
# 	Majority (1): 3183, Minority (label 0): 406
# Number of 'good' native counterfactuals in data: 1137
# Data distribution after iteration 56:
# 	Majority (1): 3183, Minority (label 0): 407
# Number of 'good' native counterfactuals in data: 1137
# Data distribution after iteration 57:
# 	Majority (1): 3183, Minority (label 0): 408
# Number of 'good' native counterfactuals in data: 1137
# Data distribution after iteration 58:
# 	Majority (1): 3183, Minority (label 0): 409
# Number of 'good' native counterfactuals in data: 1137
# Data distribution after iteration 59:
# 	Majority (1): 3183, Minority (label 0): 410
# Number of 'good' native counterfactuals in data: 1137
# Data distribution after iteration 60:
# 	Majority (1): 3183, Minority (label 0): 411
# Number of 'good' native counterfactuals in data: 1137
# Data distribution after iteration 61:
# 	Majority (1): 3183, Minority (label 0): 412
# Number of 'good' native counterfactuals in data: 1137
# Data distribution after iteration 62:
# 	Majority (1): 3183, Minority (label 0): 413
# Number of 'good' native counterfactuals in data: 1137
# Data distribution after iteration 63:
# 	Majority (1): 3183, Minority (label 0): 414
# Number of 'good' native counterfactuals in data: 1137
# Data distribution after iteration 64:
# 	Majority (1): 3183, Minority (label 0): 415
# Number of 'good' native counterfactuals in data: 1137
# Data distribution after iteration 65:
# 	Majority (1): 3183, Minority (label 0): 416
# Number of 'good' native counterfactuals in data: 1137
# Data distribution after iteration 66:
# 	Majority (1): 3183, Minority (label 0): 417
# Number of 'good' native counterfactuals in data: 1137
# Data distribution after iteration 67:
# 	Majority (1): 3183, Minority (label 0): 418
# Number of 'good' native counterfactuals in data: 1137
# Data distribution after iteration 68:
# 	Majority (1): 3183, Minority (label 0): 419
# Number of 'good' native counterfactuals in data: 1137
# Data distribution after iteration 69:
# 	Majority (1): 3183, Minority (label 0): 420
# Number of 'good' native counterfactuals in data: 1137
# Data distribution after iteration 70:
# 	Majority (1): 3183, Minority (label 0): 421
# Number of 'good' native counterfactuals in data: 1137
# Data distribution after iteration 71:
# 	Majority (1): 3183, Minority (label 0): 422
# Number of 'good' native counterfactuals in data: 1137
# Data distribution after iteration 72:
# 	Majority (1): 3183, Minority (label 0): 423
# Number of 'good' native counterfactuals in data: 1137
# Data distribution after iteration 73:
# 	Majority (1): 3183, Minority (label 0): 424
# Number of 'good' native counterfactuals in data: 1137
# Data distribution after iteration 74:
# 	Majority (1): 3183, Minority (label 0): 425
# Number of 'good' native counterfactuals in data: 1137
# Data distribution after iteration 75:
# 	Majority (1): 3183, Minority (label 0): 426
# Number of 'good' native counterfactuals in data: 1137
# Data distribution after iteration 76:
# 	Majority (1): 3183, Minority (label 0): 427
# Number of 'good' native counterfactuals in data: 1137
# Data distribution after iteration 77:
# 	Majority (1): 3183, Minority (label 0): 428
# Number of 'good' native counterfactuals in data: 1137
# Data distribution after iteration 78:
# 	Majority (1): 3183, Minority (label 0): 429
# Number of 'good' native counterfactuals in data: 1137
# Data distribution after iteration 79:
# 	Majority (1): 3183, Minority (label 0): 430
# Number of 'good' native counterfactuals in data: 1137
# Data distribution after iteration 80:
# 	Majority (1): 3183, Minority (label 0): 431
# Number of 'good' native counterfactuals in data: 1137
# Data distribution after iteration 81:
# 	Majority (1): 3183, Minority (label 0): 432
# Number of 'good' native counterfactuals in data: 1137
# Data distribution after iteration 82:
# 	Majority (1): 3183, Minority (label 0): 433
# Number of 'good' native counterfactuals in data: 1137
# Data distribution after iteration 83:
# 	Majority (1): 3183, Minority (label 0): 434
# Number of 'good' native counterfactuals in data: 1137
# Data distribution after iteration 84:
# 	Majority (1): 3183, Minority (label 0): 435
# Number of 'good' native counterfactuals in data: 1137
# Data distribution after iteration 85:
# 	Majority (1): 3183, Minority (label 0): 436
# Number of 'good' native counterfactuals in data: 1137
# Data distribution after iteration 86:
# 	Majority (1): 3183, Minority (label 0): 437
# Number of 'good' native counterfactuals in data: 1137
# Data distribution after iteration 87:
# 	Majority (1): 3183, Minority (label 0): 438
# Number of 'good' native counterfactuals in data: 1136
# Data distribution after iteration 88:
# 	Majority (1): 3183, Minority (label 0): 439
# Number of 'good' native counterfactuals in data: 1136
# Data distribution after iteration 89:
# 	Majority (1): 3183, Minority (label 0): 440
# Number of 'good' native counterfactuals in data: 1136
# Data distribution after iteration 90:
# 	Majority (1): 3183, Minority (label 0): 441
# Number of 'good' native counterfactuals in data: 1136
# Data distribution after iteration 91:
# 	Majority (1): 3183, Minority (label 0): 442
# Number of 'good' native counterfactuals in data: 1136
# Data distribution after iteration 92:
# 	Majority (1): 3183, Minority (label 0): 443
# Number of 'good' native counterfactuals in data: 1136
# Data distribution after iteration 93:
# 	Majority (1): 3183, Minority (label 0): 444
# Number of 'good' native counterfactuals in data: 1136
# Data distribution after iteration 94:
# 	Majority (1): 3183, Minority (label 0): 445
# Number of 'good' native counterfactuals in data: 1136
# Data distribution after iteration 95:
# 	Majority (1): 3183, Minority (label 0): 446
# Number of 'good' native counterfactuals in data: 1136
# Data distribution after iteration 96:
# 	Majority (1): 3183, Minority (label 0): 447
# Number of 'good' native counterfactuals in data: 1136
# Data distribution after iteration 97:
# 	Majority (1): 3183, Minority (label 0): 448
# Number of 'good' native counterfactuals in data: 1136
# Data distribution after iteration 98:
# 	Majority (1): 3183, Minority (label 0): 449
# Number of 'good' native counterfactuals in data: 1136
# Data distribution after iteration 99:
# 	Majority (1): 3183, Minority (label 0): 450
# Number of 'good' native counterfactuals in data: 1136
# Data distribution after iteration 100:
# 	Majority (1): 3183, Minority (label 0): 451
# Number of 'good' native counterfactuals in data: 1136
# Data distribution after iteration 101:
# 	Majority (1): 3183, Minority (label 0): 452
# Number of 'good' native counterfactuals in data: 1136
# Data distribution after iteration 102:
# 	Majority (1): 3183, Minority (label 0): 453
# Number of 'good' native counterfactuals in data: 1136
# Data distribution after iteration 103:
# 	Majority (1): 3183, Minority (label 0): 454
# Number of 'good' native counterfactuals in data: 1136
# Data distribution after iteration 104:
# 	Majority (1): 3183, Minority (label 0): 455
# Number of 'good' native counterfactuals in data: 1135
# Data distribution after iteration 105:
# 	Majority (1): 3183, Minority (label 0): 456
# Number of 'good' native counterfactuals in data: 1135
# Data distribution after iteration 106:
# 	Majority (1): 3183, Minority (label 0): 457
# Number of 'good' native counterfactuals in data: 1135
# Data distribution after iteration 107:
# 	Majority (1): 3183, Minority (label 0): 458
# Number of 'good' native counterfactuals in data: 1135
# Data distribution after iteration 108:
# 	Majority (1): 3183, Minority (label 0): 459
# Number of 'good' native counterfactuals in data: 1135
# Data distribution after iteration 109:
# 	Majority (1): 3183, Minority (label 0): 460
# Number of 'good' native counterfactuals in data: 1135
# Data distribution after iteration 110:
# 	Majority (1): 3183, Minority (label 0): 461
# Number of 'good' native counterfactuals in data: 1135
# Data distribution after iteration 111:
# 	Majority (1): 3183, Minority (label 0): 462
# Number of 'good' native counterfactuals in data: 1135
# Data distribution after iteration 112:
# 	Majority (1): 3183, Minority (label 0): 463
# Number of 'good' native counterfactuals in data: 1135
# Data distribution after iteration 113:
# 	Majority (1): 3183, Minority (label 0): 464
# Number of 'good' native counterfactuals in data: 1135
# Data distribution after iteration 114:
# 	Majority (1): 3183, Minority (label 0): 465
# Number of 'good' native counterfactuals in data: 1135
# Data distribution after iteration 115:
# 	Majority (1): 3183, Minority (label 0): 466
# Number of 'good' native counterfactuals in data: 1135
# Data distribution after iteration 116:
# 	Majority (1): 3183, Minority (label 0): 467
# Number of 'good' native counterfactuals in data: 1133
# Data distribution after iteration 117:
# 	Majority (1): 3183, Minority (label 0): 468
# Number of 'good' native counterfactuals in data: 1133
# Data distribution after iteration 118:
# 	Majority (1): 3183, Minority (label 0): 469
# Number of 'good' native counterfactuals in data: 1133
# Data distribution after iteration 119:
# 	Majority (1): 3183, Minority (label 0): 470
# Number of 'good' native counterfactuals in data: 1133
# Data distribution after iteration 120:
# 	Majority (1): 3183, Minority (label 0): 471
# Number of 'good' native counterfactuals in data: 1133
# Data distribution after iteration 121:
# 	Majority (1): 3183, Minority (label 0): 472
# Number of 'good' native counterfactuals in data: 1133
# Data distribution after iteration 122:
# 	Majority (1): 3183, Minority (label 0): 473
# Number of 'good' native counterfactuals in data: 1133
# Data distribution after iteration 123:
# 	Majority (1): 3183, Minority (label 0): 474
# Number of 'good' native counterfactuals in data: 1133
# Data distribution after iteration 124:
# 	Majority (1): 3183, Minority (label 0): 475
# Number of 'good' native counterfactuals in data: 1133
# Data distribution after iteration 125:
# 	Majority (1): 3183, Minority (label 0): 476
# Number of 'good' native counterfactuals in data: 1133
# Data distribution after iteration 126:
# 	Majority (1): 3183, Minority (label 0): 477
# Number of 'good' native counterfactuals in data: 1133
# Data distribution after iteration 127:
# 	Majority (1): 3183, Minority (label 0): 478
# Number of 'good' native counterfactuals in data: 1133
# Data distribution after iteration 128:
# 	Majority (1): 3183, Minority (label 0): 479
# Number of 'good' native counterfactuals in data: 1133
# Data distribution after iteration 129:
# 	Majority (1): 3183, Minority (label 0): 480
# Number of 'good' native counterfactuals in data: 1133
# Data distribution after iteration 130:
# 	Majority (1): 3183, Minority (label 0): 481
# Number of 'good' native counterfactuals in data: 1133
# Data distribution after iteration 131:
# 	Majority (1): 3183, Minority (label 0): 482
# Number of 'good' native counterfactuals in data: 1133
# Data distribution after iteration 132:
# 	Majority (1): 3183, Minority (label 0): 483
# Number of 'good' native counterfactuals in data: 1133
# Data distribution after iteration 133:
# 	Majority (1): 3183, Minority (label 0): 484
# Number of 'good' native counterfactuals in data: 1133
# Data distribution after iteration 134:
# 	Majority (1): 3183, Minority (label 0): 485
# Number of 'good' native counterfactuals in data: 1133
# Data distribution after iteration 135:
# 	Majority (1): 3183, Minority (label 0): 486
# Number of 'good' native counterfactuals in data: 1133
# Data distribution after iteration 136:
# 	Majority (1): 3183, Minority (label 0): 487
# Number of 'good' native counterfactuals in data: 1133
# Data distribution after iteration 137:
# 	Majority (1): 3183, Minority (label 0): 488
# Number of 'good' native counterfactuals in data: 1133
# Data distribution after iteration 138:
# 	Majority (1): 3183, Minority (label 0): 489
# Number of 'good' native counterfactuals in data: 1133
# Data distribution after iteration 139:
# 	Majority (1): 3183, Minority (label 0): 490
# Number of 'good' native counterfactuals in data: 1133
# Data distribution after iteration 140:
# 	Majority (1): 3183, Minority (label 0): 491
# Number of 'good' native counterfactuals in data: 1133
# Data distribution after iteration 141:
# 	Majority (1): 3183, Minority (label 0): 492
# Number of 'good' native counterfactuals in data: 1133
# Data distribution after iteration 142:
# 	Majority (1): 3183, Minority (label 0): 493
# Number of 'good' native counterfactuals in data: 1133
# Data distribution after iteration 143:
# 	Majority (1): 3183, Minority (label 0): 494
# Number of 'good' native counterfactuals in data: 1133
# Data distribution after iteration 144:
# 	Majority (1): 3183, Minority (label 0): 495
# Number of 'good' native counterfactuals in data: 1133
# Data distribution after iteration 145:
# 	Majority (1): 3183, Minority (label 0): 496
# Number of 'good' native counterfactuals in data: 1133
# Data distribution after iteration 146:
# 	Majority (1): 3183, Minority (label 0): 497
# Number of 'good' native counterfactuals in data: 1133
# Data distribution after iteration 147:
# 	Majority (1): 3183, Minority (label 0): 498
# Number of 'good' native counterfactuals in data: 1133
# Data distribution after iteration 148:
# 	Majority (1): 3183, Minority (label 0): 499
# Number of 'good' native counterfactuals in data: 1133
# Data distribution after iteration 149:
# 	Majority (1): 3183, Minority (label 0): 500
# Number of 'good' native counterfactuals in data: 1133
# Data distribution after iteration 150:
# 	Majority (1): 3183, Minority (label 0): 501
# Number of 'good' native counterfactuals in data: 1133
# Data distribution after iteration 151:
# 	Majority (1): 3183, Minority (label 0): 502
# Number of 'good' native counterfactuals in data: 1133
# Data distribution after iteration 152:
# 	Majority (1): 3183, Minority (label 0): 503
# Number of 'good' native counterfactuals in data: 1133
# Data distribution after iteration 153:
# 	Majority (1): 3183, Minority (label 0): 504
# Number of 'good' native counterfactuals in data: 1133
# Data distribution after iteration 154:
# 	Majority (1): 3183, Minority (label 0): 505
# Number of 'good' native counterfactuals in data: 1133
# Data distribution after iteration 155:
# 	Majority (1): 3183, Minority (label 0): 506
# Number of 'good' native counterfactuals in data: 1133
# Data distribution after iteration 156:
# 	Majority (1): 3183, Minority (label 0): 507
# Number of 'good' native counterfactuals in data: 1133
# Data distribution after iteration 157:
# 	Majority (1): 3183, Minority (label 0): 508
# Number of 'good' native counterfactuals in data: 1133
# Data distribution after iteration 158:
# 	Majority (1): 3183, Minority (label 0): 509
# Number of 'good' native counterfactuals in data: 1129
# Data distribution after iteration 159:
# 	Majority (1): 3183, Minority (label 0): 510
# Number of 'good' native counterfactuals in data: 1129
# Data distribution after iteration 160:
# 	Majority (1): 3183, Minority (label 0): 511
# Number of 'good' native counterfactuals in data: 1129
# Data distribution after iteration 161:
# 	Majority (1): 3183, Minority (label 0): 512
# Number of 'good' native counterfactuals in data: 1129
# Data distribution after iteration 162:
# 	Majority (1): 3183, Minority (label 0): 513
# Number of 'good' native counterfactuals in data: 1129
# Data distribution after iteration 163:
# 	Majority (1): 3183, Minority (label 0): 514
# Number of 'good' native counterfactuals in data: 1129
# Data distribution after iteration 164:
# 	Majority (1): 3183, Minority (label 0): 515
# Number of 'good' native counterfactuals in data: 1129
# Data distribution after iteration 165:
# 	Majority (1): 3183, Minority (label 0): 516
# Number of 'good' native counterfactuals in data: 1129
# Data distribution after iteration 166:
# 	Majority (1): 3183, Minority (label 0): 517
# Number of 'good' native counterfactuals in data: 1124
# Data distribution after iteration 167:
# 	Majority (1): 3183, Minority (label 0): 518
# Number of 'good' native counterfactuals in data: 1124
# Data distribution after iteration 168:
# 	Majority (1): 3183, Minority (label 0): 519
# Number of 'good' native counterfactuals in data: 1124
# Data distribution after iteration 169:
# 	Majority (1): 3183, Minority (label 0): 520
# Number of 'good' native counterfactuals in data: 1124
# Data distribution after iteration 170:
# 	Majority (1): 3183, Minority (label 0): 521
# Number of 'good' native counterfactuals in data: 1124
# Data distribution after iteration 171:
# 	Majority (1): 3183, Minority (label 0): 522
# Number of 'good' native counterfactuals in data: 1124
# Data distribution after iteration 172:
# 	Majority (1): 3183, Minority (label 0): 523
# Number of 'good' native counterfactuals in data: 1124
# Data distribution after iteration 173:
# 	Majority (1): 3183, Minority (label 0): 524
# Number of 'good' native counterfactuals in data: 1124
# Data distribution after iteration 174:
# 	Majority (1): 3183, Minority (label 0): 525
# Number of 'good' native counterfactuals in data: 1124
# Data distribution after iteration 175:
# 	Majority (1): 3183, Minority (label 0): 526
# Number of 'good' native counterfactuals in data: 1124
# Data distribution after iteration 176:
# 	Majority (1): 3183, Minority (label 0): 527
# Number of 'good' native counterfactuals in data: 1124
# Data distribution after iteration 177:
# 	Majority (1): 3183, Minority (label 0): 528
# Number of 'good' native counterfactuals in data: 1124
# Data distribution after iteration 178:
# 	Majority (1): 3183, Minority (label 0): 529
# Number of 'good' native counterfactuals in data: 1124
# Data distribution after iteration 179:
# 	Majority (1): 3183, Minority (label 0): 530
# Number of 'good' native counterfactuals in data: 1124
# Data distribution after iteration 180:
# 	Majority (1): 3183, Minority (label 0): 531
# Number of 'good' native counterfactuals in data: 1124
# Data distribution after iteration 181:
# 	Majority (1): 3183, Minority (label 0): 532
# Number of 'good' native counterfactuals in data: 1124
# Data distribution after iteration 182:
# 	Majority (1): 3183, Minority (label 0): 533
# Number of 'good' native counterfactuals in data: 1124
# Data distribution after iteration 183:
# 	Majority (1): 3183, Minority (label 0): 534
# Number of 'good' native counterfactuals in data: 1124
# Data distribution after iteration 184:
# 	Majority (1): 3183, Minority (label 0): 535
# Number of 'good' native counterfactuals in data: 1124
# Data distribution after iteration 185:
# 	Majority (1): 3183, Minority (label 0): 536
# Number of 'good' native counterfactuals in data: 1124
# Data distribution after iteration 186:
# 	Majority (1): 3183, Minority (label 0): 537
# Number of 'good' native counterfactuals in data: 1124
# Data distribution after iteration 187:
# 	Majority (1): 3183, Minority (label 0): 538
# Number of 'good' native counterfactuals in data: 1124
# Data distribution after iteration 188:
# 	Majority (1): 3183, Minority (label 0): 539
# Number of 'good' native counterfactuals in data: 1124
# Data distribution after iteration 189:
# 	Majority (1): 3183, Minority (label 0): 540
# Number of 'good' native counterfactuals in data: 1124
# Data distribution after iteration 190:
# 	Majority (1): 3183, Minority (label 0): 541
# Number of 'good' native counterfactuals in data: 1124
# Data distribution after iteration 191:
# 	Majority (1): 3183, Minority (label 0): 542
# Number of 'good' native counterfactuals in data: 1124
# Data distribution after iteration 192:
# 	Majority (1): 3183, Minority (label 0): 543
# Number of 'good' native counterfactuals in data: 1124
# Data distribution after iteration 193:
# 	Majority (1): 3183, Minority (label 0): 544
# Number of 'good' native counterfactuals in data: 1124
# Data distribution after iteration 194:
# 	Majority (1): 3183, Minority (label 0): 545
# Number of 'good' native counterfactuals in data: 1124
# Data distribution after iteration 195:
# 	Majority (1): 3183, Minority (label 0): 546
# Number of 'good' native counterfactuals in data: 1124
# Data distribution after iteration 196:
# 	Majority (1): 3183, Minority (label 0): 547
# Number of 'good' native counterfactuals in data: 1099
# Data distribution after iteration 197:
# 	Majority (1): 3183, Minority (label 0): 548
# Number of 'good' native counterfactuals in data: 1099
# Data distribution after iteration 198:
# 	Majority (1): 3183, Minority (label 0): 549
# Number of 'good' native counterfactuals in data: 1099
# Data distribution after iteration 199:
# 	Majority (1): 3183, Minority (label 0): 550
# Number of 'good' native counterfactuals in data: 1099
# Data distribution after iteration 200:
# 	Majority (1): 3183, Minority (label 0): 551
# Number of 'good' native counterfactuals in data: 1099
# Data distribution after iteration 201:
# 	Majority (1): 3183, Minority (label 0): 552
# Number of 'good' native counterfactuals in data: 1099
# Data distribution after iteration 202:
# 	Majority (1): 3183, Minority (label 0): 553
# Number of 'good' native counterfactuals in data: 1099
# Data distribution after iteration 203:
# 	Majority (1): 3183, Minority (label 0): 554
# Number of 'good' native counterfactuals in data: 1094
# Data distribution after iteration 204:
# 	Majority (1): 3183, Minority (label 0): 555
# Number of 'good' native counterfactuals in data: 1094
# Data distribution after iteration 205:
# 	Majority (1): 3183, Minority (label 0): 556
# Number of 'good' native counterfactuals in data: 1094
# Data distribution after iteration 206:
# 	Majority (1): 3183, Minority (label 0): 557
# Number of 'good' native counterfactuals in data: 1094
# Data distribution after iteration 207:
# 	Majority (1): 3183, Minority (label 0): 558
# Number of 'good' native counterfactuals in data: 1094
# Data distribution after iteration 208:
# 	Majority (1): 3183, Minority (label 0): 559
# Number of 'good' native counterfactuals in data: 1094
# Data distribution after iteration 209:
# 	Majority (1): 3183, Minority (label 0): 560
# Number of 'good' native counterfactuals in data: 1094
# Data distribution after iteration 210:
# 	Majority (1): 3183, Minority (label 0): 561
# Number of 'good' native counterfactuals in data: 1094
# Data distribution after iteration 211:
# 	Majority (1): 3183, Minority (label 0): 562
# Number of 'good' native counterfactuals in data: 1094
# Data distribution after iteration 212:
# 	Majority (1): 3183, Minority (label 0): 563
# Number of 'good' native counterfactuals in data: 1094
# Data distribution after iteration 213:
# 	Majority (1): 3183, Minority (label 0): 564
# Number of 'good' native counterfactuals in data: 1094
# Data distribution after iteration 214:
# 	Majority (1): 3183, Minority (label 0): 565
# Number of 'good' native counterfactuals in data: 1094
# Data distribution after iteration 215:
# 	Majority (1): 3183, Minority (label 0): 566
# Number of 'good' native counterfactuals in data: 1094
# Data distribution after iteration 216:
# 	Majority (1): 3183, Minority (label 0): 567
# Number of 'good' native counterfactuals in data: 1094
# Data distribution after iteration 217:
# 	Majority (1): 3183, Minority (label 0): 568
# Number of 'good' native counterfactuals in data: 1094
# Data distribution after iteration 218:
# 	Majority (1): 3183, Minority (label 0): 569
# Number of 'good' native counterfactuals in data: 1094
# Data distribution after iteration 219:
# 	Majority (1): 3183, Minority (label 0): 570
# Number of 'good' native counterfactuals in data: 1094
# Data distribution after iteration 220:
# 	Majority (1): 3183, Minority (label 0): 571
# Number of 'good' native counterfactuals in data: 1094
# Data distribution after iteration 221:
# 	Majority (1): 3183, Minority (label 0): 572
# Number of 'good' native counterfactuals in data: 1094
# Data distribution after iteration 222:
# 	Majority (1): 3183, Minority (label 0): 573
# Number of 'good' native counterfactuals in data: 1094
# Data distribution after iteration 223:
# 	Majority (1): 3183, Minority (label 0): 574
# Number of 'good' native counterfactuals in data: 1094
# Data distribution after iteration 224:
# 	Majority (1): 3183, Minority (label 0): 575
# Number of 'good' native counterfactuals in data: 1093
# Data distribution after iteration 225:
# 	Majority (1): 3183, Minority (label 0): 576
# Number of 'good' native counterfactuals in data: 1093
# Data distribution after iteration 226:
# 	Majority (1): 3183, Minority (label 0): 577
# Number of 'good' native counterfactuals in data: 1093
# Data distribution after iteration 227:
# 	Majority (1): 3183, Minority (label 0): 578
# Number of 'good' native counterfactuals in data: 1093
# Data distribution after iteration 228:
# 	Majority (1): 3183, Minority (label 0): 579
# Number of 'good' native counterfactuals in data: 1093
# Data distribution after iteration 229:
# 	Majority (1): 3183, Minority (label 0): 580
# Number of 'good' native counterfactuals in data: 1093
# Data distribution after iteration 230:
# 	Majority (1): 3183, Minority (label 0): 581
# Number of 'good' native counterfactuals in data: 1093
# Data distribution after iteration 231:
# 	Majority (1): 3183, Minority (label 0): 582
# Number of 'good' native counterfactuals in data: 1093
# Data distribution after iteration 232:
# 	Majority (1): 3183, Minority (label 0): 583
# Number of 'good' native counterfactuals in data: 1093
# Data distribution after iteration 233:
# 	Majority (1): 3183, Minority (label 0): 584
# Number of 'good' native counterfactuals in data: 1093
# Data distribution after iteration 234:
# 	Majority (1): 3183, Minority (label 0): 585
# Number of 'good' native counterfactuals in data: 1093
# Data distribution after iteration 235:
# 	Majority (1): 3183, Minority (label 0): 586
# Number of 'good' native counterfactuals in data: 1093
# Data distribution after iteration 236:
# 	Majority (1): 3183, Minority (label 0): 587
# Number of 'good' native counterfactuals in data: 1093
# Data distribution after iteration 237:
# 	Majority (1): 3183, Minority (label 0): 588
# Number of 'good' native counterfactuals in data: 1093
# Data distribution after iteration 238:
# 	Majority (1): 3183, Minority (label 0): 589
# Number of 'good' native counterfactuals in data: 1093
# Data distribution after iteration 239:
# 	Majority (1): 3183, Minority (label 0): 590
# Number of 'good' native counterfactuals in data: 1093
# Data distribution after iteration 240:
# 	Majority (1): 3183, Minority (label 0): 591
# Number of 'good' native counterfactuals in data: 1093
# Data distribution after iteration 241:
# 	Majority (1): 3183, Minority (label 0): 592
# Number of 'good' native counterfactuals in data: 1093
# Data distribution after iteration 242:
# 	Majority (1): 3183, Minority (label 0): 593
# Number of 'good' native counterfactuals in data: 1093
# Data distribution after iteration 243:
# 	Majority (1): 3183, Minority (label 0): 594
# Number of 'good' native counterfactuals in data: 1093
# Data distribution after iteration 244:
# 	Majority (1): 3183, Minority (label 0): 595
# Number of 'good' native counterfactuals in data: 1093
# Data distribution after iteration 245:
# 	Majority (1): 3183, Minority (label 0): 596
# Number of 'good' native counterfactuals in data: 1093
# Data distribution after iteration 246:
# 	Majority (1): 3183, Minority (label 0): 597
# Number of 'good' native counterfactuals in data: 1092
# Data distribution after iteration 247:
# 	Majority (1): 3183, Minority (label 0): 598
# Number of 'good' native counterfactuals in data: 1092
# Data distribution after iteration 248:
# 	Majority (1): 3183, Minority (label 0): 599
# Number of 'good' native counterfactuals in data: 1092
# Data distribution after iteration 249:
# 	Majority (1): 3183, Minority (label 0): 600
# Number of 'good' native counterfactuals in data: 1092
# Data distribution after iteration 250:
# 	Majority (1): 3183, Minority (label 0): 601
# Number of 'good' native counterfactuals in data: 1092
# Data distribution after iteration 251:
# 	Majority (1): 3183, Minority (label 0): 602
# Number of 'good' native counterfactuals in data: 1087
# Data distribution after iteration 252:
# 	Majority (1): 3183, Minority (label 0): 603
# Number of 'good' native counterfactuals in data: 1087
# Data distribution after iteration 253:
# 	Majority (1): 3183, Minority (label 0): 604
# Number of 'good' native counterfactuals in data: 1086
# Data distribution after iteration 254:
# 	Majority (1): 3183, Minority (label 0): 605
# Number of 'good' native counterfactuals in data: 1089
# No unpaired instances found, no augmentation possible! Not applying CFA...
# ====================================================================
# Data distribution after CFA:
# 	Majority (1): 3183, Minority (label 0): 605
# Fold 1:
# Data distribution before CFA:
# 	Majority (1): 3185, Minority (label 0): 156
# Number of 'good' native counterfactuals in data: 1056
# Data distribution after iteration 0:
# 	Majority (1): 3185, Minority (label 0): 467
# Number of 'good' native counterfactuals in data: 1264
# Data distribution after iteration 1:
# 	Majority (1): 3185, Minority (label 0): 568
# Number of 'good' native counterfactuals in data: 1344
# Data distribution after iteration 2:
# 	Majority (1): 3185, Minority (label 0): 581
# Number of 'good' native counterfactuals in data: 1353
# Data distribution after iteration 3:
# 	Majority (1): 3185, Minority (label 0): 585
# Number of 'good' native counterfactuals in data: 1354
# Data distribution after iteration 4:
# 	Majority (1): 3185, Minority (label 0): 587
# Number of 'good' native counterfactuals in data: 1354
# Data distribution after iteration 5:
# 	Majority (1): 3185, Minority (label 0): 589
# Number of 'good' native counterfactuals in data: 1354
# Data distribution after iteration 6:
# 	Majority (1): 3185, Minority (label 0): 591
# Number of 'good' native counterfactuals in data: 1354
# Data distribution after iteration 7:
# 	Majority (1): 3185, Minority (label 0): 593
# Number of 'good' native counterfactuals in data: 1354
# Data distribution after iteration 8:
# 	Majority (1): 3185, Minority (label 0): 595
# Number of 'good' native counterfactuals in data: 1354
# Data distribution after iteration 9:
# 	Majority (1): 3185, Minority (label 0): 597
# Number of 'good' native counterfactuals in data: 1354
# Data distribution after iteration 10:
# 	Majority (1): 3185, Minority (label 0): 599
# Number of 'good' native counterfactuals in data: 1354
# Data distribution after iteration 11:
# 	Majority (1): 3185, Minority (label 0): 601
# Number of 'good' native counterfactuals in data: 1354
# Data distribution after iteration 12:
# 	Majority (1): 3185, Minority (label 0): 603
# Number of 'good' native counterfactuals in data: 1354
# Data distribution after iteration 13:
# 	Majority (1): 3185, Minority (label 0): 605
# Number of 'good' native counterfactuals in data: 1355
# Data distribution after iteration 14:
# 	Majority (1): 3185, Minority (label 0): 607
# Number of 'good' native counterfactuals in data: 1355
# Data distribution after iteration 15:
# 	Majority (1): 3185, Minority (label 0): 609
# Number of 'good' native counterfactuals in data: 1355
# Data distribution after iteration 16:
# 	Majority (1): 3185, Minority (label 0): 611
# Number of 'good' native counterfactuals in data: 1355
# Data distribution after iteration 17:
# 	Majority (1): 3185, Minority (label 0): 613
# Number of 'good' native counterfactuals in data: 1355
# Data distribution after iteration 18:
# 	Majority (1): 3185, Minority (label 0): 615
# Number of 'good' native counterfactuals in data: 1355
# Data distribution after iteration 19:
# 	Majority (1): 3185, Minority (label 0): 617
# Number of 'good' native counterfactuals in data: 1355
# Data distribution after iteration 20:
# 	Majority (1): 3185, Minority (label 0): 619
# Number of 'good' native counterfactuals in data: 1355
# Data distribution after iteration 21:
# 	Majority (1): 3185, Minority (label 0): 621
# Number of 'good' native counterfactuals in data: 1355
# Data distribution after iteration 22:
# 	Majority (1): 3185, Minority (label 0): 623
# Number of 'good' native counterfactuals in data: 1355
# Data distribution after iteration 23:
# 	Majority (1): 3185, Minority (label 0): 625
# Number of 'good' native counterfactuals in data: 1355
# Data distribution after iteration 24:
# 	Majority (1): 3185, Minority (label 0): 627
# Number of 'good' native counterfactuals in data: 1355
# Data distribution after iteration 25:
# 	Majority (1): 3185, Minority (label 0): 629
# Number of 'good' native counterfactuals in data: 1355
# Data distribution after iteration 26:
# 	Majority (1): 3185, Minority (label 0): 631
# Number of 'good' native counterfactuals in data: 1355
# Data distribution after iteration 27:
# 	Majority (1): 3185, Minority (label 0): 633
# Number of 'good' native counterfactuals in data: 1355
# Data distribution after iteration 28:
# 	Majority (1): 3185, Minority (label 0): 635
# Number of 'good' native counterfactuals in data: 1355
# Data distribution after iteration 29:
# 	Majority (1): 3185, Minority (label 0): 637
# Number of 'good' native counterfactuals in data: 1355
# Data distribution after iteration 30:
# 	Majority (1): 3185, Minority (label 0): 639
# Number of 'good' native counterfactuals in data: 1355
# Data distribution after iteration 31:
# 	Majority (1): 3185, Minority (label 0): 641
# Number of 'good' native counterfactuals in data: 1355
# Data distribution after iteration 32:
# 	Majority (1): 3185, Minority (label 0): 643
# Number of 'good' native counterfactuals in data: 1355
# Data distribution after iteration 33:
# 	Majority (1): 3185, Minority (label 0): 645
# Number of 'good' native counterfactuals in data: 1355
# Data distribution after iteration 34:
# 	Majority (1): 3185, Minority (label 0): 647
# Number of 'good' native counterfactuals in data: 1355
# Data distribution after iteration 35:
# 	Majority (1): 3185, Minority (label 0): 649
# Number of 'good' native counterfactuals in data: 1355
# Data distribution after iteration 36:
# 	Majority (1): 3185, Minority (label 0): 651
# Number of 'good' native counterfactuals in data: 1355
# Data distribution after iteration 37:
# 	Majority (1): 3185, Minority (label 0): 653
# Number of 'good' native counterfactuals in data: 1355
# Data distribution after iteration 38:
# 	Majority (1): 3185, Minority (label 0): 655
# Number of 'good' native counterfactuals in data: 1355
# Data distribution after iteration 39:
# 	Majority (1): 3185, Minority (label 0): 657
# Number of 'good' native counterfactuals in data: 1355
# Data distribution after iteration 40:
# 	Majority (1): 3185, Minority (label 0): 659
# Number of 'good' native counterfactuals in data: 1355
# Data distribution after iteration 41:
# 	Majority (1): 3185, Minority (label 0): 661
# Number of 'good' native counterfactuals in data: 1355
# Data distribution after iteration 42:
# 	Majority (1): 3185, Minority (label 0): 663
# Number of 'good' native counterfactuals in data: 1355
# Data distribution after iteration 43:
# 	Majority (1): 3185, Minority (label 0): 665
# Number of 'good' native counterfactuals in data: 1355
# Data distribution after iteration 44:
# 	Majority (1): 3185, Minority (label 0): 667
# Number of 'good' native counterfactuals in data: 1355
# Data distribution after iteration 45:
# 	Majority (1): 3185, Minority (label 0): 669
# Number of 'good' native counterfactuals in data: 1355
# Data distribution after iteration 46:
# 	Majority (1): 3185, Minority (label 0): 671
# Number of 'good' native counterfactuals in data: 1355
# Data distribution after iteration 47:
# 	Majority (1): 3185, Minority (label 0): 673
# Number of 'good' native counterfactuals in data: 1355
# Data distribution after iteration 48:
# 	Majority (1): 3185, Minority (label 0): 675
# Number of 'good' native counterfactuals in data: 1355
# Data distribution after iteration 49:
# 	Majority (1): 3185, Minority (label 0): 677
# Number of 'good' native counterfactuals in data: 1355
# Data distribution after iteration 50:
# 	Majority (1): 3185, Minority (label 0): 679
# Number of 'good' native counterfactuals in data: 1355
# Data distribution after iteration 51:
# 	Majority (1): 3185, Minority (label 0): 681
# Number of 'good' native counterfactuals in data: 1356
# Data distribution after iteration 52:
# 	Majority (1): 3185, Minority (label 0): 683
# Number of 'good' native counterfactuals in data: 1356
# Data distribution after iteration 53:
# 	Majority (1): 3185, Minority (label 0): 685
# Number of 'good' native counterfactuals in data: 1356
# Data distribution after iteration 54:
# 	Majority (1): 3185, Minority (label 0): 687
# Number of 'good' native counterfactuals in data: 1356
# Data distribution after iteration 55:
# 	Majority (1): 3185, Minority (label 0): 689
# Number of 'good' native counterfactuals in data: 1356
# Data distribution after iteration 56:
# 	Majority (1): 3185, Minority (label 0): 691
# Number of 'good' native counterfactuals in data: 1356
# Data distribution after iteration 57:
# 	Majority (1): 3185, Minority (label 0): 693
# Number of 'good' native counterfactuals in data: 1356
# Data distribution after iteration 58:
# 	Majority (1): 3185, Minority (label 0): 695
# Number of 'good' native counterfactuals in data: 1356
# Data distribution after iteration 59:
# 	Majority (1): 3185, Minority (label 0): 697
# Number of 'good' native counterfactuals in data: 1356
# Data distribution after iteration 60:
# 	Majority (1): 3185, Minority (label 0): 699
# Number of 'good' native counterfactuals in data: 1356
# Data distribution after iteration 61:
# 	Majority (1): 3185, Minority (label 0): 701
# Number of 'good' native counterfactuals in data: 1356
# Data distribution after iteration 62:
# 	Majority (1): 3185, Minority (label 0): 703
# Number of 'good' native counterfactuals in data: 1356
# Data distribution after iteration 63:
# 	Majority (1): 3185, Minority (label 0): 705
# Number of 'good' native counterfactuals in data: 1356
# Data distribution after iteration 64:
# 	Majority (1): 3185, Minority (label 0): 707
# Number of 'good' native counterfactuals in data: 1356
# Data distribution after iteration 65:
# 	Majority (1): 3185, Minority (label 0): 709
# Number of 'good' native counterfactuals in data: 1356
# Data distribution after iteration 66:
# 	Majority (1): 3185, Minority (label 0): 711
# Number of 'good' native counterfactuals in data: 1356
# Data distribution after iteration 67:
# 	Majority (1): 3185, Minority (label 0): 713
# Number of 'good' native counterfactuals in data: 1356
# Data distribution after iteration 68:
# 	Majority (1): 3185, Minority (label 0): 715
# Number of 'good' native counterfactuals in data: 1356
# Data distribution after iteration 69:
# 	Majority (1): 3185, Minority (label 0): 717
# Number of 'good' native counterfactuals in data: 1356
# Data distribution after iteration 70:
# 	Majority (1): 3185, Minority (label 0): 719
# Number of 'good' native counterfactuals in data: 1356
# Data distribution after iteration 71:
# 	Majority (1): 3185, Minority (label 0): 721
# Number of 'good' native counterfactuals in data: 1356
# Data distribution after iteration 72:
# 	Majority (1): 3185, Minority (label 0): 723
# Number of 'good' native counterfactuals in data: 1356
# Data distribution after iteration 73:
# 	Majority (1): 3185, Minority (label 0): 725
# Number of 'good' native counterfactuals in data: 1356
# Data distribution after iteration 74:
# 	Majority (1): 3185, Minority (label 0): 727
# Number of 'good' native counterfactuals in data: 1356
# Data distribution after iteration 75:
# 	Majority (1): 3185, Minority (label 0): 729
# Number of 'good' native counterfactuals in data: 1356
# Data distribution after iteration 76:
# 	Majority (1): 3185, Minority (label 0): 731
# Number of 'good' native counterfactuals in data: 1356
# Data distribution after iteration 77:
# 	Majority (1): 3185, Minority (label 0): 733
# Number of 'good' native counterfactuals in data: 1356
# Data distribution after iteration 78:
# 	Majority (1): 3185, Minority (label 0): 735
# Number of 'good' native counterfactuals in data: 1356
# Data distribution after iteration 79:
# 	Majority (1): 3185, Minority (label 0): 737
# Number of 'good' native counterfactuals in data: 1356
# Data distribution after iteration 80:
# 	Majority (1): 3185, Minority (label 0): 739
# Number of 'good' native counterfactuals in data: 1356
# Data distribution after iteration 81:
# 	Majority (1): 3185, Minority (label 0): 741
# Number of 'good' native counterfactuals in data: 1356
# Data distribution after iteration 82:
# 	Majority (1): 3185, Minority (label 0): 743
# Number of 'good' native counterfactuals in data: 1356
# Data distribution after iteration 83:
# 	Majority (1): 3185, Minority (label 0): 745
# Number of 'good' native counterfactuals in data: 1356
# Data distribution after iteration 84:
# 	Majority (1): 3185, Minority (label 0): 747
# Number of 'good' native counterfactuals in data: 1356
# Data distribution after iteration 85:
# 	Majority (1): 3185, Minority (label 0): 749
# Number of 'good' native counterfactuals in data: 1356
# Data distribution after iteration 86:
# 	Majority (1): 3185, Minority (label 0): 751
# Number of 'good' native counterfactuals in data: 1356
# Data distribution after iteration 87:
# 	Majority (1): 3185, Minority (label 0): 753
# Number of 'good' native counterfactuals in data: 1356
# Data distribution after iteration 88:
# 	Majority (1): 3185, Minority (label 0): 755
# Number of 'good' native counterfactuals in data: 1356
# Data distribution after iteration 89:
# 	Majority (1): 3185, Minority (label 0): 757
# Number of 'good' native counterfactuals in data: 1356
# Data distribution after iteration 90:
# 	Majority (1): 3185, Minority (label 0): 759
# ...
# 	Majority (1): 3173, Minority (label 0): 2994
# Number of 'good' native counterfactuals in data: 747
# Data distribution after iteration 844:
# 	Majority (1): 3173, Minority (label 0): 2997
# Number of 'good' native counterfactuals in data: 747
# Data distribution after iteration 845:
# 	Majority (1): 3173, Minority (label 0): 3000
# Number of 'good' native counterfactuals in data: 747
# Data distribution after iteration 846:
# 	Majority (1): 3173, Minority (label 0): 3003
# Number of 'good' native counterfactuals in data: 747
# Data distribution after iteration 847:
# 	Majority (1): 3173, Minority (label 0): 3006
# Number of 'good' native counterfactuals in data: 747
# Data distribution after iteration 848:
# 	Majority (1): 3173, Minority (label 0): 3009
# Number of 'good' native counterfactuals in data: 747
# Data distribution after iteration 849:
# 	Majority (1): 3173, Minority (label 0): 3012
# Number of 'good' native counterfactuals in data: 747
# Data distribution after iteration 850:
# 	Majority (1): 3173, Minority (label 0): 3015
# Number of 'good' native counterfactuals in data: 747
# Data distribution after iteration 851:
# 	Majority (1): 3173, Minority (label 0): 3018
# Number of 'good' native counterfactuals in data: 747
# Data distribution after iteration 852:
# 	Majority (1): 3173, Minority (label 0): 3021
# Number of 'good' native counterfactuals in data: 747
# Data distribution after iteration 853:
# 	Majority (1): 3173, Minority (label 0): 3024
# Number of 'good' native counterfactuals in data: 747
# Data distribution after iteration 854:
# 	Majority (1): 3173, Minority (label 0): 3027
# Number of 'good' native counterfactuals in data: 747
# Data distribution after iteration 855:
# 	Majority (1): 3173, Minority (label 0): 3030
# Number of 'good' native counterfactuals in data: 747
# Data distribution after iteration 856:
# 	Majority (1): 3173, Minority (label 0): 3033
# Number of 'good' native counterfactuals in data: 747
# Data distribution after iteration 857:
# 	Majority (1): 3173, Minority (label 0): 3036
# Number of 'good' native counterfactuals in data: 747
# Data distribution after iteration 858:
# 	Majority (1): 3173, Minority (label 0): 3039
# Number of 'good' native counterfactuals in data: 747
# Data distribution after iteration 859:
# 	Majority (1): 3173, Minority (label 0): 3042
# Number of 'good' native counterfactuals in data: 747
# Data distribution after iteration 860:
# 	Majority (1): 3173, Minority (label 0): 3045
# Number of 'good' native counterfactuals in data: 747
# Data distribution after iteration 861:
# 	Majority (1): 3173, Minority (label 0): 3048
# Number of 'good' native counterfactuals in data: 747
# Data distribution after iteration 862:
# 	Majority (1): 3173, Minority (label 0): 3051
# Number of 'good' native counterfactuals in data: 747
# Data distribution after iteration 863:
# 	Majority (1): 3173, Minority (label 0): 3054
# Number of 'good' native counterfactuals in data: 747
# Data distribution after iteration 864:
# 	Majority (1): 3173, Minority (label 0): 3057
# Number of 'good' native counterfactuals in data: 747
# Data distribution after iteration 865:
# 	Majority (1): 3173, Minority (label 0): 3060
# Number of 'good' native counterfactuals in data: 747
# Data distribution after iteration 866:
# 	Majority (1): 3173, Minority (label 0): 3063
# Number of 'good' native counterfactuals in data: 747
# Data distribution after iteration 867:
# 	Majority (1): 3173, Minority (label 0): 3066
# Number of 'good' native counterfactuals in data: 747
# Data distribution after iteration 868:
# 	Majority (1): 3173, Minority (label 0): 3069
# Number of 'good' native counterfactuals in data: 747
# Data distribution after iteration 869:
# 	Majority (1): 3173, Minority (label 0): 3072
# Number of 'good' native counterfactuals in data: 747
# Data distribution after iteration 870:
# 	Majority (1): 3173, Minority (label 0): 3075
# Number of 'good' native counterfactuals in data: 747
# Data distribution after iteration 871:
# 	Majority (1): 3173, Minority (label 0): 3078
# Number of 'good' native counterfactuals in data: 747
# Data distribution after iteration 872:
# 	Majority (1): 3173, Minority (label 0): 3081
# Number of 'good' native counterfactuals in data: 747
# Data distribution after iteration 873:
# 	Majority (1): 3173, Minority (label 0): 3084
# Number of 'good' native counterfactuals in data: 747
# Data distribution after iteration 874:
# 	Majority (1): 3173, Minority (label 0): 3087
# Number of 'good' native counterfactuals in data: 747
# Data distribution after iteration 875:
# 	Majority (1): 3173, Minority (label 0): 3090
# Number of 'good' native counterfactuals in data: 747
# Data distribution after iteration 876:
# 	Majority (1): 3173, Minority (label 0): 3093
# Number of 'good' native counterfactuals in data: 747
# Data distribution after iteration 877:
# 	Majority (1): 3173, Minority (label 0): 3096
# Number of 'good' native counterfactuals in data: 747
# Data distribution after iteration 878:
# 	Majority (1): 3173, Minority (label 0): 3099
# Number of 'good' native counterfactuals in data: 747
# Data distribution after iteration 879:
# 	Majority (1): 3173, Minority (label 0): 3102
# Number of 'good' native counterfactuals in data: 747
# Data distribution after iteration 880:
# 	Majority (1): 3173, Minority (label 0): 3105
# Number of 'good' native counterfactuals in data: 747
# Data distribution after iteration 881:
# 	Majority (1): 3173, Minority (label 0): 3108
# Number of 'good' native counterfactuals in data: 747
# Data distribution after iteration 882:
# 	Majority (1): 3173, Minority (label 0): 3111
# Number of 'good' native counterfactuals in data: 747
# Data distribution after iteration 883:
# 	Majority (1): 3173, Minority (label 0): 3114
# Number of 'good' native counterfactuals in data: 747
# Data distribution after iteration 884:
# 	Majority (1): 3173, Minority (label 0): 3117
# Number of 'good' native counterfactuals in data: 747
# Data distribution after iteration 885:
# 	Majority (1): 3173, Minority (label 0): 3120
# Number of 'good' native counterfactuals in data: 747
# Data distribution after iteration 886:
# 	Majority (1): 3173, Minority (label 0): 3123
# Number of 'good' native counterfactuals in data: 747
# Data distribution after iteration 887:
# 	Majority (1): 3173, Minority (label 0): 3126
# Number of 'good' native counterfactuals in data: 747
# Data distribution after iteration 888:
# 	Majority (1): 3173, Minority (label 0): 3129
# Number of 'good' native counterfactuals in data: 747
# Data distribution after iteration 889:
# 	Majority (1): 3173, Minority (label 0): 3132
# Number of 'good' native counterfactuals in data: 747
# Data distribution after iteration 890:
# 	Majority (1): 3173, Minority (label 0): 3135
# Number of 'good' native counterfactuals in data: 747
# Data distribution after iteration 891:
# 	Majority (1): 3173, Minority (label 0): 3138
# Number of 'good' native counterfactuals in data: 747
# Data distribution after iteration 892:
# 	Majority (1): 3173, Minority (label 0): 3141
# Number of 'good' native counterfactuals in data: 747
# Data distribution after iteration 893:
# 	Majority (1): 3173, Minority (label 0): 3144
# ====================================================================
# Data distribution after CFA:
# 	Majority (1): 3173, Minority (label 0): 3144
# Fold 3:
# Data distribution before CFA:
# 	Majority (1): 3172, Minority (label 0): 170
# Number of 'good' native counterfactuals in data: 1031
# Data distribution after iteration 0:
# 	Majority (1): 3172, Minority (label 0): 277
# Number of 'good' native counterfactuals in data: 1027
# Data distribution after iteration 1:
# 	Majority (1): 3172, Minority (label 0): 293
# Number of 'good' native counterfactuals in data: 1032
# Data distribution after iteration 2:
# 	Majority (1): 3172, Minority (label 0): 297
# Number of 'good' native counterfactuals in data: 1033
# Data distribution after iteration 3:
# 	Majority (1): 3172, Minority (label 0): 299
# Number of 'good' native counterfactuals in data: 1031
# Data distribution after iteration 4:
# 	Majority (1): 3172, Minority (label 0): 301
# Number of 'good' native counterfactuals in data: 1031
# Data distribution after iteration 5:
# 	Majority (1): 3172, Minority (label 0): 303
# Number of 'good' native counterfactuals in data: 1030
# Data distribution after iteration 6:
# 	Majority (1): 3172, Minority (label 0): 305
# Number of 'good' native counterfactuals in data: 1028
# Data distribution after iteration 7:
# 	Majority (1): 3172, Minority (label 0): 307
# Number of 'good' native counterfactuals in data: 1028
# Data distribution after iteration 8:
# 	Majority (1): 3172, Minority (label 0): 309
# Number of 'good' native counterfactuals in data: 1028
# Data distribution after iteration 9:
# 	Majority (1): 3172, Minority (label 0): 311
# Number of 'good' native counterfactuals in data: 1028
# Data distribution after iteration 10:
# 	Majority (1): 3172, Minority (label 0): 313
# Number of 'good' native counterfactuals in data: 1028
# Data distribution after iteration 11:
# 	Majority (1): 3172, Minority (label 0): 315
# Number of 'good' native counterfactuals in data: 1020
# Data distribution after iteration 12:
# 	Majority (1): 3172, Minority (label 0): 317
# Number of 'good' native counterfactuals in data: 1019
# Data distribution after iteration 13:
# 	Majority (1): 3172, Minority (label 0): 319
# Number of 'good' native counterfactuals in data: 1018
# Data distribution after iteration 14:
# 	Majority (1): 3172, Minority (label 0): 321
# Number of 'good' native counterfactuals in data: 1018
# Data distribution after iteration 15:
# 	Majority (1): 3172, Minority (label 0): 323
# Number of 'good' native counterfactuals in data: 1018
# Data distribution after iteration 16:
# 	Majority (1): 3172, Minority (label 0): 325
# Number of 'good' native counterfactuals in data: 1018
# Data distribution after iteration 17:
# 	Majority (1): 3172, Minority (label 0): 327
# Number of 'good' native counterfactuals in data: 1018
# Data distribution after iteration 18:
# 	Majority (1): 3172, Minority (label 0): 329
# Number of 'good' native counterfactuals in data: 1018
# Data distribution after iteration 19:
# 	Majority (1): 3172, Minority (label 0): 331
# Number of 'good' native counterfactuals in data: 1018
# Data distribution after iteration 20:
# 	Majority (1): 3172, Minority (label 0): 333
# Number of 'good' native counterfactuals in data: 1018
# Data distribution after iteration 21:
# 	Majority (1): 3172, Minority (label 0): 335
# Number of 'good' native counterfactuals in data: 1018
# Data distribution after iteration 22:
# 	Majority (1): 3172, Minority (label 0): 337
# Number of 'good' native counterfactuals in data: 1018
# Data distribution after iteration 23:
# 	Majority (1): 3172, Minority (label 0): 339
# Number of 'good' native counterfactuals in data: 1009
# Data distribution after iteration 24:
# 	Majority (1): 3172, Minority (label 0): 341
# Number of 'good' native counterfactuals in data: 1009
# Data distribution after iteration 25:
# 	Majority (1): 3172, Minority (label 0): 343
# Number of 'good' native counterfactuals in data: 1009
# Data distribution after iteration 26:
# 	Majority (1): 3172, Minority (label 0): 345
# Number of 'good' native counterfactuals in data: 1009
# Data distribution after iteration 27:
# 	Majority (1): 3172, Minority (label 0): 347
# Number of 'good' native counterfactuals in data: 1009
# Data distribution after iteration 28:
# 	Majority (1): 3172, Minority (label 0): 349
# Number of 'good' native counterfactuals in data: 1009
# Data distribution after iteration 29:
# 	Majority (1): 3172, Minority (label 0): 351
# Number of 'good' native counterfactuals in data: 1005
# Data distribution after iteration 30:
# 	Majority (1): 3172, Minority (label 0): 353
# Number of 'good' native counterfactuals in data: 1003
# Data distribution after iteration 31:
# 	Majority (1): 3172, Minority (label 0): 355
# Number of 'good' native counterfactuals in data: 1003
# Data distribution after iteration 32:
# 	Majority (1): 3172, Minority (label 0): 357
# Number of 'good' native counterfactuals in data: 1003
# Data distribution after iteration 33:
# 	Majority (1): 3172, Minority (label 0): 359
# Number of 'good' native counterfactuals in data: 1003
# Data distribution after iteration 34:
# 	Majority (1): 3172, Minority (label 0): 361
# Number of 'good' native counterfactuals in data: 1003
# Data distribution after iteration 35:
# 	Majority (1): 3172, Minority (label 0): 363
# Number of 'good' native counterfactuals in data: 997
# Data distribution after iteration 36:
# 	Majority (1): 3172, Minority (label 0): 365
# Number of 'good' native counterfactuals in data: 997
# Data distribution after iteration 37:
# 	Majority (1): 3172, Minority (label 0): 367
# Number of 'good' native counterfactuals in data: 997
# Data distribution after iteration 38:
# 	Majority (1): 3172, Minority (label 0): 369
# Number of 'good' native counterfactuals in data: 997
# Data distribution after iteration 39:
# 	Majority (1): 3172, Minority (label 0): 371
# Number of 'good' native counterfactuals in data: 997
# Data distribution after iteration 40:
# 	Majority (1): 3172, Minority (label 0): 373
# Number of 'good' native counterfactuals in data: 997
# Data distribution after iteration 41:
# 	Majority (1): 3172, Minority (label 0): 375
# Number of 'good' native counterfactuals in data: 997
# Data distribution after iteration 42:
# 	Majority (1): 3172, Minority (label 0): 377
# Number of 'good' native counterfactuals in data: 996
# Data distribution after iteration 43:
# 	Majority (1): 3172, Minority (label 0): 379
# Number of 'good' native counterfactuals in data: 996
# Data distribution after iteration 44:
# 	Majority (1): 3172, Minority (label 0): 381
# Number of 'good' native counterfactuals in data: 996
# Data distribution after iteration 45:
# 	Majority (1): 3172, Minority (label 0): 383
# Number of 'good' native counterfactuals in data: 995
# Data distribution after iteration 46:
# 	Majority (1): 3172, Minority (label 0): 385
# Number of 'good' native counterfactuals in data: 995
# Data distribution after iteration 47:
# 	Majority (1): 3172, Minority (label 0): 387
# Number of 'good' native counterfactuals in data: 995
# Data distribution after iteration 48:
# 	Majority (1): 3172, Minority (label 0): 389
# Number of 'good' native counterfactuals in data: 991
# Data distribution after iteration 49:
# 	Majority (1): 3172, Minority (label 0): 391
# Number of 'good' native counterfactuals in data: 991
# Data distribution after iteration 50:
# 	Majority (1): 3172, Minority (label 0): 393
# Number of 'good' native counterfactuals in data: 991
# Data distribution after iteration 51:
# 	Majority (1): 3172, Minority (label 0): 395
# Number of 'good' native counterfactuals in data: 990
# Data distribution after iteration 52:
# 	Majority (1): 3172, Minority (label 0): 397
# Number of 'good' native counterfactuals in data: 990
# Data distribution after iteration 53:
# 	Majority (1): 3172, Minority (label 0): 399
# Number of 'good' native counterfactuals in data: 990
# Data distribution after iteration 54:
# 	Majority (1): 3172, Minority (label 0): 401
# Number of 'good' native counterfactuals in data: 990
# Data distribution after iteration 55:
# 	Majority (1): 3172, Minority (label 0): 403
# Number of 'good' native counterfactuals in data: 989
# Data distribution after iteration 56:
# 	Majority (1): 3172, Minority (label 0): 404
# Number of 'good' native counterfactuals in data: 990
# No unpaired instances found, no augmentation possible! Not applying CFA...
# ====================================================================
# Data distribution after CFA:
# 	Majority (1): 3172, Minority (label 0): 404
# Fold 4:
# Data distribution before CFA:
# 	Majority (1): 3183, Minority (label 0): 159
# Number of 'good' native counterfactuals in data: 1015
# Data distribution after iteration 0:
# 	Majority (1): 3183, Minority (label 0): 279
# Number of 'good' native counterfactuals in data: 1076
# Data distribution after iteration 1:
# 	Majority (1): 3183, Minority (label 0): 292
# Number of 'good' native counterfactuals in data: 1080
# Data distribution after iteration 2:
# 	Majority (1): 3183, Minority (label 0): 293
# Number of 'good' native counterfactuals in data: 1079
# No unpaired instances found, no augmentation possible! Not applying CFA...
# ====================================================================
# Data distribution after CFA:
# 	Majority (1): 3183, Minority (label 0): 293

# %%
score_avg_over_folds = np.array(all_scores).mean(axis=0)
best_score_idx = score_avg_over_folds.argmax()
print(f"Best params: {combination_dicts[best_score_idx]}")
print(f"Best AUC: {score_avg_over_folds[best_score_idx]}")
# Out:
# Best params: {'max_depth': 10, 'n_estimators': 600}
# Best AUC: 0.7317163918516486

# %% [markdown]
# #### Approach 2: Verification of new synthetic counterfactuals with baseline model

# %%
all_scores = []

for i, (train_index, test_index) in enumerate(kf.split(X)):
    print(f"Fold {i}:")
    scores_for_fold = []
    X_train, X_test, y_train, y_test = X.iloc[train_index], X.iloc[test_index], y.iloc[train_index], y.iloc[test_index]
    
    print("Fitting baseline model needed for verification... ")
    baseline_search = GridSearchCV(RandomForestClassifier(random_state=19231823), rf_param_grid, scoring="roc_auc")
    baseline_search.fit(X_train, y_train)
    
    X_train_augmented, y_train_augmented = Iterative_CFA(X_train, 
                                                         y_train, 
                                                         stddev_percent=50, 
                                                         verify_with_baseline_model=True, 
                                                         baseline_model=baseline_search,
                                                         visualize_with_pca=False)
    
    for param_comb in combination_dicts:
        clf = RandomForestClassifier(random_state=19231823, **param_comb)
        clf.fit(X_train_augmented, y_train_augmented)
        current_score = roc_auc_score(y_test, clf.predict_proba(X_test)[:, 1])
        #print(f"Score for combination {param_comb}: {current_score}")
        scores_for_fold.append(current_score)
        
    all_scores.append(scores_for_fold)
# Out:
# Fold 0:
# Fitting baseline model needed for verification...
# Data distribution before CFA:
# 	Majority (1): 3183, Minority (label 0): 158
# Number of 'good' native counterfactuals in data: 1378
# Classifier predicted all new synthetic counterfactuals to be in the majority class! => No new minority instances => Terminating...
# ====================================================================
# Data distribution after CFA:
# 	Majority (1): 3183, Minority (label 0): 158
# Fold 1:
# Fitting baseline model needed for verification...
# Data distribution before CFA:
# 	Majority (1): 3185, Minority (label 0): 156
# Number of 'good' native counterfactuals in data: 1056
# Classifier predicted all new synthetic counterfactuals to be in the majority class! => No new minority instances => Terminating...
# ====================================================================
# Data distribution after CFA:
# 	Majority (1): 3185, Minority (label 0): 156
# Fold 2:
# Fitting baseline model needed for verification...
# Data distribution before CFA:
# 	Majority (1): 3173, Minority (label 0): 169
# Number of 'good' native counterfactuals in data: 1029
# Classifier predicted all new synthetic counterfactuals to be in the majority class! => No new minority instances => Terminating...
# ====================================================================
# Data distribution after CFA:
# 	Majority (1): 3173, Minority (label 0): 169
# Fold 3:
# Fitting baseline model needed for verification...
# Data distribution before CFA:
# 	Majority (1): 3172, Minority (label 0): 170
# Number of 'good' native counterfactuals in data: 1031
# Classifier predicted all new synthetic counterfactuals to be in the majority class! => No new minority instances => Terminating...
# ====================================================================
# Data distribution after CFA:
# 	Majority (1): 3172, Minority (label 0): 170
# Fold 4:
# Fitting baseline model needed for verification...
# Data distribution before CFA:
# 	Majority (1): 3183, Minority (label 0): 159
# Number of 'good' native counterfactuals in data: 1015
# Classifier predicted all new synthetic counterfactuals to be in the majority class! => No new minority instances => Terminating...
# ====================================================================
# Data distribution after CFA:
# 	Majority (1): 3183, Minority (label 0): 159

# %%
score_avg_over_folds = np.array(all_scores).mean(axis=0)
best_score_idx = score_avg_over_folds.argmax()
print(f"Best params: {combination_dicts[best_score_idx]}")
print(f"Best AUC: {score_avg_over_folds[best_score_idx]}")
# Out:
# Best params: {'max_depth': 6, 'n_estimators': 600}
# Best AUC: 0.7395650202089131

# %% [markdown]
# ### ADASYN instead of CFA

# %%
from imblearn.over_sampling import ADASYN
ada = ADASYN(random_state=9317231)

# %%
all_scores = []

for i, (train_index, test_index) in enumerate(kf.split(X)):
    #print(f"Fold {i}:")
    scores_for_fold = []
    X_train, X_test, y_train, y_test = X.iloc[train_index], X.iloc[test_index], y.iloc[train_index], y.iloc[test_index]
        
    X_train_resampled, y_train_resampled = ada.fit_resample(X_train, y_train)
        
    for param_comb in combination_dicts:
        clf = RandomForestClassifier(random_state=19231823, **param_comb)
        clf.fit(X_train_resampled, y_train_resampled)
        current_score = roc_auc_score(y_test, clf.predict_proba(X_test)[:, 1])
        #print(f"Score for combination {param_comb}: {current_score}")
        scores_for_fold.append(current_score)
        
    all_scores.append(scores_for_fold)

# %%
score_avg_over_folds = np.array(all_scores).mean(axis=0)
best_score_idx = score_avg_over_folds.argmax()
print(f"Best params: {combination_dicts[best_score_idx]}")
print(f"Best AUC: {score_avg_over_folds[best_score_idx]}")
# Out:
# Best params: {'max_depth': 10, 'n_estimators': 400}
# Best AUC: 0.7172285092627817

# %% [markdown]
# ### Random Oversampling

# %%
from imblearn.over_sampling import RandomOverSampler
ros = RandomOverSampler(random_state=52012318)

# %%
all_scores = []

for i, (train_index, test_index) in enumerate(kf.split(X)):
    #print(f"Fold {i}:")
    scores_for_fold = []
    X_train, X_test, y_train, y_test = X.iloc[train_index], X.iloc[test_index], y.iloc[train_index], y.iloc[test_index]
        
    X_train_resampled, y_train_resampled = ros.fit_resample(X_train, y_train)
        
    for param_comb in combination_dicts:
        clf = RandomForestClassifier(random_state=19231823, **param_comb)
        clf.fit(X_train_resampled, y_train_resampled)
        current_score = roc_auc_score(y_test, clf.predict_proba(X_test)[:, 1])
        #print(f"Score for combination {param_comb}: {current_score}")
        scores_for_fold.append(current_score)
        
    all_scores.append(scores_for_fold)

# %%
score_avg_over_folds = np.array(all_scores).mean(axis=0)
best_score_idx = score_avg_over_folds.argmax()
print(f"Best params: {combination_dicts[best_score_idx]}")
print(f"Best AUC: {score_avg_over_folds[best_score_idx]}")
# Out:
# Best params: {'max_depth': 6, 'n_estimators': 100}
# Best AUC: 0.7175582926156095

# %% [markdown]
# ## Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr_param_grid = {"max_iter": [100, 200, 1000], 
                 "C": [0.001, 0.01, 0.1, 1, 10, 100, 1000],
                 "solver": ["newton-cg", "lbfgs", "liblinear", "sag"]}

# compute all combinations of parameters
combination_dicts = list(ParameterGrid(lr_param_grid))

# %% [markdown]
# ### Baseline (no augmentation)

# %%
all_scores = []

for i, (train_index, test_index) in enumerate(kf.split(X)):
    #print(f"Fold {i}:")
    scores_for_fold = []
    X_train, X_test, y_train, y_test = X.iloc[train_index], X.iloc[test_index], y.iloc[train_index], y.iloc[test_index]
        
    for param_comb in combination_dicts:
        clf = LogisticRegression(random_state=19231823, **param_comb)
        clf.fit(X_train, y_train)
        current_score = roc_auc_score(y_test, clf.predict_proba(X_test)[:, 1])
        #print(f"Score for combination {param_comb}: {current_score}")
        scores_for_fold.append(current_score)
        
    all_scores.append(scores_for_fold)

# %%
score_avg_over_folds = np.array(all_scores).mean(axis=0)
best_score_idx = score_avg_over_folds.argmax()
print(f"Best params: {combination_dicts[best_score_idx]}")
print(f"Best AUC: {score_avg_over_folds[best_score_idx]}")
# Out:
# Best params: {'C': 10, 'max_iter': 100, 'solver': 'liblinear'}
# Best AUC: 0.7342425375116226

# %% [markdown]
# Again, we can compare to an out-of-the-box grid search to make sure:

# %%
baseline_search = GridSearchCV(LogisticRegression(random_state=19231823), lr_param_grid, scoring="roc_auc")
baseline_search.fit(X, y)
baseline_search.best_score_
# Out:
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# 0.7366341749344969

# %% [markdown]
# ### With CFA

# %% [markdown]
# #### Approach 1: No verification

# %%
all_scores = []

for i, (train_index, test_index) in enumerate(kf.split(X)):
    print(f"Fold {i}:")
    scores_for_fold = []
    X_train, X_test, y_train, y_test = X.iloc[train_index], X.iloc[test_index], y.iloc[train_index], y.iloc[test_index]
    
    X_train_augmented, y_train_augmented = Iterative_CFA(X_train, 
                                                         y_train, 
                                                         stddev_percent=50, 
                                                         verify_with_baseline_model=False, 
                                                         visualize_with_pca=False)

    for param_comb in combination_dicts:
        clf = LogisticRegression(random_state=19231823, **param_comb)
        clf.fit(X_train_augmented, y_train_augmented)
        current_score = roc_auc_score(y_test, clf.predict_proba(X_test)[:, 1])
        #print(f"Score for combination {param_comb}: {current_score}")
        scores_for_fold.append(current_score)
        
    all_scores.append(scores_for_fold)
# Out:
# Fold 0:
# Data distribution before CFA:
# 	Majority (1): 3183, Minority (label 0): 158
# Number of 'good' native counterfactuals in data: 1378
# Data distribution after iteration 0:
# 	Majority (1): 3183, Minority (label 0): 310
# Number of 'good' native counterfactuals in data: 1125
# Data distribution after iteration 1:
# 	Majority (1): 3183, Minority (label 0): 347
# Number of 'good' native counterfactuals in data: 1136
# Data distribution after iteration 2:
# 	Majority (1): 3183, Minority (label 0): 353
# Number of 'good' native counterfactuals in data: 1141
# Data distribution after iteration 3:
# 	Majority (1): 3183, Minority (label 0): 354
# Number of 'good' native counterfactuals in data: 1141
# Data distribution after iteration 4:
# 	Majority (1): 3183, Minority (label 0): 355
# Number of 'good' native counterfactuals in data: 1141
# Data distribution after iteration 5:
# 	Majority (1): 3183, Minority (label 0): 356
# Number of 'good' native counterfactuals in data: 1141
# Data distribution after iteration 6:
# 	Majority (1): 3183, Minority (label 0): 357
# Number of 'good' native counterfactuals in data: 1141
# Data distribution after iteration 7:
# 	Majority (1): 3183, Minority (label 0): 358
# Number of 'good' native counterfactuals in data: 1141
# Data distribution after iteration 8:
# 	Majority (1): 3183, Minority (label 0): 359
# Number of 'good' native counterfactuals in data: 1141
# Data distribution after iteration 9:
# 	Majority (1): 3183, Minority (label 0): 360
# Number of 'good' native counterfactuals in data: 1141
# Data distribution after iteration 10:
# 	Majority (1): 3183, Minority (label 0): 361
# Number of 'good' native counterfactuals in data: 1141
# Data distribution after iteration 11:
# 	Majority (1): 3183, Minority (label 0): 362
# Number of 'good' native counterfactuals in data: 1141
# Data distribution after iteration 12:
# 	Majority (1): 3183, Minority (label 0): 363
# Number of 'good' native counterfactuals in data: 1141
# Data distribution after iteration 13:
# 	Majority (1): 3183, Minority (label 0): 364
# Number of 'good' native counterfactuals in data: 1141
# Data distribution after iteration 14:
# 	Majority (1): 3183, Minority (label 0): 365
# Number of 'good' native counterfactuals in data: 1141
# Data distribution after iteration 15:
# 	Majority (1): 3183, Minority (label 0): 366
# Number of 'good' native counterfactuals in data: 1141
# Data distribution after iteration 16:
# 	Majority (1): 3183, Minority (label 0): 367
# Number of 'good' native counterfactuals in data: 1141
# Data distribution after iteration 17:
# 	Majority (1): 3183, Minority (label 0): 368
# Number of 'good' native counterfactuals in data: 1141
# Data distribution after iteration 18:
# 	Majority (1): 3183, Minority (label 0): 369
# Number of 'good' native counterfactuals in data: 1141
# Data distribution after iteration 19:
# 	Majority (1): 3183, Minority (label 0): 370
# Number of 'good' native counterfactuals in data: 1141
# Data distribution after iteration 20:
# 	Majority (1): 3183, Minority (label 0): 371
# Number of 'good' native counterfactuals in data: 1141
# Data distribution after iteration 21:
# 	Majority (1): 3183, Minority (label 0): 372
# Number of 'good' native counterfactuals in data: 1141
# Data distribution after iteration 22:
# 	Majority (1): 3183, Minority (label 0): 373
# Number of 'good' native counterfactuals in data: 1141
# Data distribution after iteration 23:
# 	Majority (1): 3183, Minority (label 0): 374
# Number of 'good' native counterfactuals in data: 1141
# Data distribution after iteration 24:
# 	Majority (1): 3183, Minority (label 0): 375
# Number of 'good' native counterfactuals in data: 1141
# Data distribution after iteration 25:
# 	Majority (1): 3183, Minority (label 0): 376
# Number of 'good' native counterfactuals in data: 1140
# Data distribution after iteration 26:
# 	Majority (1): 3183, Minority (label 0): 377
# Number of 'good' native counterfactuals in data: 1140
# Data distribution after iteration 27:
# 	Majority (1): 3183, Minority (label 0): 378
# Number of 'good' native counterfactuals in data: 1140
# Data distribution after iteration 28:
# 	Majority (1): 3183, Minority (label 0): 379
# Number of 'good' native counterfactuals in data: 1140
# Data distribution after iteration 29:
# 	Majority (1): 3183, Minority (label 0): 380
# Number of 'good' native counterfactuals in data: 1140
# Data distribution after iteration 30:
# 	Majority (1): 3183, Minority (label 0): 381
# Number of 'good' native counterfactuals in data: 1140
# Data distribution after iteration 31:
# 	Majority (1): 3183, Minority (label 0): 382
# Number of 'good' native counterfactuals in data: 1140
# Data distribution after iteration 32:
# 	Majority (1): 3183, Minority (label 0): 383
# Number of 'good' native counterfactuals in data: 1140
# Data distribution after iteration 33:
# 	Majority (1): 3183, Minority (label 0): 384
# Number of 'good' native counterfactuals in data: 1140
# Data distribution after iteration 34:
# 	Majority (1): 3183, Minority (label 0): 385
# Number of 'good' native counterfactuals in data: 1140
# Data distribution after iteration 35:
# 	Majority (1): 3183, Minority (label 0): 386
# Number of 'good' native counterfactuals in data: 1140
# Data distribution after iteration 36:
# 	Majority (1): 3183, Minority (label 0): 387
# Number of 'good' native counterfactuals in data: 1140
# Data distribution after iteration 37:
# 	Majority (1): 3183, Minority (label 0): 388
# Number of 'good' native counterfactuals in data: 1140
# Data distribution after iteration 38:
# 	Majority (1): 3183, Minority (label 0): 389
# Number of 'good' native counterfactuals in data: 1140
# Data distribution after iteration 39:
# 	Majority (1): 3183, Minority (label 0): 390
# Number of 'good' native counterfactuals in data: 1140
# Data distribution after iteration 40:
# 	Majority (1): 3183, Minority (label 0): 391
# Number of 'good' native counterfactuals in data: 1140
# Data distribution after iteration 41:
# 	Majority (1): 3183, Minority (label 0): 392
# Number of 'good' native counterfactuals in data: 1137
# Data distribution after iteration 42:
# 	Majority (1): 3183, Minority (label 0): 393
# Number of 'good' native counterfactuals in data: 1137
# Data distribution after iteration 43:
# 	Majority (1): 3183, Minority (label 0): 394
# Number of 'good' native counterfactuals in data: 1137
# Data distribution after iteration 44:
# 	Majority (1): 3183, Minority (label 0): 395
# Number of 'good' native counterfactuals in data: 1137
# Data distribution after iteration 45:
# 	Majority (1): 3183, Minority (label 0): 396
# Number of 'good' native counterfactuals in data: 1137
# Data distribution after iteration 46:
# 	Majority (1): 3183, Minority (label 0): 397
# Number of 'good' native counterfactuals in data: 1137
# Data distribution after iteration 47:
# 	Majority (1): 3183, Minority (label 0): 398
# Number of 'good' native counterfactuals in data: 1137
# Data distribution after iteration 48:
# 	Majority (1): 3183, Minority (label 0): 399
# Number of 'good' native counterfactuals in data: 1137
# Data distribution after iteration 49:
# 	Majority (1): 3183, Minority (label 0): 400
# Number of 'good' native counterfactuals in data: 1137
# Data distribution after iteration 50:
# 	Majority (1): 3183, Minority (label 0): 401
# Number of 'good' native counterfactuals in data: 1137
# Data distribution after iteration 51:
# 	Majority (1): 3183, Minority (label 0): 402
# Number of 'good' native counterfactuals in data: 1137
# Data distribution after iteration 52:
# 	Majority (1): 3183, Minority (label 0): 403
# Number of 'good' native counterfactuals in data: 1137
# Data distribution after iteration 53:
# 	Majority (1): 3183, Minority (label 0): 404
# Number of 'good' native counterfactuals in data: 1137
# Data distribution after iteration 54:
# 	Majority (1): 3183, Minority (label 0): 405
# Number of 'good' native counterfactuals in data: 1137
# Data distribution after iteration 55:
# 	Majority (1): 3183, Minority (label 0): 406
# Number of 'good' native counterfactuals in data: 1137
# Data distribution after iteration 56:
# 	Majority (1): 3183, Minority (label 0): 407
# Number of 'good' native counterfactuals in data: 1137
# Data distribution after iteration 57:
# 	Majority (1): 3183, Minority (label 0): 408
# Number of 'good' native counterfactuals in data: 1137
# Data distribution after iteration 58:
# 	Majority (1): 3183, Minority (label 0): 409
# Number of 'good' native counterfactuals in data: 1137
# Data distribution after iteration 59:
# 	Majority (1): 3183, Minority (label 0): 410
# Number of 'good' native counterfactuals in data: 1137
# Data distribution after iteration 60:
# 	Majority (1): 3183, Minority (label 0): 411
# Number of 'good' native counterfactuals in data: 1137
# Data distribution after iteration 61:
# 	Majority (1): 3183, Minority (label 0): 412
# Number of 'good' native counterfactuals in data: 1137
# Data distribution after iteration 62:
# 	Majority (1): 3183, Minority (label 0): 413
# Number of 'good' native counterfactuals in data: 1137
# Data distribution after iteration 63:
# 	Majority (1): 3183, Minority (label 0): 414
# Number of 'good' native counterfactuals in data: 1137
# Data distribution after iteration 64:
# 	Majority (1): 3183, Minority (label 0): 415
# Number of 'good' native counterfactuals in data: 1137
# Data distribution after iteration 65:
# 	Majority (1): 3183, Minority (label 0): 416
# Number of 'good' native counterfactuals in data: 1137
# Data distribution after iteration 66:
# 	Majority (1): 3183, Minority (label 0): 417
# Number of 'good' native counterfactuals in data: 1137
# Data distribution after iteration 67:
# 	Majority (1): 3183, Minority (label 0): 418
# Number of 'good' native counterfactuals in data: 1137
# Data distribution after iteration 68:
# 	Majority (1): 3183, Minority (label 0): 419
# Number of 'good' native counterfactuals in data: 1137
# Data distribution after iteration 69:
# 	Majority (1): 3183, Minority (label 0): 420
# Number of 'good' native counterfactuals in data: 1137
# Data distribution after iteration 70:
# 	Majority (1): 3183, Minority (label 0): 421
# Number of 'good' native counterfactuals in data: 1137
# Data distribution after iteration 71:
# 	Majority (1): 3183, Minority (label 0): 422
# Number of 'good' native counterfactuals in data: 1137
# Data distribution after iteration 72:
# 	Majority (1): 3183, Minority (label 0): 423
# Number of 'good' native counterfactuals in data: 1137
# Data distribution after iteration 73:
# 	Majority (1): 3183, Minority (label 0): 424
# Number of 'good' native counterfactuals in data: 1137
# Data distribution after iteration 74:
# 	Majority (1): 3183, Minority (label 0): 425
# Number of 'good' native counterfactuals in data: 1137
# Data distribution after iteration 75:
# 	Majority (1): 3183, Minority (label 0): 426
# Number of 'good' native counterfactuals in data: 1137
# Data distribution after iteration 76:
# 	Majority (1): 3183, Minority (label 0): 427
# Number of 'good' native counterfactuals in data: 1137
# Data distribution after iteration 77:
# 	Majority (1): 3183, Minority (label 0): 428
# Number of 'good' native counterfactuals in data: 1137
# Data distribution after iteration 78:
# 	Majority (1): 3183, Minority (label 0): 429
# Number of 'good' native counterfactuals in data: 1137
# Data distribution after iteration 79:
# 	Majority (1): 3183, Minority (label 0): 430
# Number of 'good' native counterfactuals in data: 1137
# Data distribution after iteration 80:
# 	Majority (1): 3183, Minority (label 0): 431
# Number of 'good' native counterfactuals in data: 1137
# Data distribution after iteration 81:
# 	Majority (1): 3183, Minority (label 0): 432
# Number of 'good' native counterfactuals in data: 1137
# Data distribution after iteration 82:
# 	Majority (1): 3183, Minority (label 0): 433
# Number of 'good' native counterfactuals in data: 1137
# Data distribution after iteration 83:
# 	Majority (1): 3183, Minority (label 0): 434
# Number of 'good' native counterfactuals in data: 1137
# Data distribution after iteration 84:
# 	Majority (1): 3183, Minority (label 0): 435
# Number of 'good' native counterfactuals in data: 1137
# Data distribution after iteration 85:
# 	Majority (1): 3183, Minority (label 0): 436
# Number of 'good' native counterfactuals in data: 1137
# Data distribution after iteration 86:
# 	Majority (1): 3183, Minority (label 0): 437
# Number of 'good' native counterfactuals in data: 1137
# Data distribution after iteration 87:
# 	Majority (1): 3183, Minority (label 0): 438
# Number of 'good' native counterfactuals in data: 1136
# Data distribution after iteration 88:
# 	Majority (1): 3183, Minority (label 0): 439
# Number of 'good' native counterfactuals in data: 1136
# Data distribution after iteration 89:
# 	Majority (1): 3183, Minority (label 0): 440
# Number of 'good' native counterfactuals in data: 1136
# Data distribution after iteration 90:
# 	Majority (1): 3183, Minority (label 0): 441
# Number of 'good' native counterfactuals in data: 1136
# Data distribution after iteration 91:
# 	Majority (1): 3183, Minority (label 0): 442
# Number of 'good' native counterfactuals in data: 1136
# Data distribution after iteration 92:
# 	Majority (1): 3183, Minority (label 0): 443
# Number of 'good' native counterfactuals in data: 1136
# Data distribution after iteration 93:
# 	Majority (1): 3183, Minority (label 0): 444
# Number of 'good' native counterfactuals in data: 1136
# Data distribution after iteration 94:
# 	Majority (1): 3183, Minority (label 0): 445
# Number of 'good' native counterfactuals in data: 1136
# Data distribution after iteration 95:
# 	Majority (1): 3183, Minority (label 0): 446
# Number of 'good' native counterfactuals in data: 1136
# Data distribution after iteration 96:
# 	Majority (1): 3183, Minority (label 0): 447
# Number of 'good' native counterfactuals in data: 1136
# Data distribution after iteration 97:
# 	Majority (1): 3183, Minority (label 0): 448
# Number of 'good' native counterfactuals in data: 1136
# Data distribution after iteration 98:
# 	Majority (1): 3183, Minority (label 0): 449
# Number of 'good' native counterfactuals in data: 1136
# Data distribution after iteration 99:
# 	Majority (1): 3183, Minority (label 0): 450
# Number of 'good' native counterfactuals in data: 1136
# Data distribution after iteration 100:
# 	Majority (1): 3183, Minority (label 0): 451
# Number of 'good' native counterfactuals in data: 1136
# Data distribution after iteration 101:
# 	Majority (1): 3183, Minority (label 0): 452
# Number of 'good' native counterfactuals in data: 1136
# Data distribution after iteration 102:
# 	Majority (1): 3183, Minority (label 0): 453
# Number of 'good' native counterfactuals in data: 1136
# Data distribution after iteration 103:
# 	Majority (1): 3183, Minority (label 0): 454
# Number of 'good' native counterfactuals in data: 1136
# Data distribution after iteration 104:
# 	Majority (1): 3183, Minority (label 0): 455
# Number of 'good' native counterfactuals in data: 1135
# Data distribution after iteration 105:
# 	Majority (1): 3183, Minority (label 0): 456
# Number of 'good' native counterfactuals in data: 1135
# Data distribution after iteration 106:
# 	Majority (1): 3183, Minority (label 0): 457
# Number of 'good' native counterfactuals in data: 1135
# Data distribution after iteration 107:
# 	Majority (1): 3183, Minority (label 0): 458
# Number of 'good' native counterfactuals in data: 1135
# Data distribution after iteration 108:
# 	Majority (1): 3183, Minority (label 0): 459
# Number of 'good' native counterfactuals in data: 1135
# Data distribution after iteration 109:
# 	Majority (1): 3183, Minority (label 0): 460
# Number of 'good' native counterfactuals in data: 1135
# Data distribution after iteration 110:
# 	Majority (1): 3183, Minority (label 0): 461
# Number of 'good' native counterfactuals in data: 1135
# Data distribution after iteration 111:
# 	Majority (1): 3183, Minority (label 0): 462
# Number of 'good' native counterfactuals in data: 1135
# Data distribution after iteration 112:
# 	Majority (1): 3183, Minority (label 0): 463
# Number of 'good' native counterfactuals in data: 1135
# Data distribution after iteration 113:
# 	Majority (1): 3183, Minority (label 0): 464
# Number of 'good' native counterfactuals in data: 1135
# Data distribution after iteration 114:
# 	Majority (1): 3183, Minority (label 0): 465
# Number of 'good' native counterfactuals in data: 1135
# Data distribution after iteration 115:
# 	Majority (1): 3183, Minority (label 0): 466
# Number of 'good' native counterfactuals in data: 1135
# Data distribution after iteration 116:
# 	Majority (1): 3183, Minority (label 0): 467
# Number of 'good' native counterfactuals in data: 1133
# Data distribution after iteration 117:
# 	Majority (1): 3183, Minority (label 0): 468
# Number of 'good' native counterfactuals in data: 1133
# Data distribution after iteration 118:
# 	Majority (1): 3183, Minority (label 0): 469
# Number of 'good' native counterfactuals in data: 1133
# Data distribution after iteration 119:
# 	Majority (1): 3183, Minority (label 0): 470
# Number of 'good' native counterfactuals in data: 1133
# Data distribution after iteration 120:
# 	Majority (1): 3183, Minority (label 0): 471
# Number of 'good' native counterfactuals in data: 1133
# Data distribution after iteration 121:
# 	Majority (1): 3183, Minority (label 0): 472
# Number of 'good' native counterfactuals in data: 1133
# Data distribution after iteration 122:
# 	Majority (1): 3183, Minority (label 0): 473
# Number of 'good' native counterfactuals in data: 1133
# Data distribution after iteration 123:
# 	Majority (1): 3183, Minority (label 0): 474
# Number of 'good' native counterfactuals in data: 1133
# Data distribution after iteration 124:
# 	Majority (1): 3183, Minority (label 0): 475
# Number of 'good' native counterfactuals in data: 1133
# Data distribution after iteration 125:
# 	Majority (1): 3183, Minority (label 0): 476
# Number of 'good' native counterfactuals in data: 1133
# Data distribution after iteration 126:
# 	Majority (1): 3183, Minority (label 0): 477
# Number of 'good' native counterfactuals in data: 1133
# Data distribution after iteration 127:
# 	Majority (1): 3183, Minority (label 0): 478
# Number of 'good' native counterfactuals in data: 1133
# Data distribution after iteration 128:
# 	Majority (1): 3183, Minority (label 0): 479
# Number of 'good' native counterfactuals in data: 1133
# Data distribution after iteration 129:
# 	Majority (1): 3183, Minority (label 0): 480
# Number of 'good' native counterfactuals in data: 1133
# Data distribution after iteration 130:
# 	Majority (1): 3183, Minority (label 0): 481
# Number of 'good' native counterfactuals in data: 1133
# Data distribution after iteration 131:
# 	Majority (1): 3183, Minority (label 0): 482
# Number of 'good' native counterfactuals in data: 1133
# Data distribution after iteration 132:
# 	Majority (1): 3183, Minority (label 0): 483
# Number of 'good' native counterfactuals in data: 1133
# Data distribution after iteration 133:
# 	Majority (1): 3183, Minority (label 0): 484
# Number of 'good' native counterfactuals in data: 1133
# Data distribution after iteration 134:
# 	Majority (1): 3183, Minority (label 0): 485
# Number of 'good' native counterfactuals in data: 1133
# Data distribution after iteration 135:
# 	Majority (1): 3183, Minority (label 0): 486
# Number of 'good' native counterfactuals in data: 1133
# Data distribution after iteration 136:
# 	Majority (1): 3183, Minority (label 0): 487
# Number of 'good' native counterfactuals in data: 1133
# Data distribution after iteration 137:
# 	Majority (1): 3183, Minority (label 0): 488
# Number of 'good' native counterfactuals in data: 1133
# Data distribution after iteration 138:
# 	Majority (1): 3183, Minority (label 0): 489
# Number of 'good' native counterfactuals in data: 1133
# Data distribution after iteration 139:
# 	Majority (1): 3183, Minority (label 0): 490
# Number of 'good' native counterfactuals in data: 1133
# Data distribution after iteration 140:
# 	Majority (1): 3183, Minority (label 0): 491
# Number of 'good' native counterfactuals in data: 1133
# Data distribution after iteration 141:
# 	Majority (1): 3183, Minority (label 0): 492
# Number of 'good' native counterfactuals in data: 1133
# Data distribution after iteration 142:
# 	Majority (1): 3183, Minority (label 0): 493
# Number of 'good' native counterfactuals in data: 1133
# Data distribution after iteration 143:
# 	Majority (1): 3183, Minority (label 0): 494
# Number of 'good' native counterfactuals in data: 1133
# Data distribution after iteration 144:
# 	Majority (1): 3183, Minority (label 0): 495
# Number of 'good' native counterfactuals in data: 1133
# Data distribution after iteration 145:
# 	Majority (1): 3183, Minority (label 0): 496
# Number of 'good' native counterfactuals in data: 1133
# Data distribution after iteration 146:
# 	Majority (1): 3183, Minority (label 0): 497
# Number of 'good' native counterfactuals in data: 1133
# Data distribution after iteration 147:
# 	Majority (1): 3183, Minority (label 0): 498
# Number of 'good' native counterfactuals in data: 1133
# Data distribution after iteration 148:
# 	Majority (1): 3183, Minority (label 0): 499
# Number of 'good' native counterfactuals in data: 1133
# Data distribution after iteration 149:
# 	Majority (1): 3183, Minority (label 0): 500
# Number of 'good' native counterfactuals in data: 1133
# Data distribution after iteration 150:
# 	Majority (1): 3183, Minority (label 0): 501
# Number of 'good' native counterfactuals in data: 1133
# Data distribution after iteration 151:
# 	Majority (1): 3183, Minority (label 0): 502
# Number of 'good' native counterfactuals in data: 1133
# Data distribution after iteration 152:
# 	Majority (1): 3183, Minority (label 0): 503
# Number of 'good' native counterfactuals in data: 1133
# Data distribution after iteration 153:
# 	Majority (1): 3183, Minority (label 0): 504
# Number of 'good' native counterfactuals in data: 1133
# Data distribution after iteration 154:
# 	Majority (1): 3183, Minority (label 0): 505
# Number of 'good' native counterfactuals in data: 1133
# Data distribution after iteration 155:
# 	Majority (1): 3183, Minority (label 0): 506
# Number of 'good' native counterfactuals in data: 1133
# Data distribution after iteration 156:
# 	Majority (1): 3183, Minority (label 0): 507
# Number of 'good' native counterfactuals in data: 1133
# Data distribution after iteration 157:
# 	Majority (1): 3183, Minority (label 0): 508
# Number of 'good' native counterfactuals in data: 1133
# Data distribution after iteration 158:
# 	Majority (1): 3183, Minority (label 0): 509
# Number of 'good' native counterfactuals in data: 1129
# Data distribution after iteration 159:
# 	Majority (1): 3183, Minority (label 0): 510
# Number of 'good' native counterfactuals in data: 1129
# Data distribution after iteration 160:
# 	Majority (1): 3183, Minority (label 0): 511
# Number of 'good' native counterfactuals in data: 1129
# Data distribution after iteration 161:
# 	Majority (1): 3183, Minority (label 0): 512
# Number of 'good' native counterfactuals in data: 1129
# Data distribution after iteration 162:
# 	Majority (1): 3183, Minority (label 0): 513
# Number of 'good' native counterfactuals in data: 1129
# Data distribution after iteration 163:
# 	Majority (1): 3183, Minority (label 0): 514
# Number of 'good' native counterfactuals in data: 1129
# Data distribution after iteration 164:
# 	Majority (1): 3183, Minority (label 0): 515
# Number of 'good' native counterfactuals in data: 1129
# Data distribution after iteration 165:
# 	Majority (1): 3183, Minority (label 0): 516
# Number of 'good' native counterfactuals in data: 1129
# Data distribution after iteration 166:
# 	Majority (1): 3183, Minority (label 0): 517
# Number of 'good' native counterfactuals in data: 1124
# Data distribution after iteration 167:
# 	Majority (1): 3183, Minority (label 0): 518
# Number of 'good' native counterfactuals in data: 1124
# Data distribution after iteration 168:
# 	Majority (1): 3183, Minority (label 0): 519
# Number of 'good' native counterfactuals in data: 1124
# Data distribution after iteration 169:
# 	Majority (1): 3183, Minority (label 0): 520
# Number of 'good' native counterfactuals in data: 1124
# Data distribution after iteration 170:
# 	Majority (1): 3183, Minority (label 0): 521
# Number of 'good' native counterfactuals in data: 1124
# Data distribution after iteration 171:
# 	Majority (1): 3183, Minority (label 0): 522
# Number of 'good' native counterfactuals in data: 1124
# Data distribution after iteration 172:
# 	Majority (1): 3183, Minority (label 0): 523
# Number of 'good' native counterfactuals in data: 1124
# Data distribution after iteration 173:
# 	Majority (1): 3183, Minority (label 0): 524
# Number of 'good' native counterfactuals in data: 1124
# Data distribution after iteration 174:
# 	Majority (1): 3183, Minority (label 0): 525
# Number of 'good' native counterfactuals in data: 1124
# Data distribution after iteration 175:
# 	Majority (1): 3183, Minority (label 0): 526
# Number of 'good' native counterfactuals in data: 1124
# Data distribution after iteration 176:
# 	Majority (1): 3183, Minority (label 0): 527
# Number of 'good' native counterfactuals in data: 1124
# Data distribution after iteration 177:
# 	Majority (1): 3183, Minority (label 0): 528
# Number of 'good' native counterfactuals in data: 1124
# Data distribution after iteration 178:
# 	Majority (1): 3183, Minority (label 0): 529
# Number of 'good' native counterfactuals in data: 1124
# Data distribution after iteration 179:
# 	Majority (1): 3183, Minority (label 0): 530
# Number of 'good' native counterfactuals in data: 1124
# Data distribution after iteration 180:
# 	Majority (1): 3183, Minority (label 0): 531
# Number of 'good' native counterfactuals in data: 1124
# Data distribution after iteration 181:
# 	Majority (1): 3183, Minority (label 0): 532
# Number of 'good' native counterfactuals in data: 1124
# Data distribution after iteration 182:
# 	Majority (1): 3183, Minority (label 0): 533
# Number of 'good' native counterfactuals in data: 1124
# Data distribution after iteration 183:
# 	Majority (1): 3183, Minority (label 0): 534
# Number of 'good' native counterfactuals in data: 1124
# Data distribution after iteration 184:
# 	Majority (1): 3183, Minority (label 0): 535
# Number of 'good' native counterfactuals in data: 1124
# Data distribution after iteration 185:
# 	Majority (1): 3183, Minority (label 0): 536
# Number of 'good' native counterfactuals in data: 1124
# Data distribution after iteration 186:
# 	Majority (1): 3183, Minority (label 0): 537
# Number of 'good' native counterfactuals in data: 1124
# Data distribution after iteration 187:
# 	Majority (1): 3183, Minority (label 0): 538
# Number of 'good' native counterfactuals in data: 1124
# Data distribution after iteration 188:
# 	Majority (1): 3183, Minority (label 0): 539
# Number of 'good' native counterfactuals in data: 1124
# Data distribution after iteration 189:
# 	Majority (1): 3183, Minority (label 0): 540
# Number of 'good' native counterfactuals in data: 1124
# Data distribution after iteration 190:
# 	Majority (1): 3183, Minority (label 0): 541
# Number of 'good' native counterfactuals in data: 1124
# Data distribution after iteration 191:
# 	Majority (1): 3183, Minority (label 0): 542
# Number of 'good' native counterfactuals in data: 1124
# Data distribution after iteration 192:
# 	Majority (1): 3183, Minority (label 0): 543
# Number of 'good' native counterfactuals in data: 1124
# Data distribution after iteration 193:
# 	Majority (1): 3183, Minority (label 0): 544
# Number of 'good' native counterfactuals in data: 1124
# Data distribution after iteration 194:
# 	Majority (1): 3183, Minority (label 0): 545
# Number of 'good' native counterfactuals in data: 1124
# Data distribution after iteration 195:
# 	Majority (1): 3183, Minority (label 0): 546
# Number of 'good' native counterfactuals in data: 1124
# Data distribution after iteration 196:
# 	Majority (1): 3183, Minority (label 0): 547
# Number of 'good' native counterfactuals in data: 1099
# Data distribution after iteration 197:
# 	Majority (1): 3183, Minority (label 0): 548
# Number of 'good' native counterfactuals in data: 1099
# Data distribution after iteration 198:
# 	Majority (1): 3183, Minority (label 0): 549
# Number of 'good' native counterfactuals in data: 1099
# Data distribution after iteration 199:
# 	Majority (1): 3183, Minority (label 0): 550
# Number of 'good' native counterfactuals in data: 1099
# Data distribution after iteration 200:
# 	Majority (1): 3183, Minority (label 0): 551
# Number of 'good' native counterfactuals in data: 1099
# Data distribution after iteration 201:
# 	Majority (1): 3183, Minority (label 0): 552
# Number of 'good' native counterfactuals in data: 1099
# Data distribution after iteration 202:
# 	Majority (1): 3183, Minority (label 0): 553
# Number of 'good' native counterfactuals in data: 1099
# Data distribution after iteration 203:
# 	Majority (1): 3183, Minority (label 0): 554
# Number of 'good' native counterfactuals in data: 1094
# Data distribution after iteration 204:
# 	Majority (1): 3183, Minority (label 0): 555
# Number of 'good' native counterfactuals in data: 1094
# Data distribution after iteration 205:
# 	Majority (1): 3183, Minority (label 0): 556
# Number of 'good' native counterfactuals in data: 1094
# Data distribution after iteration 206:
# 	Majority (1): 3183, Minority (label 0): 557
# Number of 'good' native counterfactuals in data: 1094
# Data distribution after iteration 207:
# 	Majority (1): 3183, Minority (label 0): 558
# Number of 'good' native counterfactuals in data: 1094
# Data distribution after iteration 208:
# 	Majority (1): 3183, Minority (label 0): 559
# Number of 'good' native counterfactuals in data: 1094
# Data distribution after iteration 209:
# 	Majority (1): 3183, Minority (label 0): 560
# Number of 'good' native counterfactuals in data: 1094
# Data distribution after iteration 210:
# 	Majority (1): 3183, Minority (label 0): 561
# Number of 'good' native counterfactuals in data: 1094
# Data distribution after iteration 211:
# 	Majority (1): 3183, Minority (label 0): 562
# Number of 'good' native counterfactuals in data: 1094
# Data distribution after iteration 212:
# 	Majority (1): 3183, Minority (label 0): 563
# Number of 'good' native counterfactuals in data: 1094
# Data distribution after iteration 213:
# 	Majority (1): 3183, Minority (label 0): 564
# Number of 'good' native counterfactuals in data: 1094
# Data distribution after iteration 214:
# 	Majority (1): 3183, Minority (label 0): 565
# Number of 'good' native counterfactuals in data: 1094
# Data distribution after iteration 215:
# 	Majority (1): 3183, Minority (label 0): 566
# Number of 'good' native counterfactuals in data: 1094
# Data distribution after iteration 216:
# 	Majority (1): 3183, Minority (label 0): 567
# Number of 'good' native counterfactuals in data: 1094
# Data distribution after iteration 217:
# 	Majority (1): 3183, Minority (label 0): 568
# Number of 'good' native counterfactuals in data: 1094
# Data distribution after iteration 218:
# 	Majority (1): 3183, Minority (label 0): 569
# Number of 'good' native counterfactuals in data: 1094
# Data distribution after iteration 219:
# 	Majority (1): 3183, Minority (label 0): 570
# Number of 'good' native counterfactuals in data: 1094
# Data distribution after iteration 220:
# 	Majority (1): 3183, Minority (label 0): 571
# Number of 'good' native counterfactuals in data: 1094
# Data distribution after iteration 221:
# 	Majority (1): 3183, Minority (label 0): 572
# Number of 'good' native counterfactuals in data: 1094
# Data distribution after iteration 222:
# 	Majority (1): 3183, Minority (label 0): 573
# Number of 'good' native counterfactuals in data: 1094
# Data distribution after iteration 223:
# 	Majority (1): 3183, Minority (label 0): 574
# Number of 'good' native counterfactuals in data: 1094
# Data distribution after iteration 224:
# 	Majority (1): 3183, Minority (label 0): 575
# Number of 'good' native counterfactuals in data: 1093
# Data distribution after iteration 225:
# 	Majority (1): 3183, Minority (label 0): 576
# Number of 'good' native counterfactuals in data: 1093
# Data distribution after iteration 226:
# 	Majority (1): 3183, Minority (label 0): 577
# Number of 'good' native counterfactuals in data: 1093
# Data distribution after iteration 227:
# 	Majority (1): 3183, Minority (label 0): 578
# Number of 'good' native counterfactuals in data: 1093
# Data distribution after iteration 228:
# 	Majority (1): 3183, Minority (label 0): 579
# Number of 'good' native counterfactuals in data: 1093
# Data distribution after iteration 229:
# 	Majority (1): 3183, Minority (label 0): 580
# Number of 'good' native counterfactuals in data: 1093
# Data distribution after iteration 230:
# 	Majority (1): 3183, Minority (label 0): 581
# Number of 'good' native counterfactuals in data: 1093
# Data distribution after iteration 231:
# 	Majority (1): 3183, Minority (label 0): 582
# Number of 'good' native counterfactuals in data: 1093
# Data distribution after iteration 232:
# 	Majority (1): 3183, Minority (label 0): 583
# Number of 'good' native counterfactuals in data: 1093
# Data distribution after iteration 233:
# 	Majority (1): 3183, Minority (label 0): 584
# Number of 'good' native counterfactuals in data: 1093
# Data distribution after iteration 234:
# 	Majority (1): 3183, Minority (label 0): 585
# Number of 'good' native counterfactuals in data: 1093
# Data distribution after iteration 235:
# 	Majority (1): 3183, Minority (label 0): 586
# Number of 'good' native counterfactuals in data: 1093
# Data distribution after iteration 236:
# 	Majority (1): 3183, Minority (label 0): 587
# Number of 'good' native counterfactuals in data: 1093
# Data distribution after iteration 237:
# 	Majority (1): 3183, Minority (label 0): 588
# Number of 'good' native counterfactuals in data: 1093
# Data distribution after iteration 238:
# 	Majority (1): 3183, Minority (label 0): 589
# Number of 'good' native counterfactuals in data: 1093
# Data distribution after iteration 239:
# 	Majority (1): 3183, Minority (label 0): 590
# Number of 'good' native counterfactuals in data: 1093
# Data distribution after iteration 240:
# 	Majority (1): 3183, Minority (label 0): 591
# Number of 'good' native counterfactuals in data: 1093
# Data distribution after iteration 241:
# 	Majority (1): 3183, Minority (label 0): 592
# Number of 'good' native counterfactuals in data: 1093
# Data distribution after iteration 242:
# 	Majority (1): 3183, Minority (label 0): 593
# Number of 'good' native counterfactuals in data: 1093
# Data distribution after iteration 243:
# 	Majority (1): 3183, Minority (label 0): 594
# Number of 'good' native counterfactuals in data: 1093
# Data distribution after iteration 244:
# 	Majority (1): 3183, Minority (label 0): 595
# Number of 'good' native counterfactuals in data: 1093
# Data distribution after iteration 245:
# 	Majority (1): 3183, Minority (label 0): 596
# Number of 'good' native counterfactuals in data: 1093
# Data distribution after iteration 246:
# 	Majority (1): 3183, Minority (label 0): 597
# Number of 'good' native counterfactuals in data: 1092
# Data distribution after iteration 247:
# 	Majority (1): 3183, Minority (label 0): 598
# Number of 'good' native counterfactuals in data: 1092
# Data distribution after iteration 248:
# 	Majority (1): 3183, Minority (label 0): 599
# Number of 'good' native counterfactuals in data: 1092
# Data distribution after iteration 249:
# 	Majority (1): 3183, Minority (label 0): 600
# Number of 'good' native counterfactuals in data: 1092
# Data distribution after iteration 250:
# 	Majority (1): 3183, Minority (label 0): 601
# Number of 'good' native counterfactuals in data: 1092
# Data distribution after iteration 251:
# 	Majority (1): 3183, Minority (label 0): 602
# Number of 'good' native counterfactuals in data: 1087
# Data distribution after iteration 252:
# 	Majority (1): 3183, Minority (label 0): 603
# Number of 'good' native counterfactuals in data: 1087
# Data distribution after iteration 253:
# 	Majority (1): 3183, Minority (label 0): 604
# Number of 'good' native counterfactuals in data: 1086
# Data distribution after iteration 254:
# 	Majority (1): 3183, Minority (label 0): 605
# Number of 'good' native counterfactuals in data: 1089
# No unpaired instances found, no augmentation possible! Not applying CFA...
# ====================================================================
# Data distribution after CFA:
# 	Majority (1): 3183, Minority (label 0): 605
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# Fold 1:
# Data distribution before CFA:
# 	Majority (1): 3185, Minority (label 0): 156
# Number of 'good' native counterfactuals in data: 1056
# Data distribution after iteration 0:
# 	Majority (1): 3185, Minority (label 0): 467
# Number of 'good' native counterfactuals in data: 1264
# Data distribution after iteration 1:
# 	Majority (1): 3185, Minority (label 0): 568
# Number of 'good' native counterfactuals in data: 1344
# Data distribution after iteration 2:
# 	Majority (1): 3185, Minority (label 0): 581
# Number of 'good' native counterfactuals in data: 1353
# Data distribution after iteration 3:
# 	Majority (1): 3185, Minority (label 0): 585
# Number of 'good' native counterfactuals in data: 1354
# Data distribution after iteration 4:
# 	Majority (1): 3185, Minority (label 0): 587
# Number of 'good' native counterfactuals in data: 1354
# Data distribution after iteration 5:
# 	Majority (1): 3185, Minority (label 0): 589
# Number of 'good' native counterfactuals in data: 1354
# Data distribution after iteration 6:
# 	Majority (1): 3185, Minority (label 0): 591
# Number of 'good' native counterfactuals in data: 1354
# Data distribution after iteration 7:
# 	Majority (1): 3185, Minority (label 0): 593
# Number of 'good' native counterfactuals in data: 1354
# Data distribution after iteration 8:
# 	Majority (1): 3185, Minority (label 0): 595
# Number of 'good' native counterfactuals in data: 1354
# Data distribution after iteration 9:
# 	Majority (1): 3185, Minority (label 0): 597
# Number of 'good' native counterfactuals in data: 1354
# Data distribution after iteration 10:
# 	Majority (1): 3185, Minority (label 0): 599
# Number of 'good' native counterfactuals in data: 1354
# Data distribution after iteration 11:
# 	Majority (1): 3185, Minority (label 0): 601
# Number of 'good' native counterfactuals in data: 1354
# Data distribution after iteration 12:
# 	Majority (1): 3185, Minority (label 0): 603
# Number of 'good' native counterfactuals in data: 1354
# Data distribution after iteration 13:
# 	Majority (1): 3185, Minority (label 0): 605
# Number of 'good' native counterfactuals in data: 1355
# Data distribution after iteration 14:
# 	Majority (1): 3185, Minority (label 0): 607
# Number of 'good' native counterfactuals in data: 1355
# Data distribution after iteration 15:
# 	Majority (1): 3185, Minority (label 0): 609
# Number of 'good' native counterfactuals in data: 1355
# Data distribution after iteration 16:
# 	Majority (1): 3185, Minority (label 0): 611
# Number of 'good' native counterfactuals in data: 1355
# Data distribution after iteration 17:
# 	Majority (1): 3185, Minority (label 0): 613
# Number of 'good' native counterfactuals in data: 1355
# Data distribution after iteration 18:
# 	Majority (1): 3185, Minority (label 0): 615
# Number of 'good' native counterfactuals in data: 1355
# Data distribution after iteration 19:
# 	Majority (1): 3185, Minority (label 0): 617
# Number of 'good' native counterfactuals in data: 1355
# Data distribution after iteration 20:
# 	Majority (1): 3185, Minority (label 0): 619
# Number of 'good' native counterfactuals in data: 1355
# Data distribution after iteration 21:
# 	Majority (1): 3185, Minority (label 0): 621
# Number of 'good' native counterfactuals in data: 1355
# Data distribution after iteration 22:
# 	Majority (1): 3185, Minority (label 0): 623
# Number of 'good' native counterfactuals in data: 1355
# Data distribution after iteration 23:
# 	Majority (1): 3185, Minority (label 0): 625
# Number of 'good' native counterfactuals in data: 1355
# Data distribution after iteration 24:
# 	Majority (1): 3185, Minority (label 0): 627
# Number of 'good' native counterfactuals in data: 1355
# Data distribution after iteration 25:
# 	Majority (1): 3185, Minority (label 0): 629
# Number of 'good' native counterfactuals in data: 1355
# Data distribution after iteration 26:
# 	Majority (1): 3185, Minority (label 0): 631
# Number of 'good' native counterfactuals in data: 1355
# Data distribution after iteration 27:
# 	Majority (1): 3185, Minority (label 0): 633
# Number of 'good' native counterfactuals in data: 1355
# Data distribution after iteration 28:
# 	Majority (1): 3185, Minority (label 0): 635
# Number of 'good' native counterfactuals in data: 1355
# Data distribution after iteration 29:
# 	Majority (1): 3185, Minority (label 0): 637
# Number of 'good' native counterfactuals in data: 1355
# Data distribution after iteration 30:
# 	Majority (1): 3185, Minority (label 0): 639
# Number of 'good' native counterfactuals in data: 1355
# Data distribution after iteration 31:
# 	Majority (1): 3185, Minority (label 0): 641
# Number of 'good' native counterfactuals in data: 1355
# Data distribution after iteration 32:
# 	Majority (1): 3185, Minority (label 0): 643
# Number of 'good' native counterfactuals in data: 1355
# Data distribution after iteration 33:
# 	Majority (1): 3185, Minority (label 0): 645
# Number of 'good' native counterfactuals in data: 1355
# Data distribution after iteration 34:
# 	Majority (1): 3185, Minority (label 0): 647
# Number of 'good' native counterfactuals in data: 1355
# Data distribution after iteration 35:
# 	Majority (1): 3185, Minority (label 0): 649
# Number of 'good' native counterfactuals in data: 1355
# Data distribution after iteration 36:
# 	Majority (1): 3185, Minority (label 0): 651
# Number of 'good' native counterfactuals in data: 1355
# Data distribution after iteration 37:
# 	Majority (1): 3185, Minority (label 0): 653
# Number of 'good' native counterfactuals in data: 1355
# Data distribution after iteration 38:
# 	Majority (1): 3185, Minority (label 0): 655
# Number of 'good' native counterfactuals in data: 1355
# Data distribution after iteration 39:
# 	Majority (1): 3185, Minority (label 0): 657
# Number of 'good' native counterfactuals in data: 1355
# Data distribution after iteration 40:
# 	Majority (1): 3185, Minority (label 0): 659
# Number of 'good' native counterfactuals in data: 1355
# Data distribution after iteration 41:
# 	Majority (1): 3185, Minority (label 0): 661
# Number of 'good' native counterfactuals in data: 1355
# Data distribution after iteration 42:
# 	Majority (1): 3185, Minority (label 0): 663
# Number of 'good' native counterfactuals in data: 1355
# Data distribution after iteration 43:
# 	Majority (1): 3185, Minority (label 0): 665
# Number of 'good' native counterfactuals in data: 1355
# Data distribution after iteration 44:
# 	Majority (1): 3185, Minority (label 0): 667
# Number of 'good' native counterfactuals in data: 1355
# Data distribution after iteration 45:
# 	Majority (1): 3185, Minority (label 0): 669
# Number of 'good' native counterfactuals in data: 1355
# Data distribution after iteration 46:
# 	Majority (1): 3185, Minority (label 0): 671
# Number of 'good' native counterfactuals in data: 1355
# Data distribution after iteration 47:
# 	Majority (1): 3185, Minority (label 0): 673
# Number of 'good' native counterfactuals in data: 1355
# Data distribution after iteration 48:
# 	Majority (1): 3185, Minority (label 0): 675
# Number of 'good' native counterfactuals in data: 1355
# Data distribution after iteration 49:
# 	Majority (1): 3185, Minority (label 0): 677
# Number of 'good' native counterfactuals in data: 1355
# Data distribution after iteration 50:
# 	Majority (1): 3185, Minority (label 0): 679
# Number of 'good' native counterfactuals in data: 1355
# Data distribution after iteration 51:
# 	Majority (1): 3185, Minority (label 0): 681
# Number of 'good' native counterfactuals in data: 1356
# Data distribution after iteration 52:
# 	Majority (1): 3185, Minority (label 0): 683
# Number of 'good' native counterfactuals in data: 1356
# Data distribution after iteration 53:
# 	Majority (1): 3185, Minority (label 0): 685
# Number of 'good' native counterfactuals in data: 1356
# Data distribution after iteration 54:
# 	Majority (1): 3185, Minority (label 0): 687
# Number of 'good' native counterfactuals in data: 1356
# Data distribution after iteration 55:
# 	Majority (1): 3185, Minority (label 0): 689
# Number of 'good' native counterfactuals in data: 1356
# Data distribution after iteration 56:
# 	Majority (1): 3185, Minority (label 0): 691
# Number of 'good' native counterfactuals in data: 1356
# Data distribution after iteration 57:
# 	Majority (1): 3185, Minority (label 0): 693
# Number of 'good' native counterfactuals in data: 1356
# Data distribution after iteration 58:
# 	Majority (1): 3185, Minority (label 0): 695
# Number of 'good' native counterfactuals in data: 1356
# Data distribution after iteration 59:
# 	Majority (1): 3185, Minority (label 0): 697
# Number of 'good' native counterfactuals in data: 1356
# Data distribution after iteration 60:
# 	Majority (1): 3185, Minority (label 0): 699
# Number of 'good' native counterfactuals in data: 1356
# Data distribution after iteration 61:
# 	Majority (1): 3185, Minority (label 0): 701
# Number of 'good' native counterfactuals in data: 1356
# Data distribution after iteration 62:
# 	Majority (1): 3185, Minority (label 0): 703
# Number of 'good' native counterfactuals in data: 1356
# Data distribution after iteration 63:
# 	Majority (1): 3185, Minority (label 0): 705
# Number of 'good' native counterfactuals in data: 1356
# Data distribution after iteration 64:
# 	Majority (1): 3185, Minority (label 0): 707
# Number of 'good' native counterfactuals in data: 1356
# Data distribution after iteration 65:
# 	Majority (1): 3185, Minority (label 0): 709
# Number of 'good' native counterfactuals in data: 1356
# Data distribution after iteration 66:
# 	Majority (1): 3185, Minority (label 0): 711
# Number of 'good' native counterfactuals in data: 1356
# Data distribution after iteration 67:
# 	Majority (1): 3185, Minority (label 0): 713
# Number of 'good' native counterfactuals in data: 1356
# Data distribution after iteration 68:
# 	Majority (1): 3185, Minority (label 0): 715
# Number of 'good' native counterfactuals in data: 1356
# Data distribution after iteration 69:
# 	Majority (1): 3185, Minority (label 0): 717
# Number of 'good' native counterfactuals in data: 1356
# Data distribution after iteration 70:
# 	Majority (1): 3185, Minority (label 0): 719
# Number of 'good' native counterfactuals in data: 1356
# Data distribution after iteration 71:
# 	Majority (1): 3185, Minority (label 0): 721
# Number of 'good' native counterfactuals in data: 1356
# Data distribution after iteration 72:
# 	Majority (1): 3185, Minority (label 0): 723
# Number of 'good' native counterfactuals in data: 1356
# Data distribution after iteration 73:
# 	Majority (1): 3185, Minority (label 0): 725
# Number of 'good' native counterfactuals in data: 1356
# Data distribution after iteration 74:
# 	Majority (1): 3185, Minority (label 0): 727
# Number of 'good' native counterfactuals in data: 1356
# Data distribution after iteration 75:
# 	Majority (1): 3185, Minority (label 0): 729
# Number of 'good' native counterfactuals in data: 1356
# Data distribution after iteration 76:
# ...
# 	Majority (1): 3173, Minority (label 0): 3135
# Number of 'good' native counterfactuals in data: 747
# Data distribution after iteration 891:
# 	Majority (1): 3173, Minority (label 0): 3138
# Number of 'good' native counterfactuals in data: 747
# Data distribution after iteration 892:
# 	Majority (1): 3173, Minority (label 0): 3141
# Number of 'good' native counterfactuals in data: 747
# Data distribution after iteration 893:
# 	Majority (1): 3173, Minority (label 0): 3144
# ====================================================================
# Data distribution after CFA:
# 	Majority (1): 3173, Minority (label 0): 3144
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# Fold 3:
# Data distribution before CFA:
# 	Majority (1): 3172, Minority (label 0): 170
# Number of 'good' native counterfactuals in data: 1031
# Data distribution after iteration 0:
# 	Majority (1): 3172, Minority (label 0): 277
# Number of 'good' native counterfactuals in data: 1027
# Data distribution after iteration 1:
# 	Majority (1): 3172, Minority (label 0): 293
# Number of 'good' native counterfactuals in data: 1032
# Data distribution after iteration 2:
# 	Majority (1): 3172, Minority (label 0): 297
# Number of 'good' native counterfactuals in data: 1033
# Data distribution after iteration 3:
# 	Majority (1): 3172, Minority (label 0): 299
# Number of 'good' native counterfactuals in data: 1031
# Data distribution after iteration 4:
# 	Majority (1): 3172, Minority (label 0): 301
# Number of 'good' native counterfactuals in data: 1031
# Data distribution after iteration 5:
# 	Majority (1): 3172, Minority (label 0): 303
# Number of 'good' native counterfactuals in data: 1030
# Data distribution after iteration 6:
# 	Majority (1): 3172, Minority (label 0): 305
# Number of 'good' native counterfactuals in data: 1028
# Data distribution after iteration 7:
# 	Majority (1): 3172, Minority (label 0): 307
# Number of 'good' native counterfactuals in data: 1028
# Data distribution after iteration 8:
# 	Majority (1): 3172, Minority (label 0): 309
# Number of 'good' native counterfactuals in data: 1028
# Data distribution after iteration 9:
# 	Majority (1): 3172, Minority (label 0): 311
# Number of 'good' native counterfactuals in data: 1028
# Data distribution after iteration 10:
# 	Majority (1): 3172, Minority (label 0): 313
# Number of 'good' native counterfactuals in data: 1028
# Data distribution after iteration 11:
# 	Majority (1): 3172, Minority (label 0): 315
# Number of 'good' native counterfactuals in data: 1020
# Data distribution after iteration 12:
# 	Majority (1): 3172, Minority (label 0): 317
# Number of 'good' native counterfactuals in data: 1019
# Data distribution after iteration 13:
# 	Majority (1): 3172, Minority (label 0): 319
# Number of 'good' native counterfactuals in data: 1018
# Data distribution after iteration 14:
# 	Majority (1): 3172, Minority (label 0): 321
# Number of 'good' native counterfactuals in data: 1018
# Data distribution after iteration 15:
# 	Majority (1): 3172, Minority (label 0): 323
# Number of 'good' native counterfactuals in data: 1018
# Data distribution after iteration 16:
# 	Majority (1): 3172, Minority (label 0): 325
# Number of 'good' native counterfactuals in data: 1018
# Data distribution after iteration 17:
# 	Majority (1): 3172, Minority (label 0): 327
# Number of 'good' native counterfactuals in data: 1018
# Data distribution after iteration 18:
# 	Majority (1): 3172, Minority (label 0): 329
# Number of 'good' native counterfactuals in data: 1018
# Data distribution after iteration 19:
# 	Majority (1): 3172, Minority (label 0): 331
# Number of 'good' native counterfactuals in data: 1018
# Data distribution after iteration 20:
# 	Majority (1): 3172, Minority (label 0): 333
# Number of 'good' native counterfactuals in data: 1018
# Data distribution after iteration 21:
# 	Majority (1): 3172, Minority (label 0): 335
# Number of 'good' native counterfactuals in data: 1018
# Data distribution after iteration 22:
# 	Majority (1): 3172, Minority (label 0): 337
# Number of 'good' native counterfactuals in data: 1018
# Data distribution after iteration 23:
# 	Majority (1): 3172, Minority (label 0): 339
# Number of 'good' native counterfactuals in data: 1009
# Data distribution after iteration 24:
# 	Majority (1): 3172, Minority (label 0): 341
# Number of 'good' native counterfactuals in data: 1009
# Data distribution after iteration 25:
# 	Majority (1): 3172, Minority (label 0): 343
# Number of 'good' native counterfactuals in data: 1009
# Data distribution after iteration 26:
# 	Majority (1): 3172, Minority (label 0): 345
# Number of 'good' native counterfactuals in data: 1009
# Data distribution after iteration 27:
# 	Majority (1): 3172, Minority (label 0): 347
# Number of 'good' native counterfactuals in data: 1009
# Data distribution after iteration 28:
# 	Majority (1): 3172, Minority (label 0): 349
# Number of 'good' native counterfactuals in data: 1009
# Data distribution after iteration 29:
# 	Majority (1): 3172, Minority (label 0): 351
# Number of 'good' native counterfactuals in data: 1005
# Data distribution after iteration 30:
# 	Majority (1): 3172, Minority (label 0): 353
# Number of 'good' native counterfactuals in data: 1003
# Data distribution after iteration 31:
# 	Majority (1): 3172, Minority (label 0): 355
# Number of 'good' native counterfactuals in data: 1003
# Data distribution after iteration 32:
# 	Majority (1): 3172, Minority (label 0): 357
# Number of 'good' native counterfactuals in data: 1003
# Data distribution after iteration 33:
# 	Majority (1): 3172, Minority (label 0): 359
# Number of 'good' native counterfactuals in data: 1003
# Data distribution after iteration 34:
# 	Majority (1): 3172, Minority (label 0): 361
# Number of 'good' native counterfactuals in data: 1003
# Data distribution after iteration 35:
# 	Majority (1): 3172, Minority (label 0): 363
# Number of 'good' native counterfactuals in data: 997
# Data distribution after iteration 36:
# 	Majority (1): 3172, Minority (label 0): 365
# Number of 'good' native counterfactuals in data: 997
# Data distribution after iteration 37:
# 	Majority (1): 3172, Minority (label 0): 367
# Number of 'good' native counterfactuals in data: 997
# Data distribution after iteration 38:
# 	Majority (1): 3172, Minority (label 0): 369
# Number of 'good' native counterfactuals in data: 997
# Data distribution after iteration 39:
# 	Majority (1): 3172, Minority (label 0): 371
# Number of 'good' native counterfactuals in data: 997
# Data distribution after iteration 40:
# 	Majority (1): 3172, Minority (label 0): 373
# Number of 'good' native counterfactuals in data: 997
# Data distribution after iteration 41:
# 	Majority (1): 3172, Minority (label 0): 375
# Number of 'good' native counterfactuals in data: 997
# Data distribution after iteration 42:
# 	Majority (1): 3172, Minority (label 0): 377
# Number of 'good' native counterfactuals in data: 996
# Data distribution after iteration 43:
# 	Majority (1): 3172, Minority (label 0): 379
# Number of 'good' native counterfactuals in data: 996
# Data distribution after iteration 44:
# 	Majority (1): 3172, Minority (label 0): 381
# Number of 'good' native counterfactuals in data: 996
# Data distribution after iteration 45:
# 	Majority (1): 3172, Minority (label 0): 383
# Number of 'good' native counterfactuals in data: 995
# Data distribution after iteration 46:
# 	Majority (1): 3172, Minority (label 0): 385
# Number of 'good' native counterfactuals in data: 995
# Data distribution after iteration 47:
# 	Majority (1): 3172, Minority (label 0): 387
# Number of 'good' native counterfactuals in data: 995
# Data distribution after iteration 48:
# 	Majority (1): 3172, Minority (label 0): 389
# Number of 'good' native counterfactuals in data: 991
# Data distribution after iteration 49:
# 	Majority (1): 3172, Minority (label 0): 391
# Number of 'good' native counterfactuals in data: 991
# Data distribution after iteration 50:
# 	Majority (1): 3172, Minority (label 0): 393
# Number of 'good' native counterfactuals in data: 991
# Data distribution after iteration 51:
# 	Majority (1): 3172, Minority (label 0): 395
# Number of 'good' native counterfactuals in data: 990
# Data distribution after iteration 52:
# 	Majority (1): 3172, Minority (label 0): 397
# Number of 'good' native counterfactuals in data: 990
# Data distribution after iteration 53:
# 	Majority (1): 3172, Minority (label 0): 399
# Number of 'good' native counterfactuals in data: 990
# Data distribution after iteration 54:
# 	Majority (1): 3172, Minority (label 0): 401
# Number of 'good' native counterfactuals in data: 990
# Data distribution after iteration 55:
# 	Majority (1): 3172, Minority (label 0): 403
# Number of 'good' native counterfactuals in data: 989
# Data distribution after iteration 56:
# 	Majority (1): 3172, Minority (label 0): 404
# Number of 'good' native counterfactuals in data: 990
# No unpaired instances found, no augmentation possible! Not applying CFA...
# ====================================================================
# Data distribution after CFA:
# 	Majority (1): 3172, Minority (label 0): 404
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# Fold 4:
# Data distribution before CFA:
# 	Majority (1): 3183, Minority (label 0): 159
# Number of 'good' native counterfactuals in data: 1015
# Data distribution after iteration 0:
# 	Majority (1): 3183, Minority (label 0): 279
# Number of 'good' native counterfactuals in data: 1076
# Data distribution after iteration 1:
# 	Majority (1): 3183, Minority (label 0): 292
# Number of 'good' native counterfactuals in data: 1080
# Data distribution after iteration 2:
# 	Majority (1): 3183, Minority (label 0): 293
# Number of 'good' native counterfactuals in data: 1079
# No unpaired instances found, no augmentation possible! Not applying CFA...
# ====================================================================
# Data distribution after CFA:
# 	Majority (1): 3183, Minority (label 0): 293
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(

# %%
score_avg_over_folds = np.array(all_scores).mean(axis=0)
best_score_idx = score_avg_over_folds.argmax()
print(f"Best params: {combination_dicts[best_score_idx]}")
print(f"Best AUC: {score_avg_over_folds[best_score_idx]}")
# Out:
# Best params: {'C': 1, 'max_iter': 100, 'solver': 'lbfgs'}
# Best AUC: 0.626377917754169

# %% [markdown]
# #### Approach 2: Verification of new synthetic counterfactuals with baseline model

# %%
all_scores = []

for i, (train_index, test_index) in enumerate(kf.split(X)):
    print(f"Fold {i}:")
    scores_for_fold = []
    X_train, X_test, y_train, y_test = X.iloc[train_index], X.iloc[test_index], y.iloc[train_index], y.iloc[test_index]
    
    print("Fitting baseline model needed for verification... ")
    baseline_search = GridSearchCV(LogisticRegression(random_state=19231823), lr_param_grid, scoring="roc_auc")
    baseline_search.fit(X_train, y_train)
    
    X_train_augmented, y_train_augmented = Iterative_CFA(X_train, 
                                                         y_train, 
                                                         stddev_percent=50, 
                                                         verify_with_baseline_model=True, 
                                                         baseline_model=baseline_search,
                                                         visualize_with_pca=False)

    for param_comb in combination_dicts:
        clf = LogisticRegression(random_state=19231823, **param_comb)
        clf.fit(X_train_augmented, y_train_augmented)
        current_score = roc_auc_score(y_test, clf.predict_proba(X_test)[:, 1])
        #print(f"Score for combination {param_comb}: {current_score}")
        scores_for_fold.append(current_score)
        
    all_scores.append(scores_for_fold)
# Out:
# Fold 0:
# Fitting baseline model needed for verification...
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# Data distribution before CFA:
# 	Majority (1): 3183, Minority (label 0): 158
# Number of 'good' native counterfactuals in data: 1378
# Classifier predicted all new synthetic counterfactuals to be in the majority class! => No new minority instances => Terminating...
# ====================================================================
# Data distribution after CFA:
# 	Majority (1): 3183, Minority (label 0): 158
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# Fold 1:
# Fitting baseline model needed for verification...
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# Data distribution before CFA:
# 	Majority (1): 3185, Minority (label 0): 156
# Number of 'good' native counterfactuals in data: 1056
# Classifier predicted all new synthetic counterfactuals to be in the majority class! => No new minority instances => Terminating...
# ====================================================================
# Data distribution after CFA:
# 	Majority (1): 3185, Minority (label 0): 156
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# Fold 2:
# Fitting baseline model needed for verification...
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# Data distribution before CFA:
# 	Majority (1): 3173, Minority (label 0): 169
# Number of 'good' native counterfactuals in data: 1029
# Classifier predicted all new synthetic counterfactuals to be in the majority class! => No new minority instances => Terminating...
# ====================================================================
# Data distribution after CFA:
# 	Majority (1): 3173, Minority (label 0): 169
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# Fold 3:
# Fitting baseline model needed for verification...
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# Data distribution before CFA:
# 	Majority (1): 3172, Minority (label 0): 170
# Number of 'good' native counterfactuals in data: 1031
# Classifier predicted all new synthetic counterfactuals to be in the majority class! => No new minority instances => Terminating...
# ====================================================================
# Data distribution after CFA:
# 	Majority (1): 3172, Minority (label 0): 170
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# Fold 4:
# Fitting baseline model needed for verification...
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# Data distribution before CFA:
# 	Majority (1): 3183, Minority (label 0): 159
# Number of 'good' native counterfactuals in data: 1015
# Classifier predicted all new synthetic counterfactuals to be in the majority class! => No new minority instances => Terminating...
# ====================================================================
# Data distribution after CFA:
# 	Majority (1): 3183, Minority (label 0): 159
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(

# %%
score_avg_over_folds = np.array(all_scores).mean(axis=0)
best_score_idx = score_avg_over_folds.argmax()
print(f"Best params: {combination_dicts[best_score_idx]}")
print(f"Best AUC: {score_avg_over_folds[best_score_idx]}")
# Out:
# Best params: {'C': 10, 'max_iter': 100, 'solver': 'liblinear'}
# Best AUC: 0.7342425375116226

# %% [markdown]
# ### ADASYN

# %%
all_scores = []

for i, (train_index, test_index) in enumerate(kf.split(X)):
    #print(f"Fold {i}:")
    scores_for_fold = []
    X_train, X_test, y_train, y_test = X.iloc[train_index], X.iloc[test_index], y.iloc[train_index], y.iloc[test_index]
        
    X_train_resampled, y_train_resampled = ada.fit_resample(X_train, y_train)
        
    for param_comb in combination_dicts:
        clf = LogisticRegression(random_state=19231823, **param_comb)
        clf.fit(X_train_resampled, y_train_resampled)
        current_score = roc_auc_score(y_test, clf.predict_proba(X_test)[:, 1])
        #print(f"Score for combination {param_comb}: {current_score}")
        scores_for_fold.append(current_score)
        
    all_scores.append(scores_for_fold)

# %%
score_avg_over_folds = np.array(all_scores).mean(axis=0)
best_score_idx = score_avg_over_folds.argmax()
print(f"Best params: {combination_dicts[best_score_idx]}")
print(f"Best AUC: {score_avg_over_folds[best_score_idx]}")
# Out:
# Best params: {'C': 1, 'max_iter': 100, 'solver': 'liblinear'}
# Best AUC: 0.7379872972484532

# %% [markdown]
# ### Random Oversampling

# %%
all_scores = []

for i, (train_index, test_index) in enumerate(kf.split(X)):
    #print(f"Fold {i}:")
    scores_for_fold = []
    X_train, X_test, y_train, y_test = X.iloc[train_index], X.iloc[test_index], y.iloc[train_index], y.iloc[test_index]
        
    X_train_resampled, y_train_resampled = ros.fit_resample(X_train, y_train)
        
    for param_comb in combination_dicts:
        clf = LogisticRegression(random_state=19231823, **param_comb)
        clf.fit(X_train_resampled, y_train_resampled)
        current_score = roc_auc_score(y_test, clf.predict_proba(X_test)[:, 1])
        #print(f"Score for combination {param_comb}: {current_score}")
        scores_for_fold.append(current_score)
        
    all_scores.append(scores_for_fold)

# %%
score_avg_over_folds = np.array(all_scores).mean(axis=0)
best_score_idx = score_avg_over_folds.argmax()
print(f"Best params: {combination_dicts[best_score_idx]}")
print(f"Best AUC: {score_avg_over_folds[best_score_idx]}")
# Out:
# Best params: {'C': 1, 'max_iter': 100, 'solver': 'liblinear'}
# Best AUC: 0.7374792368165206
