# %% [markdown]
# # Reproduction of Experiments on Dataset D8

# %% [markdown]
# > **Note:** The paper calls this dataset/split `Yeast-0-3-5-9-vs-7–8`, but the majority and minority ratio & counts indicate they actually meant `Yeast-2-3-5-9-vs-7–8` (e.g. class 2 instead of 0).

# %% [markdown]
# ## Read data

# %%
import sys 
import os
sys.path.insert(0, os.path.join("..", "src"))
import pandas as pd
# %matplotlib inline

names = ["Sequence Name", "mcg", "gvh", "alm", "mit", "erl", "pox", "vac", "nuc", "class"]

path = 'https://archive.ics.uci.edu/ml/machine-learning-databases/yeast/yeast.data'
df = pd.read_csv(path, header=None, names=names, delim_whitespace=True)
df
# Out:
#      Sequence Name   mcg   gvh   alm   mit  erl  pox   vac   nuc class
# 0       ADT1_YEAST  0.58  0.61  0.47  0.13  0.5  0.0  0.48  0.22   MIT
# 1       ADT2_YEAST  0.43  0.67  0.48  0.27  0.5  0.0  0.53  0.22   MIT
# 2       ADT3_YEAST  0.64  0.62  0.49  0.15  0.5  0.0  0.53  0.22   MIT
# 3       AAR2_YEAST  0.58  0.44  0.57  0.13  0.5  0.0  0.54  0.22   NUC
# 4       AATM_YEAST  0.42  0.44  0.48  0.54  0.5  0.0  0.48  0.22   MIT
# ...            ...   ...   ...   ...   ...  ...  ...   ...   ...   ...
# 1479    YUR1_YEAST  0.81  0.62  0.43  0.17  0.5  0.0  0.53  0.22   ME2
# 1480    ZIP1_YEAST  0.47  0.43  0.61  0.40  0.5  0.0  0.48  0.47   NUC
# 1481    ZNRP_YEAST  0.67  0.57  0.36  0.19  0.5  0.0  0.56  0.22   ME2
# 1482    ZUO1_YEAST  0.43  0.40  0.60  0.16  0.5  0.0  0.53  0.39   NUC
# 1483    G6PD_YEAST  0.65  0.54  0.54  0.13  0.5  0.0  0.53  0.22   CYT
#
# [1484 rows x 10 columns]

# %%
df = df.drop("Sequence Name", axis=1)
df
# Out:
#        mcg   gvh   alm   mit  erl  pox   vac   nuc class
# 0     0.58  0.61  0.47  0.13  0.5  0.0  0.48  0.22   MIT
# 1     0.43  0.67  0.48  0.27  0.5  0.0  0.53  0.22   MIT
# 2     0.64  0.62  0.49  0.15  0.5  0.0  0.53  0.22   MIT
# 3     0.58  0.44  0.57  0.13  0.5  0.0  0.54  0.22   NUC
# 4     0.42  0.44  0.48  0.54  0.5  0.0  0.48  0.22   MIT
# ...    ...   ...   ...   ...  ...  ...   ...   ...   ...
# 1479  0.81  0.62  0.43  0.17  0.5  0.0  0.53  0.22   ME2
# 1480  0.47  0.43  0.61  0.40  0.5  0.0  0.48  0.47   NUC
# 1481  0.67  0.57  0.36  0.19  0.5  0.0  0.56  0.22   ME2
# 1482  0.43  0.40  0.60  0.16  0.5  0.0  0.53  0.39   NUC
# 1483  0.65  0.54  0.54  0.13  0.5  0.0  0.53  0.22   CYT
#
# [1484 rows x 9 columns]

# %%
df["class"].value_counts()
# Out:
# CYT    463
# NUC    429
# MIT    244
# ME3    163
# ME2     51
# ME1     44
# EXC     35
# VAC     30
# POX     20
# ERL      5
# Name: class, dtype: int64

# %%
from sklearn import preprocessing
le = preprocessing.LabelEncoder()

le.fit_transform(df["class"])
le.classes_ = df["class"].value_counts().index.tolist()
df["class"] = le.transform(df["class"])
df
# Out:
#        mcg   gvh   alm   mit  erl  pox   vac   nuc  class
# 0     0.58  0.61  0.47  0.13  0.5  0.0  0.48  0.22      2
# 1     0.43  0.67  0.48  0.27  0.5  0.0  0.53  0.22      2
# 2     0.64  0.62  0.49  0.15  0.5  0.0  0.53  0.22      2
# 3     0.58  0.44  0.57  0.13  0.5  0.0  0.54  0.22      1
# 4     0.42  0.44  0.48  0.54  0.5  0.0  0.48  0.22      2
# ...    ...   ...   ...   ...  ...  ...   ...   ...    ...
# 1479  0.81  0.62  0.43  0.17  0.5  0.0  0.53  0.22      4
# 1480  0.47  0.43  0.61  0.40  0.5  0.0  0.48  0.47      1
# 1481  0.67  0.57  0.36  0.19  0.5  0.0  0.56  0.22      4
# 1482  0.43  0.40  0.60  0.16  0.5  0.0  0.53  0.39      1
# 1483  0.65  0.54  0.54  0.13  0.5  0.0  0.53  0.22      0
#
# [1484 rows x 9 columns]

# %%
label_column = "class"

minority_labels = [7, 8]
majority_labels = [2, 3, 5, 9]

df_filtered = df[df[label_column].isin(majority_labels + minority_labels)].copy()

df_filtered.loc[df_filtered[label_column].isin(majority_labels), label_column] = 1
df_filtered.loc[df_filtered[label_column].isin(minority_labels), label_column] = 0

X = df_filtered.drop(label_column, axis=1)
y = df_filtered[label_column]

# %%
y.value_counts()
# Out:
# 1    456
# 0     50
# Name: class, dtype: int64

# %% [markdown]
# # Classification

# %%
from sklearn.model_selection import ParameterGrid, KFold, GridSearchCV
from sklearn.metrics import roc_auc_score
import numpy as np

# %% [markdown]
# > **Note:** In the following, we use a custom piece of code for the grid search and cross-validation. We do this to enforce that the augmentation/oversampling step is only applied to training data and the test data is actually kept separate. For the baseline model, this means that we could also simply make use of the functions provided by sklearn instead of our custom code. However, in order to make the results comparable, we use the same code in each case.

# %%
kf = KFold(n_splits=5, shuffle=True, random_state=7018321)

# %% [markdown]
# ## Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf_param_grid = {
    'n_estimators': [50, 100, 200, 400, 600],
    'max_depth': [None, 4, 6, 10, 20, 30, 50, 80, 100],
}

# compute all combinations of parameters
combination_dicts = list(ParameterGrid(rf_param_grid))

# %% [markdown]
# ### Baseline (no augmentation)

# %%
all_scores = []

for i, (train_index, test_index) in enumerate(kf.split(X)):
    #print(f"Fold {i}:")
    scores_for_fold = []
    X_train, X_test, y_train, y_test = X.iloc[train_index], X.iloc[test_index], y.iloc[train_index], y.iloc[test_index]
        
    for param_comb in combination_dicts:
        clf = RandomForestClassifier(random_state=19231823, **param_comb)
        clf.fit(X_train, y_train)
        current_score = roc_auc_score(y_test, clf.predict_proba(X_test)[:, 1])
        #print(f"Score for combination {param_comb}: {current_score}")
        scores_for_fold.append(current_score)
        
    all_scores.append(scores_for_fold)

# %%
score_avg_over_folds = np.array(all_scores).mean(axis=0)
best_score_idx = score_avg_over_folds.argmax()
print(f"Best params: {combination_dicts[best_score_idx]}")
print(f"Best AUC: {score_avg_over_folds[best_score_idx]}")
# Out:
# Best params: {'max_depth': 6, 'n_estimators': 50}
# Best AUC: 0.8233432489618057

# %% [markdown]
# To verify that our cross-validation code works as expected, we can compare to a regular sklearn grid search here:

# %%
baseline_search = GridSearchCV(RandomForestClassifier(random_state=19231823), rf_param_grid, scoring="roc_auc")
baseline_search.fit(X, y)
baseline_search.best_score_
# Out:
# 0.7863449593884376

# %% [markdown]
# We can see that the best model found by a sklearn grid search performs similarly well to our best model, which indicates that the code works as expected.

# %% [markdown]
# ### With CFA

# %%
from cfa import Iterative_CFA

# %% [markdown]
# For CFA, we try two different approaches, since it is not entirely clear from the paper what the authors actually did.
# 1. The first approach strictly follows the pseudo-code and description given in section 3.2 of the paper.
# 2. In an earlier section of the paper, the authors say that _"the class of [a] new [synthetic counterfactual] instance needs to be verified by the underlying ML model."_ This means that we use some ML model trained on the data (without CFA) to assign a class to a new synthetic counterfactual, and only keep those that were classified to be a minority instance. This seems to lead to much more reasonable synthetic counterfactuals (see visualizations of the algorithm in exp001) but, at the same time, often means that the algorithm is unable to produce a fully balanced dataset (since it may terminate early).
#
# > **Note:** We also use a different tolerance level of 50% here, since the 10%-threshold proposed by the authors does not yield any "good" native counterfactuals, which makes the algorithm unusable.

# %% [markdown]
# #### Approach 1: No verification

# %%
all_scores = []

for i, (train_index, test_index) in enumerate(kf.split(X)):
    print(f"Fold {i}:")
    scores_for_fold = []
    X_train, X_test, y_train, y_test = X.iloc[train_index], X.iloc[test_index], y.iloc[train_index], y.iloc[test_index]
    
    X_train_augmented, y_train_augmented = Iterative_CFA(X_train, 
                                                         y_train, 
                                                         stddev_percent=50, 
                                                         verify_with_baseline_model=False,
                                                         visualize_with_pca=False)
    
    for param_comb in combination_dicts:
        clf = RandomForestClassifier(random_state=19231823, **param_comb)
        clf.fit(X_train_augmented, y_train_augmented)
        current_score = roc_auc_score(y_test, clf.predict_proba(X_test)[:, 1])
        #print(f"Score for combination {param_comb}: {current_score}")
        scores_for_fold.append(current_score)
        
    all_scores.append(scores_for_fold)
# Out:
# Fold 0:
# Data distribution before CFA:
# 	Majority (1): 359, Minority (label 0): 45
# Number of 'good' native counterfactuals in data: 195
# Data distribution after iteration 0:
# 	Majority (1): 359, Minority (label 0): 198
# Number of 'good' native counterfactuals in data: 270
# Data distribution after iteration 1:
# 	Majority (1): 359, Minority (label 0): 241
# Number of 'good' native counterfactuals in data: 285
# Data distribution after iteration 2:
# 	Majority (1): 359, Minority (label 0): 261
# Number of 'good' native counterfactuals in data: 290
# Data distribution after iteration 3:
# 	Majority (1): 359, Minority (label 0): 274
# Number of 'good' native counterfactuals in data: 290
# Data distribution after iteration 4:
# 	Majority (1): 359, Minority (label 0): 287
# Number of 'good' native counterfactuals in data: 291
# Data distribution after iteration 5:
# 	Majority (1): 359, Minority (label 0): 298
# Number of 'good' native counterfactuals in data: 291
# Data distribution after iteration 6:
# 	Majority (1): 359, Minority (label 0): 309
# Number of 'good' native counterfactuals in data: 291
# Data distribution after iteration 7:
# 	Majority (1): 359, Minority (label 0): 320
# Number of 'good' native counterfactuals in data: 291
# Data distribution after iteration 8:
# 	Majority (1): 359, Minority (label 0): 331
# Number of 'good' native counterfactuals in data: 291
# Data distribution after iteration 9:
# 	Majority (1): 359, Minority (label 0): 342
# Number of 'good' native counterfactuals in data: 291
# Data distribution after iteration 10:
# 	Majority (1): 359, Minority (label 0): 353
# Number of 'good' native counterfactuals in data: 291
# Data distribution after iteration 11:
# 	Majority (1): 359, Minority (label 0): 359
# ====================================================================
# Data distribution after CFA:
# 	Majority (1): 359, Minority (label 0): 359
# Fold 1:
# Data distribution before CFA:
# 	Majority (1): 366, Minority (label 0): 39
# Number of 'good' native counterfactuals in data: 167
# Data distribution after iteration 0:
# 	Majority (1): 366, Minority (label 0): 226
# Number of 'good' native counterfactuals in data: 279
# Data distribution after iteration 1:
# 	Majority (1): 366, Minority (label 0): 274
# Number of 'good' native counterfactuals in data: 303
# Data distribution after iteration 2:
# 	Majority (1): 366, Minority (label 0): 294
# Number of 'good' native counterfactuals in data: 307
# Data distribution after iteration 3:
# 	Majority (1): 366, Minority (label 0): 308
# Number of 'good' native counterfactuals in data: 307
# Data distribution after iteration 4:
# 	Majority (1): 366, Minority (label 0): 322
# Number of 'good' native counterfactuals in data: 307
# Data distribution after iteration 5:
# 	Majority (1): 366, Minority (label 0): 336
# Number of 'good' native counterfactuals in data: 307
# Data distribution after iteration 6:
# 	Majority (1): 366, Minority (label 0): 350
# Number of 'good' native counterfactuals in data: 308
# Data distribution after iteration 7:
# 	Majority (1): 366, Minority (label 0): 364
# ====================================================================
# Data distribution after CFA:
# 	Majority (1): 366, Minority (label 0): 364
# Fold 2:
# Data distribution before CFA:
# 	Majority (1): 366, Minority (label 0): 39
# Number of 'good' native counterfactuals in data: 181
# Data distribution after iteration 0:
# 	Majority (1): 366, Minority (label 0): 213
# Number of 'good' native counterfactuals in data: 271
# Data distribution after iteration 1:
# 	Majority (1): 366, Minority (label 0): 266
# Number of 'good' native counterfactuals in data: 291
# Data distribution after iteration 2:
# 	Majority (1): 366, Minority (label 0): 281
# Number of 'good' native counterfactuals in data: 294
# Data distribution after iteration 3:
# 	Majority (1): 366, Minority (label 0): 292
# Number of 'good' native counterfactuals in data: 295
# Data distribution after iteration 4:
# 	Majority (1): 366, Minority (label 0): 302
# Number of 'good' native counterfactuals in data: 295
# Data distribution after iteration 5:
# 	Majority (1): 366, Minority (label 0): 312
# Number of 'good' native counterfactuals in data: 297
# Data distribution after iteration 6:
# 	Majority (1): 366, Minority (label 0): 325
# Number of 'good' native counterfactuals in data: 297
# Data distribution after iteration 7:
# 	Majority (1): 366, Minority (label 0): 338
# Number of 'good' native counterfactuals in data: 298
# Data distribution after iteration 8:
# 	Majority (1): 366, Minority (label 0): 349
# Number of 'good' native counterfactuals in data: 298
# Data distribution after iteration 9:
# 	Majority (1): 366, Minority (label 0): 360
# Number of 'good' native counterfactuals in data: 298
# Data distribution after iteration 10:
# 	Majority (1): 366, Minority (label 0): 366
# ====================================================================
# Data distribution after CFA:
# 	Majority (1): 366, Minority (label 0): 366
# Fold 3:
# Data distribution before CFA:
# 	Majority (1): 368, Minority (label 0): 37
# Number of 'good' native counterfactuals in data: 207
# Data distribution after iteration 0:
# 	Majority (1): 368, Minority (label 0): 187
# Number of 'good' native counterfactuals in data: 272
# Data distribution after iteration 1:
# 	Majority (1): 368, Minority (label 0): 233
# Number of 'good' native counterfactuals in data: 289
# Data distribution after iteration 2:
# 	Majority (1): 368, Minority (label 0): 253
# Number of 'good' native counterfactuals in data: 298
# Data distribution after iteration 3:
# 	Majority (1): 368, Minority (label 0): 262
# Number of 'good' native counterfactuals in data: 299
# Data distribution after iteration 4:
# 	Majority (1): 368, Minority (label 0): 268
# Number of 'good' native counterfactuals in data: 299
# Data distribution after iteration 5:
# 	Majority (1): 368, Minority (label 0): 274
# Number of 'good' native counterfactuals in data: 299
# Data distribution after iteration 6:
# 	Majority (1): 368, Minority (label 0): 280
# Number of 'good' native counterfactuals in data: 299
# Data distribution after iteration 7:
# 	Majority (1): 368, Minority (label 0): 286
# Number of 'good' native counterfactuals in data: 299
# Data distribution after iteration 8:
# 	Majority (1): 368, Minority (label 0): 292
# Number of 'good' native counterfactuals in data: 299
# Data distribution after iteration 9:
# 	Majority (1): 368, Minority (label 0): 298
# Number of 'good' native counterfactuals in data: 299
# Data distribution after iteration 10:
# 	Majority (1): 368, Minority (label 0): 304
# Number of 'good' native counterfactuals in data: 299
# Data distribution after iteration 11:
# 	Majority (1): 368, Minority (label 0): 310
# Number of 'good' native counterfactuals in data: 299
# Data distribution after iteration 12:
# 	Majority (1): 368, Minority (label 0): 316
# Number of 'good' native counterfactuals in data: 299
# Data distribution after iteration 13:
# 	Majority (1): 368, Minority (label 0): 322
# Number of 'good' native counterfactuals in data: 299
# Data distribution after iteration 14:
# 	Majority (1): 368, Minority (label 0): 328
# Number of 'good' native counterfactuals in data: 299
# Data distribution after iteration 15:
# 	Majority (1): 368, Minority (label 0): 334
# Number of 'good' native counterfactuals in data: 299
# Data distribution after iteration 16:
# 	Majority (1): 368, Minority (label 0): 340
# Number of 'good' native counterfactuals in data: 299
# Data distribution after iteration 17:
# 	Majority (1): 368, Minority (label 0): 346
# Number of 'good' native counterfactuals in data: 299
# Data distribution after iteration 18:
# 	Majority (1): 368, Minority (label 0): 352
# Number of 'good' native counterfactuals in data: 299
# Data distribution after iteration 19:
# 	Majority (1): 368, Minority (label 0): 358
# Number of 'good' native counterfactuals in data: 299
# Data distribution after iteration 20:
# 	Majority (1): 368, Minority (label 0): 364
# Number of 'good' native counterfactuals in data: 299
# Data distribution after iteration 21:
# 	Majority (1): 368, Minority (label 0): 368
# ====================================================================
# Data distribution after CFA:
# 	Majority (1): 368, Minority (label 0): 368
# Fold 4:
# Data distribution before CFA:
# 	Majority (1): 365, Minority (label 0): 40
# Number of 'good' native counterfactuals in data: 184
# Data distribution after iteration 0:
# 	Majority (1): 365, Minority (label 0): 211
# Number of 'good' native counterfactuals in data: 269
# Data distribution after iteration 1:
# 	Majority (1): 365, Minority (label 0): 267
# Number of 'good' native counterfactuals in data: 278
# Data distribution after iteration 2:
# 	Majority (1): 365, Minority (label 0): 297
# Number of 'good' native counterfactuals in data: 287
# Data distribution after iteration 3:
# 	Majority (1): 365, Minority (label 0): 312
# Number of 'good' native counterfactuals in data: 285
# Data distribution after iteration 4:
# 	Majority (1): 365, Minority (label 0): 326
# Number of 'good' native counterfactuals in data: 287
# Data distribution after iteration 5:
# 	Majority (1): 365, Minority (label 0): 338
# Number of 'good' native counterfactuals in data: 287
# Data distribution after iteration 6:
# 	Majority (1): 365, Minority (label 0): 350
# Number of 'good' native counterfactuals in data: 287
# Data distribution after iteration 7:
# 	Majority (1): 365, Minority (label 0): 362
# ====================================================================
# Data distribution after CFA:
# 	Majority (1): 365, Minority (label 0): 362

# %%
score_avg_over_folds = np.array(all_scores).mean(axis=0)
best_score_idx = score_avg_over_folds.argmax()
print(f"Best params: {combination_dicts[best_score_idx]}")
print(f"Best AUC: {score_avg_over_folds[best_score_idx]}")
# Out:
# Best params: {'max_depth': 10, 'n_estimators': 100}
# Best AUC: 0.7419417180757387

# %% [markdown]
# #### Approach 2: Verification of new synthetic counterfactuals with baseline model

# %%
all_scores = []

for i, (train_index, test_index) in enumerate(kf.split(X)):
    print(f"Fold {i}:")
    scores_for_fold = []
    X_train, X_test, y_train, y_test = X.iloc[train_index], X.iloc[test_index], y.iloc[train_index], y.iloc[test_index]
    
    print("Fitting baseline model needed for verification... ")
    baseline_search = GridSearchCV(RandomForestClassifier(random_state=19231823), rf_param_grid, scoring="roc_auc")
    baseline_search.fit(X_train, y_train)
    
    X_train_augmented, y_train_augmented = Iterative_CFA(X_train, 
                                                         y_train, 
                                                         stddev_percent=50, 
                                                         verify_with_baseline_model=True, 
                                                         baseline_model=baseline_search, 
                                                         visualize_with_pca=False)
    
    for param_comb in combination_dicts:
        clf = RandomForestClassifier(random_state=19231823, **param_comb)
        clf.fit(X_train_augmented, y_train_augmented)
        current_score = roc_auc_score(y_test, clf.predict_proba(X_test)[:, 1])
        #print(f"Score for combination {param_comb}: {current_score}")
        scores_for_fold.append(current_score)
        
    all_scores.append(scores_for_fold)
# Out:
# Fold 0:
# Fitting baseline model needed for verification...
# Data distribution before CFA:
# 	Majority (1): 359, Minority (label 0): 45
# Number of 'good' native counterfactuals in data: 195
# Data distribution after iteration 0:
# 	Majority (1): 359, Minority (label 0): 46
# Number of 'good' native counterfactuals in data: 196
# Classifier predicted all new synthetic counterfactuals to be in the majority class! => No new minority instances => Terminating...
# ====================================================================
# Data distribution after CFA:
# 	Majority (1): 359, Minority (label 0): 46
# Fold 1:
# Fitting baseline model needed for verification...
# Data distribution before CFA:
# 	Majority (1): 366, Minority (label 0): 39
# Number of 'good' native counterfactuals in data: 167
# Data distribution after iteration 0:
# 	Majority (1): 366, Minority (label 0): 41
# Number of 'good' native counterfactuals in data: 169
# Classifier predicted all new synthetic counterfactuals to be in the majority class! => No new minority instances => Terminating...
# ====================================================================
# Data distribution after CFA:
# 	Majority (1): 366, Minority (label 0): 41
# Fold 2:
# Fitting baseline model needed for verification...
# Data distribution before CFA:
# 	Majority (1): 366, Minority (label 0): 39
# Number of 'good' native counterfactuals in data: 181
# Data distribution after iteration 0:
# 	Majority (1): 366, Minority (label 0): 43
# Number of 'good' native counterfactuals in data: 181
# Data distribution after iteration 1:
# 	Majority (1): 366, Minority (label 0): 46
# Number of 'good' native counterfactuals in data: 181
# Data distribution after iteration 2:
# 	Majority (1): 366, Minority (label 0): 49
# Number of 'good' native counterfactuals in data: 181
# Data distribution after iteration 3:
# 	Majority (1): 366, Minority (label 0): 52
# Number of 'good' native counterfactuals in data: 174
# Data distribution after iteration 4:
# 	Majority (1): 366, Minority (label 0): 56
# Number of 'good' native counterfactuals in data: 176
# Data distribution after iteration 5:
# 	Majority (1): 366, Minority (label 0): 59
# Number of 'good' native counterfactuals in data: 176
# Data distribution after iteration 6:
# 	Majority (1): 366, Minority (label 0): 62
# Number of 'good' native counterfactuals in data: 176
# Data distribution after iteration 7:
# 	Majority (1): 366, Minority (label 0): 65
# Number of 'good' native counterfactuals in data: 176
# Data distribution after iteration 8:
# 	Majority (1): 366, Minority (label 0): 68
# Number of 'good' native counterfactuals in data: 176
# Data distribution after iteration 9:
# 	Majority (1): 366, Minority (label 0): 71
# Number of 'good' native counterfactuals in data: 176
# Data distribution after iteration 10:
# 	Majority (1): 366, Minority (label 0): 74
# Number of 'good' native counterfactuals in data: 176
# Data distribution after iteration 11:
# 	Majority (1): 366, Minority (label 0): 77
# Number of 'good' native counterfactuals in data: 176
# Data distribution after iteration 12:
# 	Majority (1): 366, Minority (label 0): 80
# Number of 'good' native counterfactuals in data: 176
# Data distribution after iteration 13:
# 	Majority (1): 366, Minority (label 0): 83
# Number of 'good' native counterfactuals in data: 176
# Data distribution after iteration 14:
# 	Majority (1): 366, Minority (label 0): 86
# Number of 'good' native counterfactuals in data: 176
# Data distribution after iteration 15:
# 	Majority (1): 366, Minority (label 0): 89
# Number of 'good' native counterfactuals in data: 176
# Data distribution after iteration 16:
# 	Majority (1): 366, Minority (label 0): 92
# Number of 'good' native counterfactuals in data: 176
# Data distribution after iteration 17:
# 	Majority (1): 366, Minority (label 0): 95
# Number of 'good' native counterfactuals in data: 176
# Data distribution after iteration 18:
# 	Majority (1): 366, Minority (label 0): 98
# Number of 'good' native counterfactuals in data: 176
# Data distribution after iteration 19:
# 	Majority (1): 366, Minority (label 0): 101
# Number of 'good' native counterfactuals in data: 176
# Data distribution after iteration 20:
# 	Majority (1): 366, Minority (label 0): 104
# Number of 'good' native counterfactuals in data: 172
# Data distribution after iteration 21:
# 	Majority (1): 366, Minority (label 0): 107
# Number of 'good' native counterfactuals in data: 172
# Data distribution after iteration 22:
# 	Majority (1): 366, Minority (label 0): 110
# Number of 'good' native counterfactuals in data: 161
# Data distribution after iteration 23:
# 	Majority (1): 366, Minority (label 0): 113
# Number of 'good' native counterfactuals in data: 161
# Data distribution after iteration 24:
# 	Majority (1): 366, Minority (label 0): 116
# Number of 'good' native counterfactuals in data: 161
# Data distribution after iteration 25:
# 	Majority (1): 366, Minority (label 0): 119
# Number of 'good' native counterfactuals in data: 161
# Data distribution after iteration 26:
# 	Majority (1): 366, Minority (label 0): 122
# Number of 'good' native counterfactuals in data: 161
# Data distribution after iteration 27:
# 	Majority (1): 366, Minority (label 0): 125
# Number of 'good' native counterfactuals in data: 161
# Data distribution after iteration 28:
# 	Majority (1): 366, Minority (label 0): 128
# Number of 'good' native counterfactuals in data: 161
# Data distribution after iteration 29:
# 	Majority (1): 366, Minority (label 0): 131
# Number of 'good' native counterfactuals in data: 161
# Data distribution after iteration 30:
# 	Majority (1): 366, Minority (label 0): 134
# Number of 'good' native counterfactuals in data: 161
# Data distribution after iteration 31:
# 	Majority (1): 366, Minority (label 0): 137
# Number of 'good' native counterfactuals in data: 161
# Data distribution after iteration 32:
# 	Majority (1): 366, Minority (label 0): 140
# Number of 'good' native counterfactuals in data: 161
# Data distribution after iteration 33:
# 	Majority (1): 366, Minority (label 0): 143
# Number of 'good' native counterfactuals in data: 161
# Data distribution after iteration 34:
# 	Majority (1): 366, Minority (label 0): 146
# Number of 'good' native counterfactuals in data: 161
# Data distribution after iteration 35:
# 	Majority (1): 366, Minority (label 0): 149
# Number of 'good' native counterfactuals in data: 161
# Data distribution after iteration 36:
# 	Majority (1): 366, Minority (label 0): 152
# Number of 'good' native counterfactuals in data: 161
# Data distribution after iteration 37:
# 	Majority (1): 366, Minority (label 0): 155
# Number of 'good' native counterfactuals in data: 161
# Data distribution after iteration 38:
# 	Majority (1): 366, Minority (label 0): 158
# Number of 'good' native counterfactuals in data: 161
# Data distribution after iteration 39:
# 	Majority (1): 366, Minority (label 0): 161
# Number of 'good' native counterfactuals in data: 161
# Data distribution after iteration 40:
# 	Majority (1): 366, Minority (label 0): 164
# Number of 'good' native counterfactuals in data: 161
# Data distribution after iteration 41:
# 	Majority (1): 366, Minority (label 0): 167
# Number of 'good' native counterfactuals in data: 161
# Data distribution after iteration 42:
# 	Majority (1): 366, Minority (label 0): 170
# Number of 'good' native counterfactuals in data: 161
# Data distribution after iteration 43:
# 	Majority (1): 366, Minority (label 0): 173
# Number of 'good' native counterfactuals in data: 161
# Data distribution after iteration 44:
# 	Majority (1): 366, Minority (label 0): 176
# Number of 'good' native counterfactuals in data: 161
# Data distribution after iteration 45:
# 	Majority (1): 366, Minority (label 0): 179
# Number of 'good' native counterfactuals in data: 161
# Data distribution after iteration 46:
# 	Majority (1): 366, Minority (label 0): 182
# Number of 'good' native counterfactuals in data: 161
# Data distribution after iteration 47:
# 	Majority (1): 366, Minority (label 0): 185
# Number of 'good' native counterfactuals in data: 161
# Data distribution after iteration 48:
# 	Majority (1): 366, Minority (label 0): 188
# Number of 'good' native counterfactuals in data: 161
# Data distribution after iteration 49:
# 	Majority (1): 366, Minority (label 0): 191
# Number of 'good' native counterfactuals in data: 161
# Data distribution after iteration 50:
# 	Majority (1): 366, Minority (label 0): 194
# Number of 'good' native counterfactuals in data: 161
# Data distribution after iteration 51:
# 	Majority (1): 366, Minority (label 0): 197
# Number of 'good' native counterfactuals in data: 161
# Data distribution after iteration 52:
# 	Majority (1): 366, Minority (label 0): 200
# Number of 'good' native counterfactuals in data: 161
# Data distribution after iteration 53:
# 	Majority (1): 366, Minority (label 0): 203
# Number of 'good' native counterfactuals in data: 161
# Data distribution after iteration 54:
# 	Majority (1): 366, Minority (label 0): 206
# Number of 'good' native counterfactuals in data: 161
# Data distribution after iteration 55:
# 	Majority (1): 366, Minority (label 0): 209
# Number of 'good' native counterfactuals in data: 161
# Data distribution after iteration 56:
# 	Majority (1): 366, Minority (label 0): 212
# Number of 'good' native counterfactuals in data: 161
# Data distribution after iteration 57:
# 	Majority (1): 366, Minority (label 0): 215
# Number of 'good' native counterfactuals in data: 161
# Data distribution after iteration 58:
# 	Majority (1): 366, Minority (label 0): 218
# Number of 'good' native counterfactuals in data: 146
# Data distribution after iteration 59:
# 	Majority (1): 366, Minority (label 0): 219
# Number of 'good' native counterfactuals in data: 146
# Data distribution after iteration 60:
# 	Majority (1): 366, Minority (label 0): 220
# Number of 'good' native counterfactuals in data: 146
# Data distribution after iteration 61:
# 	Majority (1): 366, Minority (label 0): 221
# Number of 'good' native counterfactuals in data: 146
# Data distribution after iteration 62:
# 	Majority (1): 366, Minority (label 0): 222
# Number of 'good' native counterfactuals in data: 146
# Data distribution after iteration 63:
# 	Majority (1): 366, Minority (label 0): 223
# Number of 'good' native counterfactuals in data: 146
# Data distribution after iteration 64:
# 	Majority (1): 366, Minority (label 0): 224
# Number of 'good' native counterfactuals in data: 146
# Data distribution after iteration 65:
# 	Majority (1): 366, Minority (label 0): 225
# Number of 'good' native counterfactuals in data: 146
# Data distribution after iteration 66:
# 	Majority (1): 366, Minority (label 0): 226
# Number of 'good' native counterfactuals in data: 146
# Data distribution after iteration 67:
# 	Majority (1): 366, Minority (label 0): 227
# Number of 'good' native counterfactuals in data: 146
# Data distribution after iteration 68:
# 	Majority (1): 366, Minority (label 0): 228
# Number of 'good' native counterfactuals in data: 146
# Data distribution after iteration 69:
# 	Majority (1): 366, Minority (label 0): 229
# Number of 'good' native counterfactuals in data: 146
# Data distribution after iteration 70:
# 	Majority (1): 366, Minority (label 0): 230
# Number of 'good' native counterfactuals in data: 146
# Data distribution after iteration 71:
# 	Majority (1): 366, Minority (label 0): 231
# Number of 'good' native counterfactuals in data: 146
# Data distribution after iteration 72:
# 	Majority (1): 366, Minority (label 0): 232
# Number of 'good' native counterfactuals in data: 146
# Data distribution after iteration 73:
# 	Majority (1): 366, Minority (label 0): 233
# Number of 'good' native counterfactuals in data: 146
# Data distribution after iteration 74:
# 	Majority (1): 366, Minority (label 0): 234
# Number of 'good' native counterfactuals in data: 146
# Data distribution after iteration 75:
# 	Majority (1): 366, Minority (label 0): 235
# Number of 'good' native counterfactuals in data: 146
# Data distribution after iteration 76:
# 	Majority (1): 366, Minority (label 0): 236
# Number of 'good' native counterfactuals in data: 146
# Data distribution after iteration 77:
# 	Majority (1): 366, Minority (label 0): 237
# Number of 'good' native counterfactuals in data: 146
# Data distribution after iteration 78:
# 	Majority (1): 366, Minority (label 0): 238
# Number of 'good' native counterfactuals in data: 146
# Data distribution after iteration 79:
# 	Majority (1): 366, Minority (label 0): 239
# Number of 'good' native counterfactuals in data: 146
# Data distribution after iteration 80:
# 	Majority (1): 366, Minority (label 0): 240
# Number of 'good' native counterfactuals in data: 146
# Data distribution after iteration 81:
# 	Majority (1): 366, Minority (label 0): 241
# Number of 'good' native counterfactuals in data: 146
# Data distribution after iteration 82:
# 	Majority (1): 366, Minority (label 0): 242
# Number of 'good' native counterfactuals in data: 146
# Data distribution after iteration 83:
# 	Majority (1): 366, Minority (label 0): 243
# Number of 'good' native counterfactuals in data: 146
# Data distribution after iteration 84:
# 	Majority (1): 366, Minority (label 0): 244
# Number of 'good' native counterfactuals in data: 146
# Data distribution after iteration 85:
# 	Majority (1): 366, Minority (label 0): 245
# Number of 'good' native counterfactuals in data: 146
# Data distribution after iteration 86:
# 	Majority (1): 366, Minority (label 0): 246
# Number of 'good' native counterfactuals in data: 146
# Data distribution after iteration 87:
# 	Majority (1): 366, Minority (label 0): 247
# Number of 'good' native counterfactuals in data: 146
# Data distribution after iteration 88:
# 	Majority (1): 366, Minority (label 0): 248
# Number of 'good' native counterfactuals in data: 146
# Data distribution after iteration 89:
# 	Majority (1): 366, Minority (label 0): 249
# Number of 'good' native counterfactuals in data: 146
# Data distribution after iteration 90:
# 	Majority (1): 366, Minority (label 0): 250
# Number of 'good' native counterfactuals in data: 146
# Data distribution after iteration 91:
# 	Majority (1): 366, Minority (label 0): 251
# Number of 'good' native counterfactuals in data: 146
# Data distribution after iteration 92:
# 	Majority (1): 366, Minority (label 0): 252
# Number of 'good' native counterfactuals in data: 146
# Data distribution after iteration 93:
# 	Majority (1): 366, Minority (label 0): 253
# Number of 'good' native counterfactuals in data: 146
# Data distribution after iteration 94:
# 	Majority (1): 366, Minority (label 0): 254
# Number of 'good' native counterfactuals in data: 146
# Data distribution after iteration 95:
# 	Majority (1): 366, Minority (label 0): 255
# Number of 'good' native counterfactuals in data: 146
# Data distribution after iteration 96:
# 	Majority (1): 366, Minority (label 0): 256
# Number of 'good' native counterfactuals in data: 146
# Data distribution after iteration 97:
# 	Majority (1): 366, Minority (label 0): 257
# Number of 'good' native counterfactuals in data: 146
# Data distribution after iteration 98:
# 	Majority (1): 366, Minority (label 0): 258
# Number of 'good' native counterfactuals in data: 146
# Data distribution after iteration 99:
# 	Majority (1): 366, Minority (label 0): 259
# Number of 'good' native counterfactuals in data: 146
# Data distribution after iteration 100:
# 	Majority (1): 366, Minority (label 0): 260
# Number of 'good' native counterfactuals in data: 146
# Data distribution after iteration 101:
# 	Majority (1): 366, Minority (label 0): 261
# Number of 'good' native counterfactuals in data: 140
# Data distribution after iteration 102:
# 	Majority (1): 366, Minority (label 0): 262
# Number of 'good' native counterfactuals in data: 140
# Data distribution after iteration 103:
# 	Majority (1): 366, Minority (label 0): 263
# Number of 'good' native counterfactuals in data: 140
# Data distribution after iteration 104:
# 	Majority (1): 366, Minority (label 0): 264
# Number of 'good' native counterfactuals in data: 140
# Data distribution after iteration 105:
# 	Majority (1): 366, Minority (label 0): 265
# Number of 'good' native counterfactuals in data: 140
# Data distribution after iteration 106:
# 	Majority (1): 366, Minority (label 0): 266
# Number of 'good' native counterfactuals in data: 140
# Data distribution after iteration 107:
# 	Majority (1): 366, Minority (label 0): 267
# Number of 'good' native counterfactuals in data: 140
# Data distribution after iteration 108:
# 	Majority (1): 366, Minority (label 0): 268
# Number of 'good' native counterfactuals in data: 140
# Data distribution after iteration 109:
# 	Majority (1): 366, Minority (label 0): 269
# Number of 'good' native counterfactuals in data: 140
# Data distribution after iteration 110:
# 	Majority (1): 366, Minority (label 0): 270
# Number of 'good' native counterfactuals in data: 140
# Data distribution after iteration 111:
# 	Majority (1): 366, Minority (label 0): 271
# Number of 'good' native counterfactuals in data: 140
# Data distribution after iteration 112:
# 	Majority (1): 366, Minority (label 0): 272
# Number of 'good' native counterfactuals in data: 140
# Data distribution after iteration 113:
# 	Majority (1): 366, Minority (label 0): 273
# Number of 'good' native counterfactuals in data: 140
# Data distribution after iteration 114:
# 	Majority (1): 366, Minority (label 0): 274
# Number of 'good' native counterfactuals in data: 140
# Data distribution after iteration 115:
# 	Majority (1): 366, Minority (label 0): 275
# Number of 'good' native counterfactuals in data: 140
# Data distribution after iteration 116:
# 	Majority (1): 366, Minority (label 0): 276
# Number of 'good' native counterfactuals in data: 140
# Data distribution after iteration 117:
# 	Majority (1): 366, Minority (label 0): 277
# Number of 'good' native counterfactuals in data: 140
# Data distribution after iteration 118:
# 	Majority (1): 366, Minority (label 0): 278
# Number of 'good' native counterfactuals in data: 140
# Data distribution after iteration 119:
# 	Majority (1): 366, Minority (label 0): 279
# Number of 'good' native counterfactuals in data: 140
# Data distribution after iteration 120:
# 	Majority (1): 366, Minority (label 0): 280
# Number of 'good' native counterfactuals in data: 140
# Data distribution after iteration 121:
# 	Majority (1): 366, Minority (label 0): 281
# Number of 'good' native counterfactuals in data: 140
# Data distribution after iteration 122:
# 	Majority (1): 366, Minority (label 0): 282
# Number of 'good' native counterfactuals in data: 140
# Data distribution after iteration 123:
# 	Majority (1): 366, Minority (label 0): 283
# Number of 'good' native counterfactuals in data: 140
# Data distribution after iteration 124:
# 	Majority (1): 366, Minority (label 0): 284
# Number of 'good' native counterfactuals in data: 140
# Data distribution after iteration 125:
# 	Majority (1): 366, Minority (label 0): 285
# Number of 'good' native counterfactuals in data: 140
# Data distribution after iteration 126:
# 	Majority (1): 366, Minority (label 0): 286
# Number of 'good' native counterfactuals in data: 140
# Data distribution after iteration 127:
# 	Majority (1): 366, Minority (label 0): 287
# Number of 'good' native counterfactuals in data: 140
# Data distribution after iteration 128:
# 	Majority (1): 366, Minority (label 0): 288
# Number of 'good' native counterfactuals in data: 140
# Data distribution after iteration 129:
# 	Majority (1): 366, Minority (label 0): 289
# Number of 'good' native counterfactuals in data: 140
# Data distribution after iteration 130:
# 	Majority (1): 366, Minority (label 0): 290
# Number of 'good' native counterfactuals in data: 140
# Data distribution after iteration 131:
# 	Majority (1): 366, Minority (label 0): 291
# Number of 'good' native counterfactuals in data: 140
# Data distribution after iteration 132:
# 	Majority (1): 366, Minority (label 0): 292
# Number of 'good' native counterfactuals in data: 140
# Data distribution after iteration 133:
# 	Majority (1): 366, Minority (label 0): 293
# Number of 'good' native counterfactuals in data: 140
# Data distribution after iteration 134:
# 	Majority (1): 366, Minority (label 0): 294
# Number of 'good' native counterfactuals in data: 140
# Data distribution after iteration 135:
# 	Majority (1): 366, Minority (label 0): 295
# Number of 'good' native counterfactuals in data: 140
# Data distribution after iteration 136:
# 	Majority (1): 366, Minority (label 0): 296
# Number of 'good' native counterfactuals in data: 140
# Data distribution after iteration 137:
# 	Majority (1): 366, Minority (label 0): 297
# Number of 'good' native counterfactuals in data: 140
# Data distribution after iteration 138:
# 	Majority (1): 366, Minority (label 0): 298
# Number of 'good' native counterfactuals in data: 140
# Data distribution after iteration 139:
# 	Majority (1): 366, Minority (label 0): 299
# Number of 'good' native counterfactuals in data: 140
# Data distribution after iteration 140:
# 	Majority (1): 366, Minority (label 0): 300
# Number of 'good' native counterfactuals in data: 140
# Data distribution after iteration 141:
# 	Majority (1): 366, Minority (label 0): 301
# Number of 'good' native counterfactuals in data: 140
# Data distribution after iteration 142:
# 	Majority (1): 366, Minority (label 0): 302
# Number of 'good' native counterfactuals in data: 140
# Data distribution after iteration 143:
# 	Majority (1): 366, Minority (label 0): 303
# Number of 'good' native counterfactuals in data: 140
# Data distribution after iteration 144:
# 	Majority (1): 366, Minority (label 0): 304
# Number of 'good' native counterfactuals in data: 140
# Data distribution after iteration 145:
# 	Majority (1): 366, Minority (label 0): 305
# Number of 'good' native counterfactuals in data: 140
# Data distribution after iteration 146:
# 	Majority (1): 366, Minority (label 0): 306
# Number of 'good' native counterfactuals in data: 140
# Data distribution after iteration 147:
# 	Majority (1): 366, Minority (label 0): 307
# Number of 'good' native counterfactuals in data: 140
# Data distribution after iteration 148:
# 	Majority (1): 366, Minority (label 0): 308
# Number of 'good' native counterfactuals in data: 140
# Data distribution after iteration 149:
# 	Majority (1): 366, Minority (label 0): 309
# Number of 'good' native counterfactuals in data: 140
# Data distribution after iteration 150:
# 	Majority (1): 366, Minority (label 0): 310
# Number of 'good' native counterfactuals in data: 140
# Data distribution after iteration 151:
# 	Majority (1): 366, Minority (label 0): 311
# Number of 'good' native counterfactuals in data: 140
# Data distribution after iteration 152:
# 	Majority (1): 366, Minority (label 0): 312
# Number of 'good' native counterfactuals in data: 140
# Data distribution after iteration 153:
# 	Majority (1): 366, Minority (label 0): 313
# Number of 'good' native counterfactuals in data: 140
# Data distribution after iteration 154:
# 	Majority (1): 366, Minority (label 0): 314
# Number of 'good' native counterfactuals in data: 140
# Data distribution after iteration 155:
# 	Majority (1): 366, Minority (label 0): 315
# Number of 'good' native counterfactuals in data: 140
# Data distribution after iteration 156:
# 	Majority (1): 366, Minority (label 0): 316
# Number of 'good' native counterfactuals in data: 140
# Data distribution after iteration 157:
# 	Majority (1): 366, Minority (label 0): 317
# Number of 'good' native counterfactuals in data: 140
# Data distribution after iteration 158:
# 	Majority (1): 366, Minority (label 0): 318
# Number of 'good' native counterfactuals in data: 140
# Data distribution after iteration 159:
# 	Majority (1): 366, Minority (label 0): 319
# Number of 'good' native counterfactuals in data: 140
# Data distribution after iteration 160:
# 	Majority (1): 366, Minority (label 0): 320
# Number of 'good' native counterfactuals in data: 140
# Data distribution after iteration 161:
# 	Majority (1): 366, Minority (label 0): 321
# Number of 'good' native counterfactuals in data: 140
# Data distribution after iteration 162:
# 	Majority (1): 366, Minority (label 0): 322
# Number of 'good' native counterfactuals in data: 140
# Data distribution after iteration 163:
# 	Majority (1): 366, Minority (label 0): 323
# Number of 'good' native counterfactuals in data: 140
# Data distribution after iteration 164:
# 	Majority (1): 366, Minority (label 0): 324
# Number of 'good' native counterfactuals in data: 126
# Data distribution after iteration 165:
# 	Majority (1): 366, Minority (label 0): 325
# Number of 'good' native counterfactuals in data: 115
# Data distribution after iteration 166:
# 	Majority (1): 366, Minority (label 0): 326
# Number of 'good' native counterfactuals in data: 115
# Data distribution after iteration 167:
# 	Majority (1): 366, Minority (label 0): 327
# Number of 'good' native counterfactuals in data: 115
# Data distribution after iteration 168:
# 	Majority (1): 366, Minority (label 0): 328
# Number of 'good' native counterfactuals in data: 115
# Data distribution after iteration 169:
# 	Majority (1): 366, Minority (label 0): 329
# Number of 'good' native counterfactuals in data: 115
# Data distribution after iteration 170:
# 	Majority (1): 366, Minority (label 0): 330
# Number of 'good' native counterfactuals in data: 115
# Data distribution after iteration 171:
# 	Majority (1): 366, Minority (label 0): 331
# Number of 'good' native counterfactuals in data: 106
# Data distribution after iteration 172:
# 	Majority (1): 366, Minority (label 0): 334
# Number of 'good' native counterfactuals in data: 118
# Data distribution after iteration 173:
# 	Majority (1): 366, Minority (label 0): 335
# Number of 'good' native counterfactuals in data: 118
# Data distribution after iteration 174:
# 	Majority (1): 366, Minority (label 0): 336
# Number of 'good' native counterfactuals in data: 118
# Data distribution after iteration 175:
# 	Majority (1): 366, Minority (label 0): 337
# Number of 'good' native counterfactuals in data: 109
# Data distribution after iteration 176:
# 	Majority (1): 366, Minority (label 0): 338
# Number of 'good' native counterfactuals in data: 109
# Data distribution after iteration 177:
# 	Majority (1): 366, Minority (label 0): 339
# Number of 'good' native counterfactuals in data: 109
# Data distribution after iteration 178:
# 	Majority (1): 366, Minority (label 0): 340
# Number of 'good' native counterfactuals in data: 109
# Data distribution after iteration 179:
# 	Majority (1): 366, Minority (label 0): 341
# Number of 'good' native counterfactuals in data: 109
# Data distribution after iteration 180:
# 	Majority (1): 366, Minority (label 0): 342
# Number of 'good' native counterfactuals in data: 109
# Data distribution after iteration 181:
# 	Majority (1): 366, Minority (label 0): 343
# Number of 'good' native counterfactuals in data: 109
# Data distribution after iteration 182:
# 	Majority (1): 366, Minority (label 0): 344
# Number of 'good' native counterfactuals in data: 109
# Data distribution after iteration 183:
# 	Majority (1): 366, Minority (label 0): 345
# Number of 'good' native counterfactuals in data: 109
# Data distribution after iteration 184:
# 	Majority (1): 366, Minority (label 0): 346
# Number of 'good' native counterfactuals in data: 109
# Data distribution after iteration 185:
# 	Majority (1): 366, Minority (label 0): 347
# Number of 'good' native counterfactuals in data: 109
# Data distribution after iteration 186:
# 	Majority (1): 366, Minority (label 0): 348
# Number of 'good' native counterfactuals in data: 109
# Data distribution after iteration 187:
# 	Majority (1): 366, Minority (label 0): 349
# Number of 'good' native counterfactuals in data: 109
# Data distribution after iteration 188:
# 	Majority (1): 366, Minority (label 0): 350
# Number of 'good' native counterfactuals in data: 109
# Data distribution after iteration 189:
# 	Majority (1): 366, Minority (label 0): 351
# Number of 'good' native counterfactuals in data: 109
# Data distribution after iteration 190:
# 	Majority (1): 366, Minority (label 0): 352
# Number of 'good' native counterfactuals in data: 109
# Data distribution after iteration 191:
# 	Majority (1): 366, Minority (label 0): 353
# Number of 'good' native counterfactuals in data: 109
# Data distribution after iteration 192:
# 	Majority (1): 366, Minority (label 0): 354
# Number of 'good' native counterfactuals in data: 109
# Data distribution after iteration 193:
# 	Majority (1): 366, Minority (label 0): 355
# Number of 'good' native counterfactuals in data: 109
# Data distribution after iteration 194:
# 	Majority (1): 366, Minority (label 0): 356
# Number of 'good' native counterfactuals in data: 109
# Data distribution after iteration 195:
# 	Majority (1): 366, Minority (label 0): 357
# Number of 'good' native counterfactuals in data: 109
# Data distribution after iteration 196:
# 	Majority (1): 366, Minority (label 0): 358
# Number of 'good' native counterfactuals in data: 109
# Data distribution after iteration 197:
# 	Majority (1): 366, Minority (label 0): 359
# Number of 'good' native counterfactuals in data: 109
# Data distribution after iteration 198:
# 	Majority (1): 366, Minority (label 0): 360
# Number of 'good' native counterfactuals in data: 109
# Data distribution after iteration 199:
# 	Majority (1): 366, Minority (label 0): 361
# Number of 'good' native counterfactuals in data: 109
# Data distribution after iteration 200:
# 	Majority (1): 366, Minority (label 0): 362
# Number of 'good' native counterfactuals in data: 109
# Data distribution after iteration 201:
# 	Majority (1): 366, Minority (label 0): 363
# ====================================================================
# Data distribution after CFA:
# 	Majority (1): 366, Minority (label 0): 363
# Fold 3:
# Fitting baseline model needed for verification...
# Data distribution before CFA:
# 	Majority (1): 368, Minority (label 0): 37
# Number of 'good' native counterfactuals in data: 207
# Data distribution after iteration 0:
# 	Majority (1): 368, Minority (label 0): 41
# Number of 'good' native counterfactuals in data: 212
# Classifier predicted all new synthetic counterfactuals to be in the majority class! => No new minority instances => Terminating...
# ====================================================================
# Data distribution after CFA:
# 	Majority (1): 368, Minority (label 0): 41
# Fold 4:
# Fitting baseline model needed for verification...
# Data distribution before CFA:
# 	Majority (1): 365, Minority (label 0): 40
# Number of 'good' native counterfactuals in data: 184
# Data distribution after iteration 0:
# 	Majority (1): 365, Minority (label 0): 41
# Number of 'good' native counterfactuals in data: 185
# Classifier predicted all new synthetic counterfactuals to be in the majority class! => No new minority instances => Terminating...
# ====================================================================
# Data distribution after CFA:
# 	Majority (1): 365, Minority (label 0): 41

# %%
score_avg_over_folds = np.array(all_scores).mean(axis=0)
best_score_idx = score_avg_over_folds.argmax()
print(f"Best params: {combination_dicts[best_score_idx]}")
print(f"Best AUC: {score_avg_over_folds[best_score_idx]}")
# Out:
# Best params: {'max_depth': 10, 'n_estimators': 600}
# Best AUC: 0.8200915579266095

# %% [markdown]
# ### ADASYN instead of CFA

# %%
from imblearn.over_sampling import ADASYN
ada = ADASYN(random_state=9317231)

# %%
all_scores = []

for i, (train_index, test_index) in enumerate(kf.split(X)):
    #print(f"Fold {i}:")
    scores_for_fold = []
    X_train, X_test, y_train, y_test = X.iloc[train_index], X.iloc[test_index], y.iloc[train_index], y.iloc[test_index]
        
    X_train_resampled, y_train_resampled = ada.fit_resample(X_train, y_train)
        
    for param_comb in combination_dicts:
        clf = RandomForestClassifier(random_state=19231823, **param_comb)
        clf.fit(X_train_resampled, y_train_resampled)
        current_score = roc_auc_score(y_test, clf.predict_proba(X_test)[:, 1])
        #print(f"Score for combination {param_comb}: {current_score}")
        scores_for_fold.append(current_score)
        
    all_scores.append(scores_for_fold)

# %%
score_avg_over_folds = np.array(all_scores).mean(axis=0)
best_score_idx = score_avg_over_folds.argmax()
print(f"Best params: {combination_dicts[best_score_idx]}")
print(f"Best AUC: {score_avg_over_folds[best_score_idx]}")
# Out:
# Best params: {'max_depth': 4, 'n_estimators': 200}
# Best AUC: 0.7789210331478372

# %% [markdown]
# ### Random Oversampling instead of CFA

# %%
from imblearn.over_sampling import RandomOverSampler
ros = RandomOverSampler(random_state=52012318)

# %%
all_scores = []

for i, (train_index, test_index) in enumerate(kf.split(X)):
    #print(f"Fold {i}:")
    scores_for_fold = []
    X_train, X_test, y_train, y_test = X.iloc[train_index], X.iloc[test_index], y.iloc[train_index], y.iloc[test_index]
        
    X_train_resampled, y_train_resampled = ros.fit_resample(X_train, y_train)
        
    for param_comb in combination_dicts:
        clf = RandomForestClassifier(random_state=19231823, **param_comb)
        clf.fit(X_train_resampled, y_train_resampled)
        current_score = roc_auc_score(y_test, clf.predict_proba(X_test)[:, 1])
        #print(f"Score for combination {param_comb}: {current_score}")
        scores_for_fold.append(current_score)
        
    all_scores.append(scores_for_fold)

# %%
score_avg_over_folds = np.array(all_scores).mean(axis=0)
best_score_idx = score_avg_over_folds.argmax()
print(f"Best params: {combination_dicts[best_score_idx]}")
print(f"Best AUC: {score_avg_over_folds[best_score_idx]}")
# Out:
# Best params: {'max_depth': None, 'n_estimators': 600}
# Best AUC: 0.811675861366583

# %% [markdown]
# ## Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr_param_grid = {"max_iter": [100, 200, 1000], 
                 "C": [0.001, 0.01, 0.1, 1, 10, 100, 1000],
                 "solver": ["newton-cg", "lbfgs", "liblinear", "sag"]}

# compute all combinations of parameters
combination_dicts = list(ParameterGrid(lr_param_grid))

# %% [markdown]
# ### Baseline (no augmentation)

# %%
all_scores = []

for i, (train_index, test_index) in enumerate(kf.split(X)):
    #print(f"Fold {i}:")
    scores_for_fold = []
    X_train, X_test, y_train, y_test = X.iloc[train_index], X.iloc[test_index], y.iloc[train_index], y.iloc[test_index]
        
    for param_comb in combination_dicts:
        clf = LogisticRegression(random_state=19231823, **param_comb)
        clf.fit(X_train, y_train)
        current_score = roc_auc_score(y_test, clf.predict_proba(X_test)[:, 1])
        #print(f"Score for combination {param_comb}: {current_score}")
        scores_for_fold.append(current_score)
        
    all_scores.append(scores_for_fold)

# %%
score_avg_over_folds = np.array(all_scores).mean(axis=0)
best_score_idx = score_avg_over_folds.argmax()
print(f"Best params: {combination_dicts[best_score_idx]}")
print(f"Best AUC: {score_avg_over_folds[best_score_idx]}")
# Out:
# Best params: {'C': 10, 'max_iter': 100, 'solver': 'newton-cg'}
# Best AUC: 0.8111887196423279

# %% [markdown]
# Again, we can compare to an out-of-the-box grid search to make sure:

# %%
baseline_search = GridSearchCV(LogisticRegression(random_state=19231823), lr_param_grid, scoring="roc_auc")
baseline_search.fit(X, y)
baseline_search.best_score_
# Out:
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# 0.8081055900621118

# %% [markdown]
# ### With CFA

# %% [markdown]
# #### Approach 1: No verification

# %%
all_scores = []

for i, (train_index, test_index) in enumerate(kf.split(X)):
    print(f"Fold {i}:")
    scores_for_fold = []
    X_train, X_test, y_train, y_test = X.iloc[train_index], X.iloc[test_index], y.iloc[train_index], y.iloc[test_index]
    
    X_train_augmented, y_train_augmented = Iterative_CFA(X_train, 
                                                         y_train, 
                                                         stddev_percent=50, 
                                                         verify_with_baseline_model=False, 
                                                         visualize_with_pca=False)

    for param_comb in combination_dicts:
        clf = LogisticRegression(random_state=19231823, **param_comb)
        clf.fit(X_train_augmented, y_train_augmented)
        current_score = roc_auc_score(y_test, clf.predict_proba(X_test)[:, 1])
        #print(f"Score for combination {param_comb}: {current_score}")
        scores_for_fold.append(current_score)
        
    all_scores.append(scores_for_fold)
# Out:
# Fold 0:
# Data distribution before CFA:
# 	Majority (1): 359, Minority (label 0): 45
# Number of 'good' native counterfactuals in data: 195
# Data distribution after iteration 0:
# 	Majority (1): 359, Minority (label 0): 198
# Number of 'good' native counterfactuals in data: 270
# Data distribution after iteration 1:
# 	Majority (1): 359, Minority (label 0): 241
# Number of 'good' native counterfactuals in data: 285
# Data distribution after iteration 2:
# 	Majority (1): 359, Minority (label 0): 261
# Number of 'good' native counterfactuals in data: 290
# Data distribution after iteration 3:
# 	Majority (1): 359, Minority (label 0): 274
# Number of 'good' native counterfactuals in data: 290
# Data distribution after iteration 4:
# 	Majority (1): 359, Minority (label 0): 287
# Number of 'good' native counterfactuals in data: 291
# Data distribution after iteration 5:
# 	Majority (1): 359, Minority (label 0): 298
# Number of 'good' native counterfactuals in data: 291
# Data distribution after iteration 6:
# 	Majority (1): 359, Minority (label 0): 309
# Number of 'good' native counterfactuals in data: 291
# Data distribution after iteration 7:
# 	Majority (1): 359, Minority (label 0): 320
# Number of 'good' native counterfactuals in data: 291
# Data distribution after iteration 8:
# 	Majority (1): 359, Minority (label 0): 331
# Number of 'good' native counterfactuals in data: 291
# Data distribution after iteration 9:
# 	Majority (1): 359, Minority (label 0): 342
# Number of 'good' native counterfactuals in data: 291
# Data distribution after iteration 10:
# 	Majority (1): 359, Minority (label 0): 353
# Number of 'good' native counterfactuals in data: 291
# Data distribution after iteration 11:
# 	Majority (1): 359, Minority (label 0): 359
# ====================================================================
# Data distribution after CFA:
# 	Majority (1): 359, Minority (label 0): 359
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# Fold 1:
# Data distribution before CFA:
# 	Majority (1): 366, Minority (label 0): 39
# Number of 'good' native counterfactuals in data: 167
# Data distribution after iteration 0:
# 	Majority (1): 366, Minority (label 0): 226
# Number of 'good' native counterfactuals in data: 279
# Data distribution after iteration 1:
# 	Majority (1): 366, Minority (label 0): 274
# Number of 'good' native counterfactuals in data: 303
# Data distribution after iteration 2:
# 	Majority (1): 366, Minority (label 0): 294
# Number of 'good' native counterfactuals in data: 307
# Data distribution after iteration 3:
# 	Majority (1): 366, Minority (label 0): 308
# Number of 'good' native counterfactuals in data: 307
# Data distribution after iteration 4:
# 	Majority (1): 366, Minority (label 0): 322
# Number of 'good' native counterfactuals in data: 307
# Data distribution after iteration 5:
# 	Majority (1): 366, Minority (label 0): 336
# Number of 'good' native counterfactuals in data: 307
# Data distribution after iteration 6:
# 	Majority (1): 366, Minority (label 0): 350
# Number of 'good' native counterfactuals in data: 308
# Data distribution after iteration 7:
# 	Majority (1): 366, Minority (label 0): 364
# ====================================================================
# Data distribution after CFA:
# 	Majority (1): 366, Minority (label 0): 364
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# Fold 2:
# Data distribution before CFA:
# 	Majority (1): 366, Minority (label 0): 39
# Number of 'good' native counterfactuals in data: 181
# Data distribution after iteration 0:
# 	Majority (1): 366, Minority (label 0): 213
# Number of 'good' native counterfactuals in data: 271
# Data distribution after iteration 1:
# 	Majority (1): 366, Minority (label 0): 266
# Number of 'good' native counterfactuals in data: 291
# Data distribution after iteration 2:
# 	Majority (1): 366, Minority (label 0): 281
# Number of 'good' native counterfactuals in data: 294
# Data distribution after iteration 3:
# 	Majority (1): 366, Minority (label 0): 292
# Number of 'good' native counterfactuals in data: 295
# Data distribution after iteration 4:
# 	Majority (1): 366, Minority (label 0): 302
# Number of 'good' native counterfactuals in data: 295
# Data distribution after iteration 5:
# 	Majority (1): 366, Minority (label 0): 312
# Number of 'good' native counterfactuals in data: 297
# Data distribution after iteration 6:
# 	Majority (1): 366, Minority (label 0): 325
# Number of 'good' native counterfactuals in data: 297
# Data distribution after iteration 7:
# 	Majority (1): 366, Minority (label 0): 338
# Number of 'good' native counterfactuals in data: 298
# Data distribution after iteration 8:
# 	Majority (1): 366, Minority (label 0): 349
# Number of 'good' native counterfactuals in data: 298
# Data distribution after iteration 9:
# 	Majority (1): 366, Minority (label 0): 360
# Number of 'good' native counterfactuals in data: 298
# Data distribution after iteration 10:
# 	Majority (1): 366, Minority (label 0): 366
# ====================================================================
# Data distribution after CFA:
# 	Majority (1): 366, Minority (label 0): 366
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# Fold 3:
# Data distribution before CFA:
# 	Majority (1): 368, Minority (label 0): 37
# Number of 'good' native counterfactuals in data: 207
# Data distribution after iteration 0:
# 	Majority (1): 368, Minority (label 0): 187
# Number of 'good' native counterfactuals in data: 272
# Data distribution after iteration 1:
# 	Majority (1): 368, Minority (label 0): 233
# Number of 'good' native counterfactuals in data: 289
# Data distribution after iteration 2:
# 	Majority (1): 368, Minority (label 0): 253
# Number of 'good' native counterfactuals in data: 298
# Data distribution after iteration 3:
# 	Majority (1): 368, Minority (label 0): 262
# Number of 'good' native counterfactuals in data: 299
# Data distribution after iteration 4:
# 	Majority (1): 368, Minority (label 0): 268
# Number of 'good' native counterfactuals in data: 299
# Data distribution after iteration 5:
# 	Majority (1): 368, Minority (label 0): 274
# Number of 'good' native counterfactuals in data: 299
# Data distribution after iteration 6:
# 	Majority (1): 368, Minority (label 0): 280
# Number of 'good' native counterfactuals in data: 299
# Data distribution after iteration 7:
# 	Majority (1): 368, Minority (label 0): 286
# Number of 'good' native counterfactuals in data: 299
# Data distribution after iteration 8:
# 	Majority (1): 368, Minority (label 0): 292
# Number of 'good' native counterfactuals in data: 299
# Data distribution after iteration 9:
# 	Majority (1): 368, Minority (label 0): 298
# Number of 'good' native counterfactuals in data: 299
# Data distribution after iteration 10:
# 	Majority (1): 368, Minority (label 0): 304
# Number of 'good' native counterfactuals in data: 299
# Data distribution after iteration 11:
# 	Majority (1): 368, Minority (label 0): 310
# Number of 'good' native counterfactuals in data: 299
# Data distribution after iteration 12:
# 	Majority (1): 368, Minority (label 0): 316
# Number of 'good' native counterfactuals in data: 299
# Data distribution after iteration 13:
# 	Majority (1): 368, Minority (label 0): 322
# Number of 'good' native counterfactuals in data: 299
# Data distribution after iteration 14:
# 	Majority (1): 368, Minority (label 0): 328
# Number of 'good' native counterfactuals in data: 299
# Data distribution after iteration 15:
# 	Majority (1): 368, Minority (label 0): 334
# Number of 'good' native counterfactuals in data: 299
# Data distribution after iteration 16:
# 	Majority (1): 368, Minority (label 0): 340
# Number of 'good' native counterfactuals in data: 299
# Data distribution after iteration 17:
# 	Majority (1): 368, Minority (label 0): 346
# Number of 'good' native counterfactuals in data: 299
# Data distribution after iteration 18:
# 	Majority (1): 368, Minority (label 0): 352
# Number of 'good' native counterfactuals in data: 299
# Data distribution after iteration 19:
# 	Majority (1): 368, Minority (label 0): 358
# Number of 'good' native counterfactuals in data: 299
# Data distribution after iteration 20:
# 	Majority (1): 368, Minority (label 0): 364
# Number of 'good' native counterfactuals in data: 299
# Data distribution after iteration 21:
# 	Majority (1): 368, Minority (label 0): 368
# ====================================================================
# Data distribution after CFA:
# 	Majority (1): 368, Minority (label 0): 368
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# Fold 4:
# Data distribution before CFA:
# 	Majority (1): 365, Minority (label 0): 40
# Number of 'good' native counterfactuals in data: 184
# Data distribution after iteration 0:
# 	Majority (1): 365, Minority (label 0): 211
# Number of 'good' native counterfactuals in data: 269
# Data distribution after iteration 1:
# 	Majority (1): 365, Minority (label 0): 267
# Number of 'good' native counterfactuals in data: 278
# Data distribution after iteration 2:
# 	Majority (1): 365, Minority (label 0): 297
# Number of 'good' native counterfactuals in data: 287
# Data distribution after iteration 3:
# 	Majority (1): 365, Minority (label 0): 312
# Number of 'good' native counterfactuals in data: 285
# Data distribution after iteration 4:
# 	Majority (1): 365, Minority (label 0): 326
# Number of 'good' native counterfactuals in data: 287
# Data distribution after iteration 5:
# 	Majority (1): 365, Minority (label 0): 338
# Number of 'good' native counterfactuals in data: 287
# Data distribution after iteration 6:
# 	Majority (1): 365, Minority (label 0): 350
# Number of 'good' native counterfactuals in data: 287
# Data distribution after iteration 7:
# 	Majority (1): 365, Minority (label 0): 362
# ====================================================================
# Data distribution after CFA:
# 	Majority (1): 365, Minority (label 0): 362
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(

# %%
score_avg_over_folds = np.array(all_scores).mean(axis=0)
best_score_idx = score_avg_over_folds.argmax()
print(f"Best params: {combination_dicts[best_score_idx]}")
print(f"Best AUC: {score_avg_over_folds[best_score_idx]}")
# Out:
# Best params: {'C': 1, 'max_iter': 100, 'solver': 'liblinear'}
# Best AUC: 0.6949766155951723

# %% [markdown]
# #### Approach 2: Verification of new synthetic counterfactuals with baseline model

# %%
all_scores = []

for i, (train_index, test_index) in enumerate(kf.split(X)):
    print(f"Fold {i}:")
    scores_for_fold = []
    X_train, X_test, y_train, y_test = X.iloc[train_index], X.iloc[test_index], y.iloc[train_index], y.iloc[test_index]
    
    print("Fitting baseline model needed for verification... ")
    baseline_search = GridSearchCV(LogisticRegression(random_state=19231823), lr_param_grid, scoring="roc_auc")
    baseline_search.fit(X_train, y_train)
    
    X_train_augmented, y_train_augmented = Iterative_CFA(X_train, 
                                                         y_train, 
                                                         stddev_percent=50, 
                                                         verify_with_baseline_model=True, 
                                                         baseline_model=baseline_search,
                                                         visualize_with_pca=False)

    for param_comb in combination_dicts:
        clf = LogisticRegression(random_state=19231823, **param_comb)
        clf.fit(X_train_augmented, y_train_augmented)
        current_score = roc_auc_score(y_test, clf.predict_proba(X_test)[:, 1])
        #print(f"Score for combination {param_comb}: {current_score}")
        scores_for_fold.append(current_score)
        
    all_scores.append(scores_for_fold)
# Out:
# Fold 0:
# Fitting baseline model needed for verification...
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# Data distribution before CFA:
# 	Majority (1): 359, Minority (label 0): 45
# Number of 'good' native counterfactuals in data: 195
# Data distribution after iteration 0:
# 	Majority (1): 359, Minority (label 0): 47
# Number of 'good' native counterfactuals in data: 197
# Classifier predicted all new synthetic counterfactuals to be in the majority class! => No new minority instances => Terminating...
# ====================================================================
# Data distribution after CFA:
# 	Majority (1): 359, Minority (label 0): 47
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# Fold 1:
# Fitting baseline model needed for verification...
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# Data distribution before CFA:
# 	Majority (1): 366, Minority (label 0): 39
# Number of 'good' native counterfactuals in data: 167
# Data distribution after iteration 0:
# 	Majority (1): 366, Minority (label 0): 41
# Number of 'good' native counterfactuals in data: 169
# Classifier predicted all new synthetic counterfactuals to be in the majority class! => No new minority instances => Terminating...
# ====================================================================
# Data distribution after CFA:
# 	Majority (1): 366, Minority (label 0): 41
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# Fold 2:
# Fitting baseline model needed for verification...
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# Data distribution before CFA:
# 	Majority (1): 366, Minority (label 0): 39
# Number of 'good' native counterfactuals in data: 181
# Data distribution after iteration 0:
# 	Majority (1): 366, Minority (label 0): 41
# Number of 'good' native counterfactuals in data: 181
# Data distribution after iteration 1:
# 	Majority (1): 366, Minority (label 0): 43
# Number of 'good' native counterfactuals in data: 181
# Data distribution after iteration 2:
# 	Majority (1): 366, Minority (label 0): 45
# Number of 'good' native counterfactuals in data: 174
# Data distribution after iteration 3:
# 	Majority (1): 366, Minority (label 0): 47
# Number of 'good' native counterfactuals in data: 174
# Data distribution after iteration 4:
# 	Majority (1): 366, Minority (label 0): 49
# Number of 'good' native counterfactuals in data: 174
# Data distribution after iteration 5:
# 	Majority (1): 366, Minority (label 0): 51
# Number of 'good' native counterfactuals in data: 174
# Data distribution after iteration 6:
# 	Majority (1): 366, Minority (label 0): 53
# Number of 'good' native counterfactuals in data: 174
# Data distribution after iteration 7:
# 	Majority (1): 366, Minority (label 0): 55
# Number of 'good' native counterfactuals in data: 174
# Data distribution after iteration 8:
# 	Majority (1): 366, Minority (label 0): 57
# Number of 'good' native counterfactuals in data: 174
# Data distribution after iteration 9:
# 	Majority (1): 366, Minority (label 0): 59
# Number of 'good' native counterfactuals in data: 174
# Data distribution after iteration 10:
# 	Majority (1): 366, Minority (label 0): 61
# Number of 'good' native counterfactuals in data: 174
# Data distribution after iteration 11:
# 	Majority (1): 366, Minority (label 0): 63
# Number of 'good' native counterfactuals in data: 174
# Data distribution after iteration 12:
# 	Majority (1): 366, Minority (label 0): 65
# Number of 'good' native counterfactuals in data: 174
# Data distribution after iteration 13:
# 	Majority (1): 366, Minority (label 0): 67
# Number of 'good' native counterfactuals in data: 174
# Data distribution after iteration 14:
# 	Majority (1): 366, Minority (label 0): 69
# Number of 'good' native counterfactuals in data: 174
# Data distribution after iteration 15:
# 	Majority (1): 366, Minority (label 0): 71
# Number of 'good' native counterfactuals in data: 174
# Data distribution after iteration 16:
# 	Majority (1): 366, Minority (label 0): 73
# Number of 'good' native counterfactuals in data: 174
# Data distribution after iteration 17:
# 	Majority (1): 366, Minority (label 0): 75
# Number of 'good' native counterfactuals in data: 174
# Data distribution after iteration 18:
# 	Majority (1): 366, Minority (label 0): 77
# Number of 'good' native counterfactuals in data: 174
# Data distribution after iteration 19:
# 	Majority (1): 366, Minority (label 0): 79
# Number of 'good' native counterfactuals in data: 174
# Data distribution after iteration 20:
# 	Majority (1): 366, Minority (label 0): 81
# Number of 'good' native counterfactuals in data: 174
# Data distribution after iteration 21:
# 	Majority (1): 366, Minority (label 0): 83
# Number of 'good' native counterfactuals in data: 174
# Data distribution after iteration 22:
# 	Majority (1): 366, Minority (label 0): 85
# Number of 'good' native counterfactuals in data: 174
# Data distribution after iteration 23:
# 	Majority (1): 366, Minority (label 0): 87
# Number of 'good' native counterfactuals in data: 174
# Data distribution after iteration 24:
# 	Majority (1): 366, Minority (label 0): 89
# Number of 'good' native counterfactuals in data: 174
# Data distribution after iteration 25:
# 	Majority (1): 366, Minority (label 0): 91
# Number of 'good' native counterfactuals in data: 174
# Data distribution after iteration 26:
# 	Majority (1): 366, Minority (label 0): 93
# Number of 'good' native counterfactuals in data: 174
# Data distribution after iteration 27:
# 	Majority (1): 366, Minority (label 0): 95
# Number of 'good' native counterfactuals in data: 174
# Data distribution after iteration 28:
# 	Majority (1): 366, Minority (label 0): 97
# Number of 'good' native counterfactuals in data: 174
# Data distribution after iteration 29:
# 	Majority (1): 366, Minority (label 0): 99
# Number of 'good' native counterfactuals in data: 174
# Data distribution after iteration 30:
# 	Majority (1): 366, Minority (label 0): 101
# Number of 'good' native counterfactuals in data: 174
# Data distribution after iteration 31:
# 	Majority (1): 366, Minority (label 0): 103
# Number of 'good' native counterfactuals in data: 174
# Data distribution after iteration 32:
# 	Majority (1): 366, Minority (label 0): 105
# Number of 'good' native counterfactuals in data: 174
# Data distribution after iteration 33:
# 	Majority (1): 366, Minority (label 0): 107
# Number of 'good' native counterfactuals in data: 174
# Data distribution after iteration 34:
# 	Majority (1): 366, Minority (label 0): 109
# Number of 'good' native counterfactuals in data: 162
# Data distribution after iteration 35:
# 	Majority (1): 366, Minority (label 0): 111
# Number of 'good' native counterfactuals in data: 162
# Data distribution after iteration 36:
# 	Majority (1): 366, Minority (label 0): 113
# Number of 'good' native counterfactuals in data: 162
# Data distribution after iteration 37:
# 	Majority (1): 366, Minority (label 0): 115
# Number of 'good' native counterfactuals in data: 162
# Data distribution after iteration 38:
# 	Majority (1): 366, Minority (label 0): 117
# Number of 'good' native counterfactuals in data: 162
# Data distribution after iteration 39:
# 	Majority (1): 366, Minority (label 0): 119
# Number of 'good' native counterfactuals in data: 162
# Data distribution after iteration 40:
# 	Majority (1): 366, Minority (label 0): 121
# Number of 'good' native counterfactuals in data: 162
# Data distribution after iteration 41:
# 	Majority (1): 366, Minority (label 0): 123
# Number of 'good' native counterfactuals in data: 162
# Data distribution after iteration 42:
# 	Majority (1): 366, Minority (label 0): 125
# Number of 'good' native counterfactuals in data: 162
# Data distribution after iteration 43:
# 	Majority (1): 366, Minority (label 0): 127
# Number of 'good' native counterfactuals in data: 162
# Data distribution after iteration 44:
# 	Majority (1): 366, Minority (label 0): 129
# Number of 'good' native counterfactuals in data: 162
# Data distribution after iteration 45:
# 	Majority (1): 366, Minority (label 0): 131
# Number of 'good' native counterfactuals in data: 162
# Data distribution after iteration 46:
# 	Majority (1): 366, Minority (label 0): 133
# Number of 'good' native counterfactuals in data: 162
# Data distribution after iteration 47:
# 	Majority (1): 366, Minority (label 0): 135
# Number of 'good' native counterfactuals in data: 162
# Data distribution after iteration 48:
# 	Majority (1): 366, Minority (label 0): 137
# Number of 'good' native counterfactuals in data: 162
# Data distribution after iteration 49:
# 	Majority (1): 366, Minority (label 0): 139
# Number of 'good' native counterfactuals in data: 162
# Data distribution after iteration 50:
# 	Majority (1): 366, Minority (label 0): 141
# Number of 'good' native counterfactuals in data: 162
# Data distribution after iteration 51:
# 	Majority (1): 366, Minority (label 0): 143
# Number of 'good' native counterfactuals in data: 162
# Data distribution after iteration 52:
# 	Majority (1): 366, Minority (label 0): 145
# Number of 'good' native counterfactuals in data: 162
# Data distribution after iteration 53:
# 	Majority (1): 366, Minority (label 0): 147
# Number of 'good' native counterfactuals in data: 162
# Data distribution after iteration 54:
# 	Majority (1): 366, Minority (label 0): 149
# Number of 'good' native counterfactuals in data: 162
# Data distribution after iteration 55:
# 	Majority (1): 366, Minority (label 0): 151
# Number of 'good' native counterfactuals in data: 162
# Data distribution after iteration 56:
# 	Majority (1): 366, Minority (label 0): 153
# Number of 'good' native counterfactuals in data: 162
# Data distribution after iteration 57:
# 	Majority (1): 366, Minority (label 0): 155
# Number of 'good' native counterfactuals in data: 162
# Data distribution after iteration 58:
# 	Majority (1): 366, Minority (label 0): 157
# Number of 'good' native counterfactuals in data: 162
# Data distribution after iteration 59:
# 	Majority (1): 366, Minority (label 0): 159
# Number of 'good' native counterfactuals in data: 162
# Data distribution after iteration 60:
# 	Majority (1): 366, Minority (label 0): 161
# Number of 'good' native counterfactuals in data: 162
# Data distribution after iteration 61:
# 	Majority (1): 366, Minority (label 0): 163
# Number of 'good' native counterfactuals in data: 158
# Data distribution after iteration 62:
# 	Majority (1): 366, Minority (label 0): 165
# Number of 'good' native counterfactuals in data: 158
# Data distribution after iteration 63:
# 	Majority (1): 366, Minority (label 0): 167
# Number of 'good' native counterfactuals in data: 158
# Data distribution after iteration 64:
# 	Majority (1): 366, Minority (label 0): 169
# Number of 'good' native counterfactuals in data: 158
# Data distribution after iteration 65:
# 	Majority (1): 366, Minority (label 0): 171
# Number of 'good' native counterfactuals in data: 158
# Data distribution after iteration 66:
# 	Majority (1): 366, Minority (label 0): 173
# Number of 'good' native counterfactuals in data: 158
# Data distribution after iteration 67:
# 	Majority (1): 366, Minority (label 0): 175
# Number of 'good' native counterfactuals in data: 158
# Data distribution after iteration 68:
# 	Majority (1): 366, Minority (label 0): 177
# Number of 'good' native counterfactuals in data: 158
# Data distribution after iteration 69:
# 	Majority (1): 366, Minority (label 0): 179
# Number of 'good' native counterfactuals in data: 158
# Data distribution after iteration 70:
# 	Majority (1): 366, Minority (label 0): 181
# Number of 'good' native counterfactuals in data: 158
# Data distribution after iteration 71:
# 	Majority (1): 366, Minority (label 0): 183
# Number of 'good' native counterfactuals in data: 158
# Data distribution after iteration 72:
# 	Majority (1): 366, Minority (label 0): 185
# Number of 'good' native counterfactuals in data: 158
# Data distribution after iteration 73:
# 	Majority (1): 366, Minority (label 0): 187
# Number of 'good' native counterfactuals in data: 142
# Data distribution after iteration 74:
# 	Majority (1): 366, Minority (label 0): 189
# Number of 'good' native counterfactuals in data: 144
# Classifier predicted all new synthetic counterfactuals to be in the majority class! => No new minority instances => Terminating...
# ====================================================================
# Data distribution after CFA:
# 	Majority (1): 366, Minority (label 0): 189
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# Fold 3:
# Fitting baseline model needed for verification...
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# Data distribution before CFA:
# 	Majority (1): 368, Minority (label 0): 37
# Number of 'good' native counterfactuals in data: 207
# Data distribution after iteration 0:
# 	Majority (1): 368, Minority (label 0): 39
# Number of 'good' native counterfactuals in data: 199
# Classifier predicted all new synthetic counterfactuals to be in the majority class! => No new minority instances => Terminating...
# ====================================================================
# Data distribution after CFA:
# 	Majority (1): 368, Minority (label 0): 39
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# Fold 4:
# Fitting baseline model needed for verification...
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# Data distribution before CFA:
# 	Majority (1): 365, Minority (label 0): 40
# Number of 'good' native counterfactuals in data: 184
# Data distribution after iteration 0:
# 	Majority (1): 365, Minority (label 0): 41
# Number of 'good' native counterfactuals in data: 185
# Classifier predicted all new synthetic counterfactuals to be in the majority class! => No new minority instances => Terminating...
# ====================================================================
# Data distribution after CFA:
# 	Majority (1): 365, Minority (label 0): 41
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\fredd\Anaconda3\envs\cfa\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(

# %%
score_avg_over_folds = np.array(all_scores).mean(axis=0)
best_score_idx = score_avg_over_folds.argmax()
print(f"Best params: {combination_dicts[best_score_idx]}")
print(f"Best AUC: {score_avg_over_folds[best_score_idx]}")
# Out:
# Best params: {'C': 10, 'max_iter': 100, 'solver': 'newton-cg'}
# Best AUC: 0.8121044705580788

# %% [markdown]
# ### ADASYN

# %%
all_scores = []

for i, (train_index, test_index) in enumerate(kf.split(X)):
    #print(f"Fold {i}:")
    scores_for_fold = []
    X_train, X_test, y_train, y_test = X.iloc[train_index], X.iloc[test_index], y.iloc[train_index], y.iloc[test_index]
        
    X_train_resampled, y_train_resampled = ada.fit_resample(X_train, y_train)
        
    for param_comb in combination_dicts:
        clf = LogisticRegression(random_state=19231823, **param_comb)
        clf.fit(X_train_resampled, y_train_resampled)
        current_score = roc_auc_score(y_test, clf.predict_proba(X_test)[:, 1])
        #print(f"Score for combination {param_comb}: {current_score}")
        scores_for_fold.append(current_score)
        
    all_scores.append(scores_for_fold)

# %%
score_avg_over_folds = np.array(all_scores).mean(axis=0)
best_score_idx = score_avg_over_folds.argmax()
print(f"Best params: {combination_dicts[best_score_idx]}")
print(f"Best AUC: {score_avg_over_folds[best_score_idx]}")
# Out:
# Best params: {'C': 1, 'max_iter': 100, 'solver': 'liblinear'}
# Best AUC: 0.8061193388512976

# %% [markdown]
# ### Random Oversampling

# %%
all_scores = []

for i, (train_index, test_index) in enumerate(kf.split(X)):
    #print(f"Fold {i}:")
    scores_for_fold = []
    X_train, X_test, y_train, y_test = X.iloc[train_index], X.iloc[test_index], y.iloc[train_index], y.iloc[test_index]
        
    X_train_resampled, y_train_resampled = ros.fit_resample(X_train, y_train)
        
    for param_comb in combination_dicts:
        clf = LogisticRegression(random_state=19231823, **param_comb)
        clf.fit(X_train_resampled, y_train_resampled)
        current_score = roc_auc_score(y_test, clf.predict_proba(X_test)[:, 1])
        #print(f"Score for combination {param_comb}: {current_score}")
        scores_for_fold.append(current_score)
        
    all_scores.append(scores_for_fold)

# %%
score_avg_over_folds = np.array(all_scores).mean(axis=0)
best_score_idx = score_avg_over_folds.argmax()
print(f"Best params: {combination_dicts[best_score_idx]}")
print(f"Best AUC: {score_avg_over_folds[best_score_idx]}")
# Out:
# Best params: {'C': 1, 'max_iter': 100, 'solver': 'liblinear'}
# Best AUC: 0.7988203892327604
